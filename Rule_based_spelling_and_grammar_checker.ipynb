# %%
import json

# RuleExtractor class (already provided by you)
class RuleExtractor:
    def __init__(self, correct_sentences, incorrect_sentences):
        self.correct_sentences = correct_sentences
        self.incorrect_sentences = incorrect_sentences

    def extract_rules(self):
        rules = {
            "subject_verb_order": [],
            "pronoun_ending_match": [],
            "verb_conjugation": []  # New category
        }

        for correct, incorrect in zip(self.correct_sentences, self.incorrect_sentences):
            if correct != incorrect:
                correct_words = correct.split()
                incorrect_words = incorrect.split()

                # Subject-Verb order rule
                if sorted(correct_words) == sorted(incorrect_words):
                    rules["subject_verb_order"].append({
                        "incorrect": incorrect,
                        "correct": correct
                    })

                # Pronoun-ending match rule
                if len(correct_words) > 1 and len(incorrect_words) > 1:
                    pronoun = correct_words[0]
                    correct_ending = correct_words[-1][-2:]
                    incorrect_ending = incorrect_words[-1][-2:]
                    if pronoun in ["මම", "අපි", "ඔහු"] and correct_ending != incorrect_ending:
                        rules["pronoun_ending_match"].append({
                            "start": pronoun,
                            "end": correct_ending
                        })

                # Verb conjugation rule
                if len(correct_words) == len(incorrect_words):
                    for cw, iw in zip(correct_words, incorrect_words):
                        if cw != iw and cw.endswith("යි") and iw.endswith("ය"):
                            rules["verb_conjugation"].append({
                                "incorrect": iw,
                                "correct": cw
                            })

        # Save rules to a JSON file
        with open(".extracted_rules.json", "w", encoding="utf-8") as file:
            json.dump(rules, file, ensure_ascii=False, indent=4)

        return rules


# Load sentences from files
with open('incorrectSentences.txt', 'r', encoding='utf-8') as f:
    incorrect_sentences = f.read().splitlines()

with open('correctSentences.txt', 'r', encoding='utf-8') as f:
    correct_sentences = f.read().splitlines()

# Initialize RuleExtractor
extractor = RuleExtractor(correct_sentences, incorrect_sentences)

# Extract rules
rules = extractor.extract_rules()
print("Extracted Rules:")
print(json.dumps(rules, ensure_ascii=False, indent=4))

# Example: Apply extracted rules
def apply_rules(sentence, rules):
    # Apply subject-verb order rules
    for rule in rules["subject_verb_order"]:
        if sentence == rule["incorrect"]:
            return rule["correct"]

    # Apply pronoun-ending match rules
    words = sentence.split()
    if len(words) > 1:
        pronoun = words[0]
        if pronoun in ["මම", "අපි", "ඔහු"]:
            correct_end = next(
                (r["end"] for r in rules["pronoun_ending_match"] if r["start"] == pronoun),
                None
            )
            if correct_end and not words[-1].endswith(correct_end):
                words[-1] = words[-1][:-2] + correct_end
                return " ".join(words)

    # Apply verb conjugation rules
    for rule in rules["verb_conjugation"]:
        if rule["incorrect"] in sentence:
            return sentence.replace(rule["incorrect"], rule["correct"])

    return sentence


# Example usage
example_sentence = "අපි පොතක් කියවම ."
corrected_sentence = apply_rules(example_sentence, rules)
print("Original Sentence:", example_sentence)
print("Corrected Sentence:", corrected_sentence)
# Out:
# Extracted Rules:
# {
#     "subject_verb_order": [
#         {
#             "incorrect": "පාසැල් නුඹ  යන්නෙහි",
#             "correct": "නුඹ පාසැල් යන්නෙහි"
#         },
#         {
#             "incorrect": "ඔබ සැම ගුරුතුමාට  කරන්නෙහු ආචාර",
#             "correct": "ඔබ සැම ගුරුතුමාට ආචාර කරන්නෙහු"
#         },
#         {
#             "incorrect": "ගුරුතුමා  උගන්වයි පාඩම",
#             "correct": "ගුරුතුමා පාඩම උගන්වයි"
#         },
#         {
#             "incorrect": "ගුරුවරු  උගන්වති පාඩම්",
#             "correct": "ගුරුවරු පාඩම් උගන්වති"
#         },
#         {
#             "incorrect": "පාසැල් දරුවා  ගියේය",
#             "correct": "දරුවා පාසැල් ගියේය"
#         },
#         {
#             "incorrect": "දරුවෝ  ගියෝය පාසැල්",
#             "correct": "දරුවෝ පාසැල් ගියෝය"
#         },
#         {
#             "incorrect": "දරුවෝ  ගියහ පාසැල්",
#             "correct": "දරුවෝ පාසැල්  ගියහ"
#         },
#         {
#             "incorrect": "පාසැල් දරුවා  යයි ",
#             "correct": "දරුවා පාසැල් යයි "
#         },
#         {
#             "incorrect": "දරුවෝ  යති පාසැල්  ",
#             "correct": "දරුවෝ පාසැල් යති "
#         },
#         {
#             "incorrect": "ඈ අසයි බණ",
#             "correct": "ඈ බණ අසයි "
#         },
#         {
#             "incorrect": "බණ ඈ අසන්නීය",
#             "correct": "ඈ බණ අසන්නීය"
#         },
#         {
#             "incorrect": "ඈ ඇසුවාය බණ",
#             "correct": "ඈ බණ ඇසුවාය"
#         },
#         {
#             "incorrect": "උපාසිකාවෝ  අසති බණ",
#             "correct": "උපාසිකාවෝ බණ අසති"
#         },
#         {
#             "incorrect": "උපාසිකාවෝ  අසන්නෝය බණ",
#             "correct": "උපාසිකාවෝ බණ අසන්නෝය"
#         },
#         {
#             "incorrect": "බණ උපාසිකාවෝ ඇසූහ ",
#             "correct": "උපාසිකාවෝ බණ ඇසූහ "
#         },
#         {
#             "incorrect": "උපාසිකාවෝ ඇසුවෝය බණ",
#             "correct": "උපාසිකාවෝ බණ ඇසුවෝය"
#         },
#         {
#             "incorrect": "ඔහු අසයි බණ",
#             "correct": "ඔහු බණ අසයි "
#         },
#         {
#             "incorrect": "ඔහු අසන්නේය බණ",
#             "correct": "ඔහු බණ අසන්නේය"
#         },
#         {
#             "incorrect": "බණ උපාසකයා ඇසුවේය",
#             "correct": "උපාසකයා බණ ඇසුවේය"
#         },
#         {
#             "incorrect": "උපාසකයෝ අසති බණ",
#             "correct": "උපාසකයෝ බණ අසති "
#         },
#         {
#             "incorrect": "උපාසකයෝ අසන්නෝය බණ",
#             "correct": "උපාසකයෝ බණ අසන්නෝය"
#         },
#         {
#             "incorrect": "උපාසකයෝ ඇසූහ බණ ",
#             "correct": "උපාසකයෝ බණ ඇසූහ "
#         },
#         {
#             "incorrect": "සෙලවෙයි ගස සුළඟට ",
#             "correct": "ගස සුළඟට සෙලවෙයි"
#         },
#         {
#             "incorrect": "ගස  සෙලැවුණි සුළඟට",
#             "correct": "ගස සුළඟට සෙලැවුණි"
#         },
#         {
#             "incorrect": "සුළඟට ගස සෙලවුණේය",
#             "correct": "ගස සුළඟට සෙලවුණේය"
#         },
#         {
#             "incorrect": "ගස් සෙලවෙයි සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවෙයි "
#         },
#         {
#             "incorrect": "ගස්  සෙලවුණි සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවුණි"
#         },
#         {
#             "incorrect": "ගස් සෙලවුණේය සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවුණේය"
#         },
#         {
#             "incorrect": "අපි  නමදිමු දෙමාපියන්",
#             "correct": "අපි දෙමාපියන් නමදිමු"
#         },
#         {
#             "incorrect": "මා විසින්  කියවේ පොත",
#             "correct": "මා විසින් පොත කියවේ"
#         },
#         {
#             "incorrect": "අප විසින් නැමදෙති දෙමාපියෝ ",
#             "correct": "අප විසින් දෙමාපියෝ නැමදෙති"
#         },
#         {
#             "incorrect": "පුතා  පිබිදෙයි අලුයම",
#             "correct": "පුතා අලුයම පිබිදෙයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින්  සදනු ලබයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු ලබයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින් සදනු සෑදෙයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු සෑදෙයි"
#         },
#         {
#             "incorrect": "තාත්තා සේවකයා ලවා කරවයි වැඩ",
#             "correct": "තාත්තා සේවකයා ලවා වැඩ කරවයි "
#         },
#         {
#             "incorrect": "ලේඛකයෝ  ලියති පොත්",
#             "correct": "ලේඛකයෝ පොත් ලියති"
#         },
#         {
#             "incorrect": "මම කඩමි මලක්",
#             "correct": "මම මලක් කඩමි"
#         },
#         {
#             "incorrect": "වඩුවා විසින්  සදනු ලබයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු ලබයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින් සදනු සෑදෙයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු සෑදෙයි"
#         },
#         {
#             "incorrect": "අප විසින්  කඩනු ලැබේ මල්",
#             "correct": "අප විසින් මල් කඩනු ලැබේ "
#         },
#         {
#             "incorrect": "අප විසින්  කඩනු කැඩේ මල්",
#             "correct": "අප විසින් මල් කඩනු කැඩේ"
#         },
#         {
#             "incorrect": "ගුරුවරුන් විසින්  යහ මග යැවේ ශිෂ්‍යයෝ",
#             "correct": "ගුරුවරුන් විසින් ශිෂ්‍යයෝ යහ මග යැවේ"
#         },
#         {
#             "incorrect": "අයියා සෑදූ  හැඩයි සරුංගලය",
#             "correct": "අයියා සෑදූ සරුංගලය හැඩයි"
#         },
#         {
#             "incorrect": "ළමයා මාමා ලවා  කඩවයි අඹ",
#             "correct": "ළමයා මාමා ලවා අඹ කඩවයි"
#         },
#         {
#             "incorrect": "මාමා කෙක්කෙන් කඩයි අඹ",
#             "correct": "මාමා කෙක්කෙන් අඹ කඩයි"
#         },
#         {
#             "incorrect": "ගස්  පිරී තිබේ මල්වලින්",
#             "correct": "ගස් මල්වලින් පිරී තිබේ"
#         },
#         {
#             "incorrect": "විදිලි බුබුළුවලින්  බබලයි තොරණ",
#             "correct": "විදිලි බුබුළුවලින් තොරණ බබලයි "
#         },
#         {
#             "incorrect": "අපි සතුන්ට දක්වමු කරුණාව",
#             "correct": "අපි සතුන්ට කරුණාව දක්වමු"
#         },
#         {
#             "incorrect": "අම්බලම මගීන්ගේ පිණිස නිමවා ඇත පහසුව",
#             "correct": "අම්බලම මගීන්ගේ පහසුව පිණිස නිමවා ඇත"
#         },
#         {
#             "incorrect": "වහලෙන්  බිමට වැටේ වතුර",
#             "correct": "වහලෙන් වතුර බිමට වැටේ"
#         },
#         {
#             "incorrect": "බල්ලා  එලියට ආවේය කුඩුවෙන්",
#             "correct": "බල්ලා කුඩුවෙන් එලියට ආවේය"
#         },
#         {
#             "incorrect": "ඇතාගේ  සුදු පාටය දළ",
#             "correct": "ඇතාගේ දළ සුදු පාටය"
#         },
#         {
#             "incorrect": "ඔහු  පිහිනයි මුහුදේ",
#             "correct": "ඔහු මුහුදේ පිහිනයි"
#         },
#         {
#             "incorrect": "සතුරෝ  ඇද වැටුනෝය රණබිමෙහි",
#             "correct": "සතුරෝ රණබිමෙහි ඇද වැටුනෝය"
#         },
#         {
#             "incorrect": "අඹ  ගෙඩි පිරී ඇත ගස්වල",
#             "correct": "අඹ ගස්වල ගෙඩි පිරී ඇත"
#         },
#         {
#             "incorrect": "මා කියන  අසන්න බස්",
#             "correct": "මා කියන බස් අසන්න"
#         },
#         {
#             "incorrect": "අපට  කියන්න කතාවක්",
#             "correct": "අපට කතාවක් කියන්න"
#         },
#         {
#             "incorrect": "මම  වදිමි අම්මාට",
#             "correct": "මම අම්මාට වදිමි"
#         },
#         {
#             "incorrect": "සිරිපාල  ගියේ ය කඩයට",
#             "correct": "සිරිපාල කඩයට ගියේ ය"
#         },
#         {
#             "incorrect": "ඇත්තු  ඇදී යති පේලියට",
#             "correct": "ඇත්තු පේලියට ඇදී යති"
#         },
#         {
#             "incorrect": "ගස්‌ වැටෙයි සුලඟට",
#             "correct": "ගස්‌ සුලඟට වැටෙයි"
#         },
#         {
#             "incorrect": "ඇය නැළ වූවාය පුතු",
#             "correct": "ඇය පුතු නැළ වූවාය"
#         },
#         {
#             "incorrect": "ඔහු යයි රැකියාවට",
#             "correct": "ඔහු රැකියාවට යයි"
#         },
#         {
#             "incorrect": "ගායකයා ගයයි ගී",
#             "correct": "ගායකයා ගී ගයයි"
#         },
#         {
#             "incorrect": "නිවේදකයා  කරයි නිවේදනය",
#             "correct": "නිවේදකයා නිවේදනය කරයි"
#         },
#         {
#             "incorrect": "පන්ති නායකයා  කියවයි පොත",
#             "correct": "පන්ති නායකයා පොත කියවයි"
#         },
#         {
#             "incorrect": "ළමයා ගසයි බෝලයෙන්‌",
#             "correct": "ළමයා බෝලයෙන්‌ ගසයි"
#         },
#         {
#             "incorrect": "නළු රඟති නිළියෝ",
#             "correct": "නළු නිළියෝ රඟති "
#         },
#         {
#             "incorrect": "සිංහයෝ  නොකති තණ",
#             "correct": "සිංහයෝ තණ නොකති"
#         },
#         {
#             "incorrect": "මම යමි නගරයට",
#             "correct": "මම නගරයට යමි "
#         },
#         {
#             "incorrect": "අපි යමු  නගරයට",
#             "correct": "අපි නගරයට යමු"
#         },
#         {
#             "incorrect": "ඔබ යන්නෙහි  නගරයට",
#             "correct": "ඔබ නගරයට යන්නෙහි "
#         },
#         {
#             "incorrect": "නුබලා යන්නෙහු  නගරයට",
#             "correct": "නුබලා නගරයට යන්නෙහු"
#         },
#         {
#             "incorrect": "නගරයට ඔහු  යයි",
#             "correct": "ඔහු නගරයට යයි"
#         },
#         {
#             "incorrect": "නගරයට අප යති",
#             "correct": "අප නගරයට යති"
#         },
#         {
#             "incorrect": "මම  කළෙමි පාඩමි",
#             "correct": "මම පාඩමි කළෙමි"
#         },
#         {
#             "incorrect": "අපි යන්නේමු පාසල්",
#             "correct": "අපි පාසල් යන්නේමු "
#         },
#         {
#             "incorrect": "කෝවිලට නුඹ යහි ",
#             "correct": "නුඹ කෝවිලට යහි "
#         },
#         {
#             "incorrect": "නුඹ යන්නෙහි කෝවිලට",
#             "correct": "නුඹ කෝවිලට යන්නෙහි"
#         },
#         {
#             "incorrect": "නුඹ ගියෙහි කෝවිලට",
#             "correct": "නුඹ කෝවිලට ගියෙහි"
#         },
#         {
#             "incorrect": "අවදි මම වෙමි",
#             "correct": "මම අවදි වෙමි"
#         },
#         {
#             "incorrect": "මම මඳිමි දත්‌ ",
#             "correct": "මම දත්‌ මඳිමි"
#         },
#         {
#             "incorrect": "මම සෝදමි මුහුණ",
#             "correct": "මම මුහුණ සෝදමි"
#         },
#         {
#             "incorrect": "රට රණවිරුවෝ  රකිති",
#             "correct": "රණවිරුවෝ රට රකිති"
#         },
#         {
#             "incorrect": "කොටියා විසින්‌  මැරෙයි මුව ",
#             "correct": "කොටියා විසින්‌ මුව මැරෙයි"
#         },
#         {
#             "incorrect": "කම්කරුවා විසින්‌  ගොඩ නැගේ මාර්ග",
#             "correct": "කම්කරුවා විසින්‌ මාර්ග ගොඩ නැගේ"
#         },
#         {
#             "incorrect": "මට පුළුවන් පිළිගන්න",
#             "correct": "මට පිළිගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා එකතු",
#             "correct": "ඇය එකතු කළා"
#         },
#         {
#             "incorrect": "අපි  පිළිගත්තා එය",
#             "correct": "අපි එය පිළිගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන්  දුන්නා උපදෙස්",
#             "correct": "ඔවුන් උපදෙස් දුන්නා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් පිළිගන්න",
#             "correct": "මට පිළිගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  දෙනවා ඉඩ",
#             "correct": "ඇය ඉඩ දෙනවා"
#         },
#         {
#             "incorrect": "අපි  කරනවා නිවේදනය",
#             "correct": "අපි නිවේදනය කරනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් ගන්න",
#             "correct": "මට ගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  ඉන්නවා අද",
#             "correct": "ඇය අද ඉන්නවා"
#         },
#         {
#             "incorrect": "ඔවුන්  කළා පිළිවෙළ",
#             "correct": "ඔවුන් පිළිවෙළ කළා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් එන්න",
#             "correct": "මට එන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇයට  පුළුවන් අහන්න",
#             "correct": "ඇයට අහන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය අමුණනවා  එය ",
#             "correct": "ඇය එය අමුණනවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට දෙනවා  පහර",
#             "correct": "අපි ඔවුන්ට පහර දෙනවා"
#         },
#         {
#             "incorrect": "ඔවුන්  මඟහරිනවා ඇයව",
#             "correct": "ඔවුන් ඇයව මඟහරිනවා"
#         },
#         {
#             "incorrect": "මට පුළුවන් පිසින්න",
#             "correct": "මට පිසින්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  වගෙයි ඔහු",
#             "correct": "ඇය ඔහු වගෙයි"
#         },
#         {
#             "incorrect": "අපි   කරනවා පරාජය",
#             "correct": "අපි  පරාජය කරනවා"
#         },
#         {
#             "incorrect": "සතුටට ඔවුන්  පත්වුනා",
#             "correct": "ඔවුන් සතුටට පත්වුනා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් අරඹන්න ",
#             "correct": "මට  අරඹන්න පුළුවන්"
#         },
#         {
#             "incorrect": "අපි  ණයට ගත්තා මුදල්",
#             "correct": "අපි මුදල් ණයට ගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන්  ගන්නවා හුස්ම",
#             "correct": "ඔවුන් හුස්ම ගන්නවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් එන්න",
#             "correct": "මට එන්න පුළුවන්"
#         },
#         {
#             "incorrect": "මට  පුළුවන් සාදන්න",
#             "correct": "මට සාදන්න පුළුවන්"
#         },
#         {
#             "incorrect": "අපි කරනවා  ගණනය ",
#             "correct": "අපි  ගණනය කරනවා"
#         },
#         {
#             "incorrect": "ඇය  තෝරනවා ඔහුව",
#             "correct": "ඇය ඔහුව තෝරනවා"
#         },
#         {
#             "incorrect": "අපි  වහනවා එය",
#             "correct": "අපි එය වහනවා"
#         },
#         {
#             "incorrect": "මෙහෙ ඔහු  එනවා",
#             "correct": "ඔහු මෙහෙ එනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් සසඳන්න ",
#             "correct": "මට  සසඳන්න පුළුවන්"
#         },
#         {
#             "incorrect": "තරඟ ඇය  කරනවා",
#             "correct": "ඇය තරඟ කරනවා"
#         },
#         {
#             "incorrect": "පැමිණිලි අපි  කරනවා",
#             "correct": "අපි පැමිණිලි කරනවා"
#         },
#         {
#             "incorrect": "ඔවුන් දිගටම කළා කියවීම ",
#             "correct": "ඔවුන් කියවීම දිගටම කළා"
#         },
#         {
#             "incorrect": "ඔහු  ඇඬුවා ගැන",
#             "correct": "ඔහු ගැන ඇඬුවා"
#         },
#         {
#             "incorrect": "තීරණය මට  කරන්න පුළුවන්",
#             "correct": "මට තීරණය කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා විස්තර ",
#             "correct": "ඇය විස්තර කළා"
#         },
#         {
#             "incorrect": "අතුරුදහන් ඔවුන්  වුනා",
#             "correct": "ඔවුන් අතුරුදහන් වුනා"
#         },
#         {
#             "incorrect": "එය මම සොයාගත්තා",
#             "correct": "මම එය සොයාගත්තා"
#         },
#         {
#             "incorrect": "එයට  ඇය කැමතිනෑ",
#             "correct": "ඇය එයට කැමතිනෑ"
#         },
#         {
#             "incorrect": "අපි කරනවා  එය ",
#             "correct": "අපි එය කරනවා"
#         },
#         {
#             "incorrect": "ඔවුන් දකිනවා සිහින ",
#             "correct": "ඔවුන් සිහින දකිනවා"
#         },
#         {
#             "incorrect": "මම උපයනවා මුදල්",
#             "correct": "මම මුදල් උපයනවා"
#         },
#         {
#             "incorrect": "ඔහු  කනවා සෑහෙන්න",
#             "correct": "ඔහු සෑහෙන්න කනවා"
#         },
#         {
#             "incorrect": "අපි රසවින්ඳා එය ",
#             "correct": "අපි එය රසවින්ඳා"
#         },
#         {
#             "incorrect": "මෙහෙ ඔවුන් ආවා",
#             "correct": "ඔවුන් මෙහෙ ආවා"
#         },
#         {
#             "incorrect": "පළා ඔහු  ගියා",
#             "correct": "ඔහු පළා ගියා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් කරන්න",
#             "correct": "මට කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇයටත්  හැඟෙනවා එය",
#             "correct": "ඇයටත් එය හැඟෙනවා"
#         },
#         {
#             "incorrect": "එහෙන් අපි  පළාගියා",
#             "correct": "අපි එහෙන් පළාගියා"
#         },
#         {
#             "incorrect": "ඔවුන්  වෙනවා ගුවන්ගත",
#             "correct": "ඔවුන් ගුවන්ගත වෙනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් අනුගමනය කරන්න",
#             "correct": "මට අනුගමනය කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කළා අමතක",
#             "correct": "ඇය අමතක කළා"
#         },
#         {
#             "incorrect": "අපි  දෙනවා සමාව",
#             "correct": "අපි සමාව දෙනවා"
#         },
#         {
#             "incorrect": "මට  ඇයට පුළුවන් දෙන්න ",
#             "correct": "මට ඇයට දෙන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය යනවා එහෙ ",
#             "correct": "ඇය එහෙ යනවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට  කිව්වා ආයුබෝවන්",
#             "correct": "අපි ඔවුන්ට ආයුබෝවන් කිව්වා"
#         },
#         {
#             "incorrect": "මම   කරනවා පිළිකුල්",
#             "correct": "මම  පිළිකුල් කරනවා"
#         },
#         {
#             "incorrect": "එය මට  ඇහෙනවා",
#             "correct": "මට එය ඇහෙනවා"
#         },
#         {
#             "incorrect": "ඇය  මවාගන්නවා සිතෙහි",
#             "correct": "ඇය සිතෙහි මවාගන්නවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට කළා ආරාධනා ",
#             "correct": "අපි ඔවුන්ට ආරාධනා කළා"
#         },
#         {
#             "incorrect": "මම  දන්නවා ඔහුව",
#             "correct": "මම ඔහුව දන්නවා"
#         },
#         {
#             "incorrect": "ඇය  ඉගෙනගත්තා එය",
#             "correct": "ඇය එය ඉගෙනගත්තා"
#         },
#         {
#             "incorrect": "අපි  පිටවෙනවා දැන්",
#             "correct": "අපි දැන් පිටවෙනවා"
#         },
#         {
#             "incorrect": "ඔවුහු  කිව්වා බොරු",
#             "correct": "ඔවුහු  බොරු කිව්වා"
#         },
#         {
#             "incorrect": "මට  පුළුවන්  සවන්දෙන්න",
#             "correct": "මට  සවන්දෙන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කරගත්තා අහිමි ",
#             "correct": "ඇය  අහිමි කරගත්තා"
#         },
#         {
#             "incorrect": "අපි  සෑදුවා ඊයේ",
#             "correct": "අපි ඊයේ සෑදුවා"
#         },
#         {
#             "incorrect": "ඔවුන්  හමුවුනා ඔහුව",
#             "correct": "ඔවුන් ඔහුව හමුවුනා"
#         },
#         {
#             "incorrect": "මම  ලියනවා වැරදි",
#             "correct": "මම වැරදි ලියනවා"
#         },
#         {
#             "incorrect": "මම සැමවිටම කරනවා යාච්ඤා ",
#             "correct": "මම සැමවිටම යාච්ඤා කරනවා"
#         },
#         {
#             "incorrect": "ඇය  තෝරාගන්නවා එය",
#             "correct": "ඇය එය තෝරාගන්නවා"
#         },
#         {
#             "incorrect": "අපි  කළා ආරක්ෂා",
#             "correct": "අපි ආරක්ෂා කළා"
#         },
#         {
#             "incorrect": "ඔවුහු  කරාවි දඬුවම්",
#             "correct": "ඔවුහු දඬුවම් කරාවි"
#         },
#         {
#             "incorrect": "මට  පුළුවන් තියන්න",
#             "correct": "මට තියන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කියවනවා එය",
#             "correct": "ඇය එය කියවනවා"
#         },
#         {
#             "incorrect": "අපිට  ලැබුණා එය",
#             "correct": "අපිට එය ලැබුණා"
#         },
#         {
#             "incorrect": "ඔවුන්  කරනවා ප්‍රතික්ෂේප",
#             "correct": "ඔවුන් ප්‍රතික්ෂේප කරනවා"
#         },
#         {
#             "incorrect": "මට  මතකයි එය",
#             "correct": "මට එය මතකයි"
#         },
#         {
#             "incorrect": "නැවත  ඇය කියනවා",
#             "correct": "ඇය නැවත කියනවා"
#         },
#         {
#             "incorrect": "අපිට  පෙනෙනවා එය",
#             "correct": "අපිට එය පෙනෙනවා"
#         },
#         {
#             "incorrect": "එය ඔවුන් විකුණනවා",
#             "correct": "ඔවුන් එය විකුණනවා"
#         },
#         {
#             "incorrect": "මම යැව්වා  ඊයේ",
#             "correct": "මම ඊයේ යැව්වා"
#         },
#         {
#             "incorrect": "රැවුල  ඔහු බෑවා",
#             "correct": "ඔහු රැවුල බෑවා"
#         },
#         {
#             "incorrect": "අපි කළා ගායනා",
#             "correct": "අපි  ගායනා කළා"
#         },
#         {
#             "incorrect": "ඔවුන් ඉඳත්තා එතන ",
#             "correct": "ඔවුන් එතන ඉඳත්තා"
#         },
#         {
#             "incorrect": "මට පුළුවන් කියන්න",
#             "correct": "මට  කියන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කරනවා වියදම්",
#             "correct": "ඇය වියදම් කරනවා"
#         },
#         {
#             "incorrect": "අපි වින්ඳා දුක් ",
#             "correct": "අපි දුක් වින්ඳා"
#         },
#         {
#             "incorrect": "යෝජනා ඔවුන් කරනවා",
#             "correct": "ඔවුන් යෝජනා කරනවා"
#         },
#         {
#             "incorrect": "පුදුම මම කළා",
#             "correct": "මම පුදුම කළා"
#         },
#         {
#             "incorrect": "ඇය ගත්තා එය",
#             "correct": "ඇය එය ගත්තා"
#         },
#         {
#             "incorrect": "එය අපි උගන්වනවා",
#             "correct": "අපි එය උගන්වනවා"
#         },
#         {
#             "incorrect": "ඔවුන් කීව්වා අපට ",
#             "correct": "ඔවුන් අපට කීව්වා"
#         },
#         {
#             "incorrect": "ඇය කළා ස්තූති ",
#             "correct": "ඇය ස්තූති කළා"
#         },
#         {
#             "incorrect": "මට පුළුවන් සිතා බලන්න",
#             "correct": "මට සිතා බලන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා විසි ",
#             "correct": "ඇය විසි කළා"
#         },
#         {
#             "incorrect": "අපි  තේරුම්ගන්නවා එය",
#             "correct": "අපි එය තේරුම්ගන්නවා"
#         },
#         {
#             "incorrect": "එය ඔවුන්ට අවශ්‍යයි",
#             "correct": "ඔවුන්ට එය අවශ්‍යයි"
#         },
#         {
#             "incorrect": "මට පුළුවන් ඇඳපැළඳ ගන්න",
#             "correct": "මට  ඇඳපැළඳ ගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  ලියනවා එය",
#             "correct": "ඇය එය ලියනවා"
#         },
#         {
#             "incorrect": "අපි කරනවා කතා",
#             "correct": "අපි කතා කරනවා"
#         },
#         {
#             "incorrect": "එය ගාව ඔවුන්",
#             "correct": "එය ඔවුන් ගාව"
#         },
#         {
#             "incorrect": "මම නැරඹුවා එය ",
#             "correct": "මම එය නැරඹුවා"
#         },
#         {
#             "incorrect": "කතා මම කරාවි",
#             "correct": "මම කතා කරාවි"
#         },
#         {
#             "incorrect": "ඔහු ගත්තා  මිලට ",
#             "correct": "ඔහු මිලට ගත්තා"
#         },
#         {
#             "incorrect": "අපි කළා නිමා",
#             "correct": "අපි නිමා කළා"
#         },
#         {
#             "incorrect": "මට හැක පිළිගත",
#             "correct": "මට පිළිගත හැක"
#         },
#         {
#             "incorrect": "ඇය කළාය එකතු ",
#             "correct": "ඇය එකතු කළාය"
#         },
#         {
#             "incorrect": "අපි පිළිගනිමු එය ",
#             "correct": "අපි එය පිළිගනිමු"
#         },
#         {
#             "incorrect": "ඔවුහු දුන්නෝය උපදෙස් ",
#             "correct": "ඔවුහු උපදෙස් දුන්නෝය"
#         },
#         {
#             "incorrect": "මට වියහැක එකඟ ",
#             "correct": "මට එකඟ වියහැක"
#         },
#         {
#             "incorrect": "ඇය දෙයි ඉඩ",
#             "correct": "ඇය ඉඩ දෙයි"
#         },
#         {
#             "incorrect": "අපි කරමු නිවේදනය ",
#             "correct": "අපි නිවේදනය කරමු"
#         },
#         {
#             "incorrect": "මට ඉල්ලියහැක  සමාව",
#             "correct": "මට සමාව ඉල්ලියහැක"
#         },
#         {
#             "incorrect": "ඔවුහු  කළෝය පිළියෙළ",
#             "correct": "ඔවුහු පිළියෙළ කළෝය"
#         },
#         {
#             "incorrect": "මට ආහැක හෙට ",
#             "correct": "මට හෙට ආහැක"
#         },
#         {
#             "incorrect": "ඇයට හැක ඇසිය",
#             "correct": "ඇයට ඇසිය හැක"
#         },
#         {
#             "incorrect": "ඇය  අමුණයි එය",
#             "correct": "ඇය එය අමුණයි"
#         },
#         {
#             "incorrect": "අපි පහරදෙමු ඔවුන්ට ",
#             "correct": "අපි ඔවුන්ට පහරදෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු මඟහැරියෝය ඇයව",
#             "correct": "ඔවුහු ඇයව මඟහැරියෝය"
#         },
#         {
#             "incorrect": "පිසිය මට හැක",
#             "correct": "මට පිසිය හැක"
#         },
#         {
#             "incorrect": "ඇය වැනිය ඔහු ",
#             "correct": "ඇය ඔහු වැනිය"
#         },
#         {
#             "incorrect": "අපි  කරමු පරාජය",
#             "correct": "අපි පරාජය කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු පත්විය  සතුටට ",
#             "correct": "ඔවුහු සතුටට පත්විය"
#         },
#         {
#             "incorrect": "මට හැක ඇරඹිය",
#             "correct": "මට ඇරඹිය හැක"
#         },
#         {
#             "incorrect": "ඔවුහු ගනිති හුස්ම ",
#             "correct": "ඔවුහු හුස්ම ගනිති"
#         },
#         {
#             "incorrect": "මට  හැක සෑදිය",
#             "correct": "මට සෑදිය හැක"
#         },
#         {
#             "incorrect": "ආහාර ඇය මිලට ගනියි",
#             "correct": "ඇය ආහාර මිලට ගනියි"
#         },
#         {
#             "incorrect": "ගණනය අපි කරමු",
#             "correct": "අපි ගණනය කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු  යති රැගෙන",
#             "correct": "ඔවුහු රැගෙන යති"
#         },
#         {
#             "incorrect": "ඔවුන්  නොකරයි වංචා",
#             "correct": "ඔවුන් වංචා නොකරයි"
#         },
#         {
#             "incorrect": "ඇය  තෝරයි ඔහුව",
#             "correct": "ඇය ඔහුව තෝරයි"
#         },
#         {
#             "incorrect": "අපි  වසමු එය",
#             "correct": "අපි එය වසමු"
#         },
#         {
#             "incorrect": "ඔහු එයි මෙහි",
#             "correct": "ඔහු මෙහි එයි"
#         },
#         {
#             "incorrect": "මට  හැක සැසඳිය",
#             "correct": "මට සැසඳිය හැක"
#         },
#         {
#             "incorrect": "ඇය කරයි  තරඟ ",
#             "correct": "ඇය තරඟ කරයි"
#         },
#         {
#             "incorrect": "අපි  කරමු පැමිණිලි",
#             "correct": "අපි පැමිණිලි කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු  කළෝය දිගටම",
#             "correct": "ඔවුහු දිගටම කළෝය"
#         },
#         {
#             "incorrect": "දිගටම ඔහු ඇඬුවේය",
#             "correct": "ඔහු දිගටම ඇඬුවේය"
#         },
#         {
#             "incorrect": "ඇය කළාය විස්තර",
#             "correct": "ඇය විස්තර කළාය"
#         },
#         {
#             "incorrect": "අපි නොවීමු එකඟ",
#             "correct": "අපි එකඟ නොවීමු"
#         },
#         {
#             "incorrect": "ඔවුහු විය අතුරුදහන්",
#             "correct": "ඔවුහු අතුරුදහන් විය"
#         },
#         {
#             "incorrect": "එය මම සොයාගත්තෙමි",
#             "correct": "මම එය සොයාගත්තෙමි"
#         },
#         {
#             "incorrect": "ඇය අකැමතියි එයට",
#             "correct": "ඇය එයට අකැමතියි"
#         },
#         {
#             "incorrect": "අපි කරමු එය",
#             "correct": "අපි එය කරමු"
#         },
#         {
#             "incorrect": "ඔවුන් දකිති සිහින",
#             "correct": "ඔවුන් සිහින දකිති"
#         },
#         {
#             "incorrect": "මම උපයමි මුදල්",
#             "correct": "මම මුදල් උපයමි"
#         },
#         {
#             "incorrect": "ඔහු කයි සෑහෙන්න",
#             "correct": "ඔහු සෑහෙන්න කයි"
#         },
#         {
#             "incorrect": "අපි රසවින්ඳෙමු එය",
#             "correct": "අපි එය රසවින්ඳෙමු"
#         },
#         {
#             "incorrect": "ඔවුන් ආවෝය මෙහි ",
#             "correct": "ඔවුන් මෙහි ආවෝය"
#         },
#         {
#             "incorrect": "ඔහු ගියේය පළා",
#             "correct": "ඔහු පළා ගියේය"
#         },
#         {
#             "incorrect": "මට කළහැක පැහැදිලි ",
#             "correct": "මට පැහැදිලි කළහැක"
#         },
#         {
#             "incorrect": "ඇයට හැඟෙයි එය ",
#             "correct": "ඇයට එය හැඟෙයි"
#         },
#         {
#             "incorrect": "අපි ගියෙමු පළා ",
#             "correct": "අපි පළා ගියෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු වන්නෝය ගුවන්ගත ",
#             "correct": "ඔවුහු ගුවන්ගත වන්නෝය"
#         },
#         {
#             "incorrect": "මට කළහැක අනුගමනය ",
#             "correct": "මට අනුගමනය කළහැක"
#         },
#         {
#             "incorrect": "ඇය කළාය අමතක ",
#             "correct": "ඇය අමතක කළාය"
#         },
#         {
#             "incorrect": "අපි දෙමු සමාව ",
#             "correct": "අපි සමාව දෙමු"
#         },
#         {
#             "incorrect": "ඇය යයි එහෙ ",
#             "correct": "ඇය  එහෙ යයි"
#         },
#         {
#             "incorrect": "ආයුබෝවන් අපි කීවෙමු",
#             "correct": "අපි ආයුබෝවන් කීවෙමු"
#         },
#         {
#             "incorrect": "මම කරමි පිළිකුල් ",
#             "correct": "මම පිළිකුල් කරමි"
#         },
#         {
#             "incorrect": "මට ඇසෙයි එය ",
#             "correct": "මට එය ඇසෙයි"
#         },
#         {
#             "incorrect": "ඇය ගනියි  මවා ",
#             "correct": "ඇය මවා ගනියි"
#         },
#         {
#             "incorrect": "අපි කළෙමු ආරාධනා ",
#             "correct": "අපි ආරාධනා කළෙමු"
#         },
#         {
#             "incorrect": "මම දනිමි  ඔහුව ",
#             "correct": "මම ඔහුව දනිමි"
#         },
#         {
#             "incorrect": "ඇය ගත්තාය ඉගෙන ",
#             "correct": "ඇය ඉගෙන ගත්තාය"
#         },
#         {
#             "incorrect": "අපි පිටවෙමු දැන් ",
#             "correct": "අපි දැන් පිටවෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කීවෝය බොරු ",
#             "correct": "ඔවුහු බොරු කීවෝය"
#         },
#         {
#             "incorrect": "මට හැක සවන්දිය ",
#             "correct": "මට සවන්දිය හැක"
#         },
#         {
#             "incorrect": "ඇය කරගත්තාය අහිමි ",
#             "correct": "ඇය අහිමි කරගත්තාය"
#         },
#         {
#             "incorrect": "අපි සෑදුවෙමු එය ",
#             "correct": "අපි එය සෑදුවෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු හමුවූවෝය ඔහුව ",
#             "correct": "ඔවුහු ඔහුව හමුවූවෝය"
#         },
#         {
#             "incorrect": "මම ලෙස ලියමි වැරදි ",
#             "correct": "මම වැරදි ලෙස ලියමි"
#         },
#         {
#             "incorrect": "මම කරමි  යාච්ඤා ",
#             "correct": "මම යාච්ඤා කරමි"
#         },
#         {
#             "incorrect": "ඇය තෝරාගනියි එය ",
#             "correct": "ඇය එය තෝරාගනියි"
#         },
#         {
#             "incorrect": "අපි කළෙමු  ආරක්ෂා ",
#             "correct": "අපි ආරක්ෂා කළෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කරයි දඬුවම්",
#             "correct": "ඔවුහු දඬුවම් කරයි"
#         },
#         {
#             "incorrect": "මට හැක  තැබිය ",
#             "correct": "මට තැබිය හැක"
#         },
#         {
#             "incorrect": "ඇය කියවයි එය ",
#             "correct": "ඇය එය කියවයි"
#         },
#         {
#             "incorrect": "අපිට ලැබුණි එය ",
#             "correct": "අපිට එය ලැබුණි"
#         },
#         {
#             "incorrect": "ඔවුහු කරති  ප්‍රතික්ෂේප ",
#             "correct": "ඔවුහු ප්‍රතික්ෂේප කරති"
#         },
#         {
#             "incorrect": "මට මතකයි එය ",
#             "correct": "මට එය මතකයි"
#         },
#         {
#             "incorrect": "ඇය කියයි නැවත ",
#             "correct": "ඇය නැවත කියයි"
#         },
#         {
#             "incorrect": "අපිට පෙනෙයි එය ",
#             "correct": "අපිට එය පෙනෙයි"
#         },
#         {
#             "incorrect": "ඔවුන් විකුණති  එය ",
#             "correct": "ඔවුන් එය විකුණති"
#         },
#         {
#             "incorrect": "මම යැව්වෙමි ඊයේ ",
#             "correct": "මම ඊයේ යැව්වෙමි"
#         },
#         {
#             "incorrect": "ඔහු බෑවේය රැවුල ",
#             "correct": "ඔහු රැවුල බෑවේය"
#         },
#         {
#             "incorrect": "එය ඇකිළුනේය සැණින් ",
#             "correct": "එය සැණින් ඇකිළුනේය"
#         },
#         {
#             "incorrect": "අපි කරන්නෙමු ගායනා ",
#             "correct": "අපි ගායනා කරන්නෙමු"
#         },
#         {
#             "incorrect": "ඔවුන් ඉඳත්තෝය එතන ",
#             "correct": "ඔවුන් එතන ඉඳත්තෝය"
#         },
#         {
#             "incorrect": "මට හැක කිව ",
#             "correct": "මට කිව හැක"
#         },
#         {
#             "incorrect": "ඇය කරයි වියදම් ",
#             "correct": "ඇය වියදම් කරයි"
#         },
#         {
#             "incorrect": "අපි  වින්ඳෙමු දුක්",
#             "correct": "අපි දුක් වින්ඳෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කරති යෝජනා ",
#             "correct": "ඔවුහු යෝජනා කරති"
#         },
#         {
#             "incorrect": "මම කළෙමි පුදුම ",
#             "correct": "මම පුදුම කළෙමි"
#         },
#         {
#             "incorrect": "ඇය ගත්තාය එය ",
#             "correct": "ඇය එය ගත්තාය"
#         },
#         {
#             "incorrect": "අපි උගන්වමු එය ",
#             "correct": "අපි එය උගන්වමු"
#         },
#         {
#             "incorrect": "අපට ඔවුන් කීවෝය",
#             "correct": "ඔවුන් අපට කීවෝය"
#         },
#         {
#             "incorrect": "ස්තූතියි ඇය කළාය",
#             "correct": "ඇය ස්තූතියි කළාය"
#         },
#         {
#             "incorrect": "සිතා මට බැලියහැක",
#             "correct": "මට සිතා බැලියහැක"
#         },
#         {
#             "incorrect": "විසි  ඇය කළාය",
#             "correct": "ඇය විසි කළාය"
#         },
#         {
#             "incorrect": "එය  අපි තේරුම්ගනිමු",
#             "correct": "අපි එය තේරුම්ගනිමු"
#         },
#         {
#             "incorrect": "ඔවුන්ට අවශ්‍යයි එය ",
#             "correct": "ඔවුන්ට එය අවශ්‍යයි"
#         },
#         {
#             "incorrect": "මට ගතහැක ඇඳපැළඳ ",
#             "correct": "මට ඇඳපැළඳ ගතහැක"
#         },
#         {
#             "incorrect": "එය  ඇය ලියයි",
#             "correct": "ඇය එය ලියයි"
#         },
#         {
#             "incorrect": "අපි කරමු කතා ",
#             "correct": "අපි කතා කරමු"
#         },
#         {
#             "incorrect": "එය සතුයි ඔවුන් ",
#             "correct": "එය ඔවුන් සතුයි"
#         },
#         {
#             "incorrect": "එය  මම නැරඹුවෙමි",
#             "correct": "මම එය නැරඹුවෙමි"
#         },
#         {
#             "incorrect": "කතා  මම කරන්නෙමි",
#             "correct": "මම කතා කරන්නෙමි"
#         },
#         {
#             "incorrect": "ඔහු ගත්තේය මිලට ",
#             "correct": "ඔහු මිලට ගත්තේය"
#         },
#         {
#             "incorrect": "අපි කළෙමු නිමා ",
#             "correct": "අපි නිමා කළෙමු"
#         },
#         {
#             "incorrect": "යන්නෙ ඔහු කොහිද?",
#             "correct": "ඔහු යන්නෙ කොහිද?"
#         },
#         {
#             "incorrect": "දුක්වන්නේ ඔබ ඇයි?",
#             "correct": "ඔබ දුක්වන්නේ ඇයි?"
#         },
#         {
#             "incorrect": "කැමති ඔබ කොහොමද?",
#             "correct": "ඔබ කැමති කොහොමද?"
#         },
#         {
#             "incorrect": "කොතරම් එය විශාලද?",
#             "correct": "එය කොතරම් විශාලද?"
#         },
#         {
#             "incorrect": "ඔහු නොමැත මෙහි ",
#             "correct": "ඔහු මෙහි නොමැත"
#         },
#         {
#             "incorrect": "මෙය නොවෙයි මගේ ",
#             "correct": "මෙය මගේ නොවෙයි"
#         },
#         {
#             "incorrect": "මම නොකරමි කතා ",
#             "correct": "මම කතා නොකරමි"
#         },
#         {
#             "incorrect": "මම නොලියමි පොත ",
#             "correct": "මම පොත නොලියමි"
#         },
#         {
#             "incorrect": "රිය  මම නොපදවමි",
#             "correct": "මම රිය නොපදවමි"
#         },
#         {
#             "incorrect": "ආදරය  මම නොකරමි",
#             "correct": "මම ආදරය නොකරමි"
#         },
#         {
#             "incorrect": "පොත මම නොදෙමි",
#             "correct": "මම පොත නොදෙමි"
#         },
#         {
#             "incorrect": "මම නොවෙමි සිනා ",
#             "correct": "මම සිනා නොවෙමි"
#         },
#         {
#             "incorrect": "මම නොගනිමි පොත ",
#             "correct": "මම පොත නොගනිමි"
#         },
#         {
#             "incorrect": "කතා ඔහු නොකරයි",
#             "correct": "ඔහු කතා නොකරයි"
#         },
#         {
#             "incorrect": "පොත මහු නොලියයි",
#             "correct": "මහු පොත නොලියයි"
#         },
#         {
#             "incorrect": "ඔහු නොපදවයි රිය ",
#             "correct": "ඔහු රිය නොපදවයි"
#         },
#         {
#             "incorrect": "ආදරය ඔහු නොකරයි",
#             "correct": "ඔහු ආදරය නොකරයි"
#         },
#         {
#             "incorrect": "පොත ඔහු නොදෙයි",
#             "correct": "ඔහු පොත නොදෙයි"
#         },
#         {
#             "incorrect": "සිනා ඔහු නොවෙයි",
#             "correct": "ඔහු සිනා නොවෙයි"
#         },
#         {
#             "incorrect": "ඔහු නොගනියි පොත ",
#             "correct": "ඔහු පොත නොගනියි"
#         },
#         {
#             "incorrect": "අපි නොකරමු කතා ",
#             "correct": "අපි කතා නොකරමු"
#         },
#         {
#             "incorrect": "පොත අපි නොලියමු",
#             "correct": "අපි පොත නොලියමු"
#         },
#         {
#             "incorrect": "අපි නොපදවමු රිය ",
#             "correct": "අපි රිය නොපදවමු"
#         },
#         {
#             "incorrect": "ආදරය අපි නොකරමු",
#             "correct": "අපි ආදරය නොකරමු"
#         },
#         {
#             "incorrect": "අපි නොදෙමු පොත ",
#             "correct": "අපි පොත නොදෙමු"
#         },
#         {
#             "incorrect": "සිනා අපි නොවෙමු",
#             "correct": "අපි සිනා නොවෙමු"
#         },
#         {
#             "incorrect": "මම කරමි කතා ",
#             "correct": "මම කතා කරමි"
#         },
#         {
#             "incorrect": "කතා ඔබ කරන්නෙහි",
#             "correct": "ඔබ කතා කරන්නෙහි"
#         },
#         {
#             "incorrect": "ඔහු කරයි කතා ",
#             "correct": "ඔහු කතා කරයි"
#         },
#         {
#             "incorrect": "කතා ඇය කරයි",
#             "correct": "ඇය කතා කරයි"
#         },
#         {
#             "incorrect": "අපි කරමු කතා ",
#             "correct": "අපි කතා කරමු"
#         },
#         {
#             "incorrect": "කතා ඔවුහු කරති",
#             "correct": "ඔවුහු කතා කරති"
#         },
#         {
#             "incorrect": "ගණන් මේක වැඩියි",
#             "correct": "මේක ගණන් වැඩියි"
#         },
#         {
#             "incorrect": "මෙහෙට ඔයා කැමතිද?",
#             "correct": "ඔයා මෙහෙට කැමතිද?"
#         },
#         {
#             "incorrect": "යන්නෙ මම කොහොමද?",
#             "correct": "මම යන්නෙ කොහොමද?"
#         },
#         {
#             "incorrect": "ප්‍රශ්නයක් මට  තියෙනවා ",
#             "correct": "මට ප්‍රශ්නයක් තියෙනවා "
#         },
#         {
#             "incorrect": "කරුණාකර කියන්න මට ",
#             "correct": "කරුණාකර මට කියන්න"
#         },
#         {
#             "incorrect": "මම කථා නැහැ කරන්නේ",
#             "correct": "මම කථා කරන්නේ නැහැ "
#         },
#         {
#             "incorrect": "මම  නැහැ ගන්නේ",
#             "correct": "මම ගන්නේ නැහැ "
#         },
#         {
#             "incorrect": "නැවත ඒක කියන්න ",
#             "correct": "ඒක නැවත කියන්න "
#         },
#         {
#             "incorrect": "මට  අවශ්‍යයි තොරතුරු",
#             "correct": "මට තොරතුරු අවශ්‍යයි "
#         },
#         {
#             "incorrect": "කාමර ඔබට තිබේද? ",
#             "correct": "ඔබට කාමර තිබේද? "
#         },
#         {
#             "incorrect": "කෑම උදෑසන ඇතුළත්ද? ",
#             "correct": "උදෑසන කෑම ඇතුළත්ද? "
#         },
#         {
#             "incorrect": "කාමරයක් මට ඕනේ ",
#             "correct": "මට කාමරයක් ඕනේ "
#         },
#         {
#             "incorrect": "මට ඕනේ කාමරයක් ",
#             "correct": "මට කාමරයක් ඕනේ "
#         },
#         {
#             "incorrect": "යන්ත්‍රය උකස් කොහේද? ",
#             "correct": "උකස් යන්ත්‍රය කොහේද? "
#         },
#         {
#             "incorrect": "කරගන්න කාමරයක් බුක් ඕනේ ",
#             "correct": "කාමරයක් බුක් කරගන්න ඕනේ "
#         },
#         {
#             "incorrect": "ආරක්ෂිතව මම සිටිනවා ",
#             "correct": "මම ආරක්ෂිතව සිටිනවා "
#         },
#         {
#             "incorrect": "උදේ ඇහැරවන්න මාව ",
#             "correct": "උදේ මාව ඇහැරවන්න "
#         },
#         {
#             "incorrect": "බිළිඳුන්ට ඕනේ කූඩයක් ",
#             "correct": "බිළිඳුන්ට කූඩයක් ඕනේ "
#         },
#         {
#             "incorrect": "මිල වට්ටමේ කීයද?",
#             "correct": "වට්ටමේ මිල කීයද?"
#         },
#         {
#             "incorrect": "එය මිලයි වැඩි ",
#             "correct": "එය වැඩි මිලයි"
#         },
#         {
#             "incorrect": "වර්ණයක් මෙයට තිබේද? ",
#             "correct": "මෙයට  වර්ණයක් තිබේද? "
#         },
#         {
#             "incorrect": "මම ඕන දෙන්න  ",
#             "correct": "මම දෙන්න ඕන "
#         },
#         {
#             "incorrect": "ඇලර්ජියක් මට තියෙනවා ",
#             "correct": "මට ඇලර්ජියක් තියෙනවා "
#         },
#         {
#             "incorrect": "මේකට මම කැමතියි ",
#             "correct": "මම මේකට කැමතියි "
#         },
#         {
#             "incorrect": "යන්න මට ඕන",
#             "correct": "මට යන්න ඕන"
#         },
#         {
#             "incorrect": "මගේ  සුදුයි බල්ලා",
#             "correct": "මගේ බල්ලා සුදුයි"
#         },
#         {
#             "incorrect": "කඩේ එයාලා යනවා",
#             "correct": "එයාලා කඩේ යනවා"
#         },
#         {
#             "incorrect": "මේ වහිනවා වෙලාවේ ",
#             "correct": "මේ වෙලාවේ වහිනවා"
#         },
#         {
#             "incorrect": "වැනිලා මම වලට කැමතියි",
#             "correct": "මම වැනිලා වලට කැමතියි"
#         },
#         {
#             "incorrect": "ඉර දිලිසෙනවා එළියෙන් ",
#             "correct": "ඉර එළියෙන් දිලිසෙනවා"
#         },
#         {
#             "incorrect": "අයිස් මම වලට කැමතියි",
#             "correct": "මම අයිස් වලට කැමතියි"
#         },
#         {
#             "incorrect": "මට ඉන්නවා බල්ලෙක්",
#             "correct": "මට බල්ලෙක් ඉන්නවා "
#         },
#         {
#             "incorrect": "අපි නගරයේ නිව්යෝර්ක් ",
#             "correct": "අපි නිව්යෝර්ක් නගරයේ"
#         },
#         {
#             "incorrect": "කලිසමක් ඔහු කළු ඇඳ ගෙන සිටී",
#             "correct": "ඔහු කළු කලිසමක් ඇඳ ගෙන සිටී"
#         },
#         {
#             "incorrect": "උද්යානයට ඔවුන් ගියා",
#             "correct": "ඔවුන් උද්යානයට ගියා"
#         },
#         {
#             "incorrect": "යාළුවෝ එක්ක කරන්න සෙල්ලම්",
#             "correct": "යාළුවෝ එක්ක සෙල්ලම් කරන්න"
#         },
#         {
#             "incorrect": "යහන මත නිදාසිටී බළලා",
#             "correct": "බළලා යහන මත නිදාසිටී"
#         },
#         {
#             "incorrect": "බල්ලා පනිනවා තටාකයට",
#             "correct": "බල්ලා තටාකයට පනිනවා"
#         },
#         {
#             "incorrect": "කැමති මම කෑමකට",
#             "correct": "මම කැමති කෑමකට"
#         },
#         {
#             "incorrect": "අම්මා ආදරෙයි ගොඩක් ",
#             "correct": "අම්මා ගොඩක් ආදරෙයි"
#         },
#         {
#             "incorrect": "මම කරනවා වැඩ ",
#             "correct": "මම වැඩ කරනවා"
#         },
#         {
#             "incorrect": "මම  ගියා කඩේට",
#             "correct": "මම කඩේට ගියා"
#         },
#         {
#             "incorrect": "මගේ නම ස්මිත් ජෝන් ",
#             "correct": "මගේ නම ජෝන් ස්මිත්"
#         },
#         {
#             "incorrect": "අද රස්නෙයි ඉර ",
#             "correct": "අද ඉර රස්නෙයි"
#         },
#         {
#             "incorrect": "ගෙයක් අපිට තියෙනවා",
#             "correct": "අපිට ගෙයක් තියෙනවා"
#         },
#         {
#             "incorrect": "අපි  ඩ්රයිව්කලා රෑම",
#             "correct": "අපි රෑම ඩ්රයිව්කලා"
#         },
#         {
#             "incorrect": "ආයෙත් ඔයා පරක්කුයි",
#             "correct": "ඔයා ආයෙත් පරක්කුයි"
#         },
#         {
#             "incorrect": "බල්ලා විය බුරන්නට ",
#             "correct": "බල්ලා බුරන්නට විය"
#         },
#         {
#             "incorrect": "වටේ බල්ලා දිව්වා",
#             "correct": "බල්ලා වටේ දිව්වා"
#         },
#         {
#             "incorrect": "පූසා  කෑගැහුවා හයියෙන්",
#             "correct": "පූසා හයියෙන් කෑගැහුවා"
#         },
#         {
#             "incorrect": "අයියා ආසයි කන්න සැන්ඩ්විච් ",
#             "correct": "අයියා ආසයි සැන්ඩ්විච් කන්න"
#         },
#         {
#             "incorrect": "මම  යන්න ආසයි සාලෙට",
#             "correct": "මම ආසයි සාලෙට යන්න"
#         },
#         {
#             "incorrect": "හරිම ආසයි ආච්චි කේක් හදන්න ",
#             "correct": "ආච්චි කේක් හදන්න හරිම ආසයි"
#         },
#         {
#             "incorrect": "සීයා නිවස වටා සවි කිරීමට ආසයි  ඇති දේවල්",
#             "correct": "සීයා නිවස වටා ඇති දේවල් සවි කිරීමට ආසයි"
#         },
#         {
#             "incorrect": "එයාලට  සල්ලියක්නෑ කිසිම",
#             "correct": "එයාලට කිසිම සල්ලියක්නෑ"
#         },
#         {
#             "incorrect": "දීප්තිමත්ව හිරු  දිලිසෙනවා",
#             "correct": "හිරු දීප්තිමත්ව දිලිසෙනවා"
#         },
#         {
#             "incorrect": "මම  ආසයි කියවන්න",
#             "correct": "මම කියවන්න ආසයි"
#         },
#         {
#             "incorrect": "පියානෝවාදනයට ඇය  ආසයි",
#             "correct": "ඇය පියානෝවාදනයට ආසයි"
#         },
#         {
#             "incorrect": "ඉන්නේ එයාලා ගෙදරක",
#             "correct": "එයාලා ඉන්නේ ගෙදරක"
#         },
#         {
#             "incorrect": "බළලුන් දිව්වා  වටේ ",
#             "correct": "බළලුන් වටේ දිව්වා"
#         },
#         {
#             "incorrect": "මල් වසන්තයේදීය පිපෙන්නේ ",
#             "correct": "මල් පිපෙන්නේ වසන්තයේදීය"
#         },
#         {
#             "incorrect": "උදේට එයා දුවනවා",
#             "correct": "එයා උදේට දුවනවා"
#         },
#         {
#             "incorrect": "අපි  පීසා කෑවා රෑකෑමට",
#             "correct": "අපි රෑකෑමට පීසා කෑවා"
#         },
#         {
#             "incorrect": "හයියෙන් බල්ලා  බුරනවා",
#             "correct": "බල්ලා හයියෙන් බුරනවා"
#         },
#         {
#             "incorrect": "කුරුල්ලෝ කියනවා සින්දු ",
#             "correct": "කුරුල්ලෝ සින්දු කියනවා"
#         },
#         {
#             "incorrect": "ගලා ගංගාව යයි",
#             "correct": "ගංගාව ගලා යයි"
#         },
#         {
#             "incorrect": "මම තේ  ආසයි බොන්න",
#             "correct": "මම තේ බොන්න ආසයි"
#         },
#         {
#             "incorrect": "ඇය හැටි බලනවා ඉර බහින ",
#             "correct": "ඇය ඉර බහින හැටි බලනවා"
#         },
#         {
#             "incorrect": "ඔවුන් යනවා නිතර ",
#             "correct": "ඔවුන් නිතර යනවා"
#         },
#         {
#             "incorrect": "අද පිරිලා  රෑ හඳ",
#             "correct": "අද රෑ හඳ පිරිලා"
#         },
#         {
#             "incorrect": "සිල්ලරබඩු මට  ගන්න ඕන",
#             "correct": "මට සිල්ලරබඩු ගන්න ඕන"
#         },
#         {
#             "incorrect": "එයා කරන්නෙ වැඩ ",
#             "correct": "එයා වැඩ කරන්නෙ "
#         },
#         {
#             "incorrect": "අපි වැව්වා වත්තක්",
#             "correct": "අපි වත්තක් වැව්වා"
#         },
#         {
#             "incorrect": "කාර් නිල්පාටයි එක ",
#             "correct": "කාර් එක නිල්පාටයි"
#         },
#         {
#             "incorrect": "ඇය බේක්කරයි කුකීස්",
#             "correct": "ඇය කුකීස් බේක්කරයි"
#         },
#         {
#             "incorrect": "කුරුල්ලන් සාදයි කූඩු ",
#             "correct": "කුරුල්ලන් කූඩු සාදයි"
#         },
#         {
#             "incorrect": "ඔහු පුස්තකාලයේ ඉන්නේ ",
#             "correct": "ඔහු ඉන්නේ පුස්තකාලයේ"
#         },
#         {
#             "incorrect": "බබා වෙනවා හිනා ",
#             "correct": "බබා හිනා වෙනවා"
#         },
#         {
#             "incorrect": "ක්රීඩා ඔවුන් කරයි",
#             "correct": "ඔවුන් ක්රීඩා කරයි"
#         },
#         {
#             "incorrect": "කන්ද උසයි හරි ",
#             "correct": "කන්ද හරි උසයි"
#         },
#         {
#             "incorrect": "මට ඇහෙනවා මුහුද ",
#             "correct": "මට මුහුද ඇහෙනවා"
#         },
#         {
#             "incorrect": "ලියුමක් එයා ලිව්වා",
#             "correct": "එයා ලියුමක් ලිව්වා"
#         },
#         {
#             "incorrect": "අපි පැදුවා බයිසිකල් ",
#             "correct": "අපි බයිසිකල් පැදුවා"
#         },
#         {
#             "incorrect": "රත් කෝපි  වෙලා",
#             "correct": "කෝපි රත් වෙලා"
#         },
#         {
#             "incorrect": "ඔහු පිහිනයි  තටාකයේ ",
#             "correct": "ඔහු තටාකයේ පිහිනයි"
#         },
#         {
#             "incorrect": "හිම ශීතඍතුවේ වැටෙනවා",
#             "correct": "ශීතඍතුවේ හිම වැටෙනවා"
#         },
#         {
#             "incorrect": "ඔවුන් ගියා යුරෝපයට ",
#             "correct": "ඔවුන් යුරෝපයට ගියා"
#         },
#         {
#             "incorrect": "මම බැලුවා ෆිල්ම් ",
#             "correct": "මම ෆිල්ම් බැලුවා"
#         },
#         {
#             "incorrect": "ලස්සනට ඇය නටනවා",
#             "correct": "ඇය ලස්සනට නටනවා"
#         },
#         {
#             "incorrect": "දුරකථනය විය නාද ",
#             "correct": "දුරකථනය නාද විය"
#         },
#         {
#             "incorrect": "කඳුකරයේ අපි නැග්ගා",
#             "correct": "අපි කඳුකරයේ නැග්ගා"
#         },
#         {
#             "incorrect": "ගසෙහි ඇත කොළ ",
#             "correct": "ගසෙහි කොළ ඇත"
#         },
#         {
#             "incorrect": "උයන්න එයා ආසයි",
#             "correct": "එයා උයන්න ආසයි"
#         },
#         {
#             "incorrect": "සංක්රමණය කුරුල්ලන්  වේ",
#             "correct": "කුරුල්ලන් සංක්රමණය වේ"
#         },
#         {
#             "incorrect": "මට ඕනේ ජැකට් ",
#             "correct": "මට ජැකට් ඕනේ"
#         },
#         {
#             "incorrect": "ඇය ඇන්දා චිත්‍රරයක් ",
#             "correct": "ඇය චිත්‍රරයක් ඇන්දා "
#         },
#         {
#             "incorrect": "කල් තරඟය දැම්මා.",
#             "correct": "තරඟය කල් දැම්මා."
#         },
#         {
#             "incorrect": "හෙට වහිනවා දවසම ",
#             "correct": "හෙට දවසම වහිනවා"
#         },
#         {
#             "incorrect": "පාපන්දු ජේක් ක්‍රීඩාකළා",
#             "correct": "ජේක් පාපන්දු ක්‍රීඩාකළා"
#         },
#         {
#             "incorrect": "ෆිල්ම් සාරා බැලුවා",
#             "correct": "සාරා ෆිල්ම් බැලුවා"
#         },
#         {
#             "incorrect": "දවසම බළලා නිදාගත්තා",
#             "correct": "බළලා දවසම නිදාගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන් පිරිසිදුකළා  කාමරය ",
#             "correct": "ඔවුන් කාමරය පිරිසිදුකළා"
#         },
#         {
#             "incorrect": "කිචිබිචි කුරුල්ලා  ගාන්නට විය",
#             "correct": "කුරුල්ලා  කිචිබිචි ගාන්නට විය"
#         },
#         {
#             "incorrect": "ඔහු ගියේය බැලීමට ",
#             "correct": "ඔහු බැලීමට ගියේය"
#         },
#         {
#             "incorrect": "අවසන් ටිම් ආහාරය කළේය",
#             "correct": "ටිම් ආහාරය අවසන් කළේය"
#         },
#         {
#             "incorrect": "නතර විය මෝටර්රථය",
#             "correct": "මෝටර්රථය නතර විය"
#         },
#         {
#             "incorrect": "අපි දැක්කා දේදුන්නක්",
#             "correct": "අපි දේදුන්නක් දැක්කා"
#         },
#         {
#             "incorrect": "සාදයේදී නැටුවා සෑම් ",
#             "correct": "සාදයේදී සෑම් නැටුවා"
#         },
#         {
#             "incorrect": "ජැක් කළේය ක්‍රීඩා ",
#             "correct": "ජැක් ක්‍රීඩා කළේය"
#         },
#         {
#             "incorrect": "කුකීස් ලීසා පිළිස්සුවාය",
#             "correct": "ලීසා කුකීස් පිළිස්සුවාය"
#         },
#         {
#             "incorrect": "ටොම් ගියේය ඇවිද ",
#             "correct": "ටොම් ඇවිද ගියේය"
#         },
#         {
#             "incorrect": "නිවාඩුවට සාරා ගියාය",
#             "correct": "සාරා නිවාඩුවට ගියාය"
#         },
#         {
#             "incorrect": "චිත්‍රපටයක් අපි නැරඹුවෙමු",
#             "correct": "අපි චිත්‍රපටයක් නැරඹුවෙමු"
#         },
#         {
#             "incorrect": "ලුහුබැඳ බළලා ගියේය",
#             "correct": "බළලා ලුහුබැඳ ගියේය"
#         },
#         {
#             "incorrect": "පින්තාරු පින්තූරයක්  කළා",
#             "correct": "පින්තූරයක් පින්තාරු කළා"
#         },
#         {
#             "incorrect": "කුස්සිය ඇලෙක්ස්  පිරිසිදු කළේය",
#             "correct": "ඇලෙක්ස් කුස්සිය පිරිසිදු කළේය"
#         },
#         {
#             "incorrect": "බැස හිරු ගියේය",
#             "correct": "හිරු බැස ගියේය"
#         },
#         {
#             "incorrect": "ඉගෙන සිසු ගත්හ",
#             "correct": "සිසු ඉගෙන ගත්හ"
#         },
#         {
#             "incorrect": "ඉස්කෝලේ ජේක් ගියේය",
#             "correct": "ජේක් ඉස්කෝලේ ගියේය"
#         },
#         {
#             "incorrect": "ප්‍රසංගයේදී ලුසී නැටුවාය",
#             "correct": "ලුසී ප්‍රසංගයේදී නැටුවාය"
#         },
#         {
#             "incorrect": "ඔවුන් ඉදිකළහ වැලිමාලිගාවක්",
#             "correct": "ඔවුන් වැලිමාලිගාවක් ඉදිකළහ"
#         },
#         {
#             "incorrect": "අපි  නැරඹුවෙමු චිත්‍රපටයක්",
#             "correct": "අපි චිත්‍රපටයක් නැරඹුවෙමු"
#         },
#         {
#             "incorrect": "චාරිකාවක් අපි යනවා",
#             "correct": "අපි චාරිකාවක් යනවා"
#         },
#         {
#             "incorrect": "වැස්ස විය නතර ",
#             "correct": "වැස්ස නතර විය"
#         },
#         {
#             "incorrect": "මිතුරිය සමන්තා ඇමතුවාය",
#             "correct": "සමන්තා මිතුරිය ඇමතුවාය"
#         },
#         {
#             "incorrect": "මැක්ස්  ගියා ගමනක්",
#             "correct": "මැක්ස් ගමනක් ගියා"
#         },
#         {
#             "incorrect": "එක බයික් හදන්න",
#             "correct": "බයික් එක හදන්න"
#         },
#         {
#             "incorrect": "ටයර්  හදන්න එක",
#             "correct": "ටයර් එක හදන්න"
#         },
#         {
#             "incorrect": "ගුරුවරයා කියෙව්වා කතාවක් ",
#             "correct": "ගුරුවරයා කතාවක් කියෙව්වා"
#         },
#         {
#             "incorrect": "ක්‍රීඩා මයික් කළේය",
#             "correct": "මයික් ක්‍රීඩා කළේය"
#         },
#         {
#             "incorrect": "ඇමී දුටුවේය සතුන්",
#             "correct": "ඇමී සතුන් දුටුවේය"
#         },
#         {
#             "incorrect": "ජේසන් නැග්ගා කන්ද ",
#             "correct": "ජේසන් කන්ද නැග්ගා"
#         },
#         {
#             "incorrect": "කන්ද ජේසන් නැග්ගාද?",
#             "correct": "ජේසන් කන්ද නැග්ගාද?"
#         },
#         {
#             "incorrect": "මම නැග්ගේමි කන්ද ",
#             "correct": "මම කන්ද නැග්ගේමි"
#         },
#         {
#             "incorrect": "එක කාටූන් මොකක්ද?",
#             "correct": "කාටූන් එක මොකක්ද?"
#         },
#         {
#             "incorrect": "අත්පුඩි බබා ගැහුවා",
#             "correct": "බබා අත්පුඩි ගැහුවා"
#         },
#         {
#             "incorrect": "බල්ලා  ගියේය දිව",
#             "correct": "බල්ලා දිව ගියේය"
#         },
#         {
#             "incorrect": "අල්ලා පන්දුව ගත්තද?",
#             "correct": "පන්දුව අල්ලා  ගත්තද?"
#         },
#         {
#             "incorrect": "ලීසා කළාය උදව් ",
#             "correct": "ලීසා උදව් කළාය"
#         },
#         {
#             "incorrect": "මේකට බල්ලා කැමතිද?",
#             "correct": "බල්ලා මේකට කැමතිද?"
#         },
#         {
#             "incorrect": "කතාවට ගුරුවරයා කැමතිද? ",
#             "correct": "ගුරුවරයා කතාවට කැමතිද? "
#         },
#         {
#             "incorrect": "ටිම්ට හැරුනා මග ",
#             "correct": "ටිම්ට මග හැරුනා"
#         },
#         {
#             "incorrect": "මල් ලස්සනට වසන්තයේ පිපෙනවා",
#             "correct": "වසන්තයේ මල් ලස්සනට පිපෙනවා"
#         },
#         {
#             "incorrect": "උපන්දිනය සාරා සැමරුවාය ",
#             "correct": "සාරා උපන්දිනය සැමරුවාය "
#         },
#         {
#             "incorrect": "අපි වෙමු පුදුම ",
#             "correct": "අපි පුදුම වෙමු"
#         },
#         {
#             "incorrect": "ලිපියක් සාරා ලිව්වාය",
#             "correct": "සාරා ලිපියක් ලිව්වාය"
#         },
#         {
#             "incorrect": "පෙට්ටියක් ළමයා සොයා ගත්තේය",
#             "correct": "ළමයා පෙට්ටියක් සොයා ගත්තේය"
#         },
#         {
#             "incorrect": "නිධන් අපි සොයා ගත්තෙමු ",
#             "correct": "අපි නිධන් සොයා ගත්තෙමු "
#         },
#         {
#             "incorrect": "දියඇල්ලක් අපි සොයා ගත්තෙමු",
#             "correct": "අපි දියඇල්ලක් සොයා ගත්තෙමු"
#         },
#         {
#             "incorrect": "පුවරුක්‍රීඩා ඔවුහු කළහ",
#             "correct": "ඔවුහු පුවරුක්‍රීඩා කළහ"
#         }
#     ],
#     "pronoun_ending_match": [
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "ු,"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "නෑ"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ඳා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "අපි",
#             "end": "ඳා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ැත"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "හැ"
#         },
#         {
#             "start": "මම",
#             "end": "හැ"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "ඕන"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "අපි",
#             "end": "යේ"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "යා"
#         },
#         {
#             "start": "අපි",
#             "end": "ලා"
#         },
#         {
#             "start": "මම",
#             "end": "්න"
#         },
#         {
#             "start": "මම",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යේ"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "කා"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         }
#     ],
#     "verb_conjugation": [
#         {
#             "incorrect": "සරුංගලය",
#             "correct": "හැඩයි"
#         },
#         {
#             "incorrect": "නිවේදනය",
#             "correct": "කරයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "මතකයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "අමුණයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "හැඟෙයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "ඇසෙයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "තෝරාගනියි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "කියවයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "මතකයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "පෙනෙයි"
#         },
#         {
#             "incorrect": "ඇය",
#             "correct": "ස්තූතියි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "අවශ්‍යයි"
#         },
#         {
#             "incorrect": "රිය",
#             "correct": "නොපදවයි"
#         }
#     ]
# }
# Original Sentence: අපි පොතක් කියවම .
# Corrected Sentence: අපි පොතක් කියවම ු,

# %%
import json

# RuleExtractor class (already provided by you)
class RuleExtractor:
    def __init__(self, correct_sentences, incorrect_sentences):
        self.correct_sentences = correct_sentences
        self.incorrect_sentences = incorrect_sentences

    def extract_rules(self):
        rules = {
            "subject_verb_order": [],
            "pronoun_ending_match": [],
            "verb_conjugation": []  # New category
        }

        for correct, incorrect in zip(self.correct_sentences, self.incorrect_sentences):
            if correct != incorrect:
                correct_words = correct.split()
                incorrect_words = incorrect.split()

                # Subject-Verb order rule
                if sorted(correct_words) == sorted(incorrect_words):
                    rules["subject_verb_order"].append({
                        "incorrect": incorrect,
                        "correct": correct
                    })

                # Pronoun-ending match rule
                if len(correct_words) > 1 and len(incorrect_words) > 1:
                    pronoun = correct_words[0]
                    correct_ending = correct_words[-1][-2:]
                    incorrect_ending = incorrect_words[-1][-2:]
                    if pronoun in ["මම", "අපි", "ඔහු"] and correct_ending != incorrect_ending:
                        rules["pronoun_ending_match"].append({
                            "start": pronoun,
                            "end": correct_ending
                        })

                # Verb conjugation rule
                if len(correct_words) == len(incorrect_words):
                    for cw, iw in zip(correct_words, incorrect_words):
                        if cw != iw and cw.endswith("යි") and iw.endswith("ය"):
                            rules["verb_conjugation"].append({
                                "incorrect": iw,
                                "correct": cw
                            })

        # Save rules to a JSON file
        with open(".extracted_rules.json", "w", encoding="utf-8") as file:
            json.dump(rules, file, ensure_ascii=False, indent=4)

        return rules


# Load sentences from files
with open('incorrectSentences.txt', 'r', encoding='utf-8') as f:
    incorrect_sentences = f.read().splitlines()

with open('correctSentences.txt', 'r', encoding='utf-8') as f:
    correct_sentences = f.read().splitlines()

# Initialize RuleExtractor
extractor = RuleExtractor(correct_sentences, incorrect_sentences)

# Extract rules
rules = extractor.extract_rules()
print("Extracted Rules:")
print(json.dumps(rules, ensure_ascii=False, indent=4))

# Example: Apply extracted rules
def apply_rules(sentence, rules):
    # Apply subject-verb order rules
    for rule in rules["subject_verb_order"]:
        if sentence == rule["incorrect"]:
            return rule["correct"]

    # Apply pronoun-ending match rules
    words = sentence.split()
    if len(words) > 1:
        pronoun = words[0]
        if pronoun in ["මම", "අපි", "ඔහු"]:
            correct_end = next(
                (r["end"] for r in rules["pronoun_ending_match"] if r["start"] == pronoun),
                None
            )
            if correct_end and not words[-1].endswith(correct_end):
                words[-1] = words[-1][:-2] + correct_end
                return " ".join(words)

    # Apply verb conjugation rules
    for rule in rules["verb_conjugation"]:
        if rule["incorrect"] in sentence:
            return sentence.replace(rule["incorrect"], rule["correct"])

    return sentence
def calculate_accuracy(correct_sentences, incorrect_sentences, rules):
    """
    Calculate the accuracy of rule-based correction.
    Compares the corrected sentences to the correct ones.
    """
    total_sentences = len(correct_sentences)
    correct_count = 0

    for correct, incorrect in zip(correct_sentences, incorrect_sentences):
        corrected_sentence = apply_rules(incorrect, rules)
        if corrected_sentence == correct:
            correct_count += 1

    accuracy = (correct_count / total_sentences) * 100
    return accuracy


# Calculate accuracy
accuracy = calculate_accuracy(correct_sentences, incorrect_sentences, rules)
print(f"Accuracy of the rule-based correction system: {accuracy:.2f}%")

# Example usage
example_sentence = "පාසැල් දරුවා  ගියේය"
corrected_sentence = apply_rules(example_sentence, rules)
print("Original Sentence:", example_sentence)
print("Corrected Sentence:", corrected_sentence)
# Out:
# Extracted Rules:
# {
#     "subject_verb_order": [
#         {
#             "incorrect": "පාසැල් නුඹ  යන්නෙහි",
#             "correct": "නුඹ පාසැල් යන්නෙහි"
#         },
#         {
#             "incorrect": "ඔබ සැම ගුරුතුමාට  කරන්නෙහු ආචාර",
#             "correct": "ඔබ සැම ගුරුතුමාට ආචාර කරන්නෙහු"
#         },
#         {
#             "incorrect": "ගුරුතුමා  උගන්වයි පාඩම",
#             "correct": "ගුරුතුමා පාඩම උගන්වයි"
#         },
#         {
#             "incorrect": "ගුරුවරු  උගන්වති පාඩම්",
#             "correct": "ගුරුවරු පාඩම් උගන්වති"
#         },
#         {
#             "incorrect": "පාසැල් දරුවා  ගියේය",
#             "correct": "දරුවා පාසැල් ගියේය"
#         },
#         {
#             "incorrect": "දරුවෝ  ගියෝය පාසැල්",
#             "correct": "දරුවෝ පාසැල් ගියෝය"
#         },
#         {
#             "incorrect": "දරුවෝ  ගියහ පාසැල්",
#             "correct": "දරුවෝ පාසැල්  ගියහ"
#         },
#         {
#             "incorrect": "පාසැල් දරුවා  යයි ",
#             "correct": "දරුවා පාසැල් යයි "
#         },
#         {
#             "incorrect": "දරුවෝ  යති පාසැල්  ",
#             "correct": "දරුවෝ පාසැල් යති "
#         },
#         {
#             "incorrect": "ඈ අසයි බණ",
#             "correct": "ඈ බණ අසයි "
#         },
#         {
#             "incorrect": "බණ ඈ අසන්නීය",
#             "correct": "ඈ බණ අසන්නීය"
#         },
#         {
#             "incorrect": "ඈ ඇසුවාය බණ",
#             "correct": "ඈ බණ ඇසුවාය"
#         },
#         {
#             "incorrect": "උපාසිකාවෝ  අසති බණ",
#             "correct": "උපාසිකාවෝ බණ අසති"
#         },
#         {
#             "incorrect": "උපාසිකාවෝ  අසන්නෝය බණ",
#             "correct": "උපාසිකාවෝ බණ අසන්නෝය"
#         },
#         {
#             "incorrect": "බණ උපාසිකාවෝ ඇසූහ ",
#             "correct": "උපාසිකාවෝ බණ ඇසූහ "
#         },
#         {
#             "incorrect": "උපාසිකාවෝ ඇසුවෝය බණ",
#             "correct": "උපාසිකාවෝ බණ ඇසුවෝය"
#         },
#         {
#             "incorrect": "ඔහු අසයි බණ",
#             "correct": "ඔහු බණ අසයි "
#         },
#         {
#             "incorrect": "ඔහු අසන්නේය බණ",
#             "correct": "ඔහු බණ අසන්නේය"
#         },
#         {
#             "incorrect": "බණ උපාසකයා ඇසුවේය",
#             "correct": "උපාසකයා බණ ඇසුවේය"
#         },
#         {
#             "incorrect": "උපාසකයෝ අසති බණ",
#             "correct": "උපාසකයෝ බණ අසති "
#         },
#         {
#             "incorrect": "උපාසකයෝ අසන්නෝය බණ",
#             "correct": "උපාසකයෝ බණ අසන්නෝය"
#         },
#         {
#             "incorrect": "උපාසකයෝ ඇසූහ බණ ",
#             "correct": "උපාසකයෝ බණ ඇසූහ "
#         },
#         {
#             "incorrect": "සෙලවෙයි ගස සුළඟට ",
#             "correct": "ගස සුළඟට සෙලවෙයි"
#         },
#         {
#             "incorrect": "ගස  සෙලැවුණි සුළඟට",
#             "correct": "ගස සුළඟට සෙලැවුණි"
#         },
#         {
#             "incorrect": "සුළඟට ගස සෙලවුණේය",
#             "correct": "ගස සුළඟට සෙලවුණේය"
#         },
#         {
#             "incorrect": "ගස් සෙලවෙයි සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවෙයි "
#         },
#         {
#             "incorrect": "ගස්  සෙලවුණි සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවුණි"
#         },
#         {
#             "incorrect": "ගස් සෙලවුණේය සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවුණේය"
#         },
#         {
#             "incorrect": "අපි  නමදිමු දෙමාපියන්",
#             "correct": "අපි දෙමාපියන් නමදිමු"
#         },
#         {
#             "incorrect": "මා විසින්  කියවේ පොත",
#             "correct": "මා විසින් පොත කියවේ"
#         },
#         {
#             "incorrect": "අප විසින් නැමදෙති දෙමාපියෝ ",
#             "correct": "අප විසින් දෙමාපියෝ නැමදෙති"
#         },
#         {
#             "incorrect": "පුතා  පිබිදෙයි අලුයම",
#             "correct": "පුතා අලුයම පිබිදෙයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින්  සදනු ලබයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු ලබයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින් සදනු සෑදෙයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු සෑදෙයි"
#         },
#         {
#             "incorrect": "තාත්තා සේවකයා ලවා කරවයි වැඩ",
#             "correct": "තාත්තා සේවකයා ලවා වැඩ කරවයි "
#         },
#         {
#             "incorrect": "ලේඛකයෝ  ලියති පොත්",
#             "correct": "ලේඛකයෝ පොත් ලියති"
#         },
#         {
#             "incorrect": "මම කඩමි මලක්",
#             "correct": "මම මලක් කඩමි"
#         },
#         {
#             "incorrect": "වඩුවා විසින්  සදනු ලබයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු ලබයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින් සදනු සෑදෙයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු සෑදෙයි"
#         },
#         {
#             "incorrect": "අප විසින්  කඩනු ලැබේ මල්",
#             "correct": "අප විසින් මල් කඩනු ලැබේ "
#         },
#         {
#             "incorrect": "අප විසින්  කඩනු කැඩේ මල්",
#             "correct": "අප විසින් මල් කඩනු කැඩේ"
#         },
#         {
#             "incorrect": "ගුරුවරුන් විසින්  යහ මග යැවේ ශිෂ්‍යයෝ",
#             "correct": "ගුරුවරුන් විසින් ශිෂ්‍යයෝ යහ මග යැවේ"
#         },
#         {
#             "incorrect": "අයියා සෑදූ  හැඩයි සරුංගලය",
#             "correct": "අයියා සෑදූ සරුංගලය හැඩයි"
#         },
#         {
#             "incorrect": "ළමයා මාමා ලවා  කඩවයි අඹ",
#             "correct": "ළමයා මාමා ලවා අඹ කඩවයි"
#         },
#         {
#             "incorrect": "මාමා කෙක්කෙන් කඩයි අඹ",
#             "correct": "මාමා කෙක්කෙන් අඹ කඩයි"
#         },
#         {
#             "incorrect": "ගස්  පිරී තිබේ මල්වලින්",
#             "correct": "ගස් මල්වලින් පිරී තිබේ"
#         },
#         {
#             "incorrect": "විදිලි බුබුළුවලින්  බබලයි තොරණ",
#             "correct": "විදිලි බුබුළුවලින් තොරණ බබලයි "
#         },
#         {
#             "incorrect": "අපි සතුන්ට දක්වමු කරුණාව",
#             "correct": "අපි සතුන්ට කරුණාව දක්වමු"
#         },
#         {
#             "incorrect": "අම්බලම මගීන්ගේ පිණිස නිමවා ඇත පහසුව",
#             "correct": "අම්බලම මගීන්ගේ පහසුව පිණිස නිමවා ඇත"
#         },
#         {
#             "incorrect": "වහලෙන්  බිමට වැටේ වතුර",
#             "correct": "වහලෙන් වතුර බිමට වැටේ"
#         },
#         {
#             "incorrect": "බල්ලා  එලියට ආවේය කුඩුවෙන්",
#             "correct": "බල්ලා කුඩුවෙන් එලියට ආවේය"
#         },
#         {
#             "incorrect": "ඇතාගේ  සුදු පාටය දළ",
#             "correct": "ඇතාගේ දළ සුදු පාටය"
#         },
#         {
#             "incorrect": "ඔහු  පිහිනයි මුහුදේ",
#             "correct": "ඔහු මුහුදේ පිහිනයි"
#         },
#         {
#             "incorrect": "සතුරෝ  ඇද වැටුනෝය රණබිමෙහි",
#             "correct": "සතුරෝ රණබිමෙහි ඇද වැටුනෝය"
#         },
#         {
#             "incorrect": "අඹ  ගෙඩි පිරී ඇත ගස්වල",
#             "correct": "අඹ ගස්වල ගෙඩි පිරී ඇත"
#         },
#         {
#             "incorrect": "මා කියන  අසන්න බස්",
#             "correct": "මා කියන බස් අසන්න"
#         },
#         {
#             "incorrect": "අපට  කියන්න කතාවක්",
#             "correct": "අපට කතාවක් කියන්න"
#         },
#         {
#             "incorrect": "මම  වදිමි අම්මාට",
#             "correct": "මම අම්මාට වදිමි"
#         },
#         {
#             "incorrect": "සිරිපාල  ගියේ ය කඩයට",
#             "correct": "සිරිපාල කඩයට ගියේ ය"
#         },
#         {
#             "incorrect": "ඇත්තු  ඇදී යති පේලියට",
#             "correct": "ඇත්තු පේලියට ඇදී යති"
#         },
#         {
#             "incorrect": "ගස්‌ වැටෙයි සුලඟට",
#             "correct": "ගස්‌ සුලඟට වැටෙයි"
#         },
#         {
#             "incorrect": "ඇය නැළ වූවාය පුතු",
#             "correct": "ඇය පුතු නැළ වූවාය"
#         },
#         {
#             "incorrect": "ඔහු යයි රැකියාවට",
#             "correct": "ඔහු රැකියාවට යයි"
#         },
#         {
#             "incorrect": "ගායකයා ගයයි ගී",
#             "correct": "ගායකයා ගී ගයයි"
#         },
#         {
#             "incorrect": "නිවේදකයා  කරයි නිවේදනය",
#             "correct": "නිවේදකයා නිවේදනය කරයි"
#         },
#         {
#             "incorrect": "පන්ති නායකයා  කියවයි පොත",
#             "correct": "පන්ති නායකයා පොත කියවයි"
#         },
#         {
#             "incorrect": "ළමයා ගසයි බෝලයෙන්‌",
#             "correct": "ළමයා බෝලයෙන්‌ ගසයි"
#         },
#         {
#             "incorrect": "නළු රඟති නිළියෝ",
#             "correct": "නළු නිළියෝ රඟති "
#         },
#         {
#             "incorrect": "සිංහයෝ  නොකති තණ",
#             "correct": "සිංහයෝ තණ නොකති"
#         },
#         {
#             "incorrect": "මම යමි නගරයට",
#             "correct": "මම නගරයට යමි "
#         },
#         {
#             "incorrect": "අපි යමු  නගරයට",
#             "correct": "අපි නගරයට යමු"
#         },
#         {
#             "incorrect": "ඔබ යන්නෙහි  නගරයට",
#             "correct": "ඔබ නගරයට යන්නෙහි "
#         },
#         {
#             "incorrect": "නුබලා යන්නෙහු  නගරයට",
#             "correct": "නුබලා නගරයට යන්නෙහු"
#         },
#         {
#             "incorrect": "නගරයට ඔහු  යයි",
#             "correct": "ඔහු නගරයට යයි"
#         },
#         {
#             "incorrect": "නගරයට අප යති",
#             "correct": "අප නගරයට යති"
#         },
#         {
#             "incorrect": "මම  කළෙමි පාඩමි",
#             "correct": "මම පාඩමි කළෙමි"
#         },
#         {
#             "incorrect": "අපි යන්නේමු පාසල්",
#             "correct": "අපි පාසල් යන්නේමු "
#         },
#         {
#             "incorrect": "කෝවිලට නුඹ යහි ",
#             "correct": "නුඹ කෝවිලට යහි "
#         },
#         {
#             "incorrect": "නුඹ යන්නෙහි කෝවිලට",
#             "correct": "නුඹ කෝවිලට යන්නෙහි"
#         },
#         {
#             "incorrect": "නුඹ ගියෙහි කෝවිලට",
#             "correct": "නුඹ කෝවිලට ගියෙහි"
#         },
#         {
#             "incorrect": "අවදි මම වෙමි",
#             "correct": "මම අවදි වෙමි"
#         },
#         {
#             "incorrect": "මම මඳිමි දත්‌ ",
#             "correct": "මම දත්‌ මඳිමි"
#         },
#         {
#             "incorrect": "මම සෝදමි මුහුණ",
#             "correct": "මම මුහුණ සෝදමි"
#         },
#         {
#             "incorrect": "රට රණවිරුවෝ  රකිති",
#             "correct": "රණවිරුවෝ රට රකිති"
#         },
#         {
#             "incorrect": "කොටියා විසින්‌  මැරෙයි මුව ",
#             "correct": "කොටියා විසින්‌ මුව මැරෙයි"
#         },
#         {
#             "incorrect": "කම්කරුවා විසින්‌  ගොඩ නැගේ මාර්ග",
#             "correct": "කම්කරුවා විසින්‌ මාර්ග ගොඩ නැගේ"
#         },
#         {
#             "incorrect": "මට පුළුවන් පිළිගන්න",
#             "correct": "මට පිළිගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා එකතු",
#             "correct": "ඇය එකතු කළා"
#         },
#         {
#             "incorrect": "අපි  පිළිගත්තා එය",
#             "correct": "අපි එය පිළිගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන්  දුන්නා උපදෙස්",
#             "correct": "ඔවුන් උපදෙස් දුන්නා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් පිළිගන්න",
#             "correct": "මට පිළිගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  දෙනවා ඉඩ",
#             "correct": "ඇය ඉඩ දෙනවා"
#         },
#         {
#             "incorrect": "අපි  කරනවා නිවේදනය",
#             "correct": "අපි නිවේදනය කරනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් ගන්න",
#             "correct": "මට ගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  ඉන්නවා අද",
#             "correct": "ඇය අද ඉන්නවා"
#         },
#         {
#             "incorrect": "ඔවුන්  කළා පිළිවෙළ",
#             "correct": "ඔවුන් පිළිවෙළ කළා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් එන්න",
#             "correct": "මට එන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇයට  පුළුවන් අහන්න",
#             "correct": "ඇයට අහන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය අමුණනවා  එය ",
#             "correct": "ඇය එය අමුණනවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට දෙනවා  පහර",
#             "correct": "අපි ඔවුන්ට පහර දෙනවා"
#         },
#         {
#             "incorrect": "ඔවුන්  මඟහරිනවා ඇයව",
#             "correct": "ඔවුන් ඇයව මඟහරිනවා"
#         },
#         {
#             "incorrect": "මට පුළුවන් පිසින්න",
#             "correct": "මට පිසින්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  වගෙයි ඔහු",
#             "correct": "ඇය ඔහු වගෙයි"
#         },
#         {
#             "incorrect": "අපි   කරනවා පරාජය",
#             "correct": "අපි  පරාජය කරනවා"
#         },
#         {
#             "incorrect": "සතුටට ඔවුන්  පත්වුනා",
#             "correct": "ඔවුන් සතුටට පත්වුනා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් අරඹන්න ",
#             "correct": "මට  අරඹන්න පුළුවන්"
#         },
#         {
#             "incorrect": "අපි  ණයට ගත්තා මුදල්",
#             "correct": "අපි මුදල් ණයට ගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන්  ගන්නවා හුස්ම",
#             "correct": "ඔවුන් හුස්ම ගන්නවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් එන්න",
#             "correct": "මට එන්න පුළුවන්"
#         },
#         {
#             "incorrect": "මට  පුළුවන් සාදන්න",
#             "correct": "මට සාදන්න පුළුවන්"
#         },
#         {
#             "incorrect": "අපි කරනවා  ගණනය ",
#             "correct": "අපි  ගණනය කරනවා"
#         },
#         {
#             "incorrect": "ඇය  තෝරනවා ඔහුව",
#             "correct": "ඇය ඔහුව තෝරනවා"
#         },
#         {
#             "incorrect": "අපි  වහනවා එය",
#             "correct": "අපි එය වහනවා"
#         },
#         {
#             "incorrect": "මෙහෙ ඔහු  එනවා",
#             "correct": "ඔහු මෙහෙ එනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් සසඳන්න ",
#             "correct": "මට  සසඳන්න පුළුවන්"
#         },
#         {
#             "incorrect": "තරඟ ඇය  කරනවා",
#             "correct": "ඇය තරඟ කරනවා"
#         },
#         {
#             "incorrect": "පැමිණිලි අපි  කරනවා",
#             "correct": "අපි පැමිණිලි කරනවා"
#         },
#         {
#             "incorrect": "ඔවුන් දිගටම කළා කියවීම ",
#             "correct": "ඔවුන් කියවීම දිගටම කළා"
#         },
#         {
#             "incorrect": "ඔහු  ඇඬුවා ගැන",
#             "correct": "ඔහු ගැන ඇඬුවා"
#         },
#         {
#             "incorrect": "තීරණය මට  කරන්න පුළුවන්",
#             "correct": "මට තීරණය කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා විස්තර ",
#             "correct": "ඇය විස්තර කළා"
#         },
#         {
#             "incorrect": "අතුරුදහන් ඔවුන්  වුනා",
#             "correct": "ඔවුන් අතුරුදහන් වුනා"
#         },
#         {
#             "incorrect": "එය මම සොයාගත්තා",
#             "correct": "මම එය සොයාගත්තා"
#         },
#         {
#             "incorrect": "එයට  ඇය කැමතිනෑ",
#             "correct": "ඇය එයට කැමතිනෑ"
#         },
#         {
#             "incorrect": "අපි කරනවා  එය ",
#             "correct": "අපි එය කරනවා"
#         },
#         {
#             "incorrect": "ඔවුන් දකිනවා සිහින ",
#             "correct": "ඔවුන් සිහින දකිනවා"
#         },
#         {
#             "incorrect": "මම උපයනවා මුදල්",
#             "correct": "මම මුදල් උපයනවා"
#         },
#         {
#             "incorrect": "ඔහු  කනවා සෑහෙන්න",
#             "correct": "ඔහු සෑහෙන්න කනවා"
#         },
#         {
#             "incorrect": "අපි රසවින්ඳා එය ",
#             "correct": "අපි එය රසවින්ඳා"
#         },
#         {
#             "incorrect": "මෙහෙ ඔවුන් ආවා",
#             "correct": "ඔවුන් මෙහෙ ආවා"
#         },
#         {
#             "incorrect": "පළා ඔහු  ගියා",
#             "correct": "ඔහු පළා ගියා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් කරන්න",
#             "correct": "මට කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇයටත්  හැඟෙනවා එය",
#             "correct": "ඇයටත් එය හැඟෙනවා"
#         },
#         {
#             "incorrect": "එහෙන් අපි  පළාගියා",
#             "correct": "අපි එහෙන් පළාගියා"
#         },
#         {
#             "incorrect": "ඔවුන්  වෙනවා ගුවන්ගත",
#             "correct": "ඔවුන් ගුවන්ගත වෙනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් අනුගමනය කරන්න",
#             "correct": "මට අනුගමනය කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කළා අමතක",
#             "correct": "ඇය අමතක කළා"
#         },
#         {
#             "incorrect": "අපි  දෙනවා සමාව",
#             "correct": "අපි සමාව දෙනවා"
#         },
#         {
#             "incorrect": "මට  ඇයට පුළුවන් දෙන්න ",
#             "correct": "මට ඇයට දෙන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය යනවා එහෙ ",
#             "correct": "ඇය එහෙ යනවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට  කිව්වා ආයුබෝවන්",
#             "correct": "අපි ඔවුන්ට ආයුබෝවන් කිව්වා"
#         },
#         {
#             "incorrect": "මම   කරනවා පිළිකුල්",
#             "correct": "මම  පිළිකුල් කරනවා"
#         },
#         {
#             "incorrect": "එය මට  ඇහෙනවා",
#             "correct": "මට එය ඇහෙනවා"
#         },
#         {
#             "incorrect": "ඇය  මවාගන්නවා සිතෙහි",
#             "correct": "ඇය සිතෙහි මවාගන්නවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට කළා ආරාධනා ",
#             "correct": "අපි ඔවුන්ට ආරාධනා කළා"
#         },
#         {
#             "incorrect": "මම  දන්නවා ඔහුව",
#             "correct": "මම ඔහුව දන්නවා"
#         },
#         {
#             "incorrect": "ඇය  ඉගෙනගත්තා එය",
#             "correct": "ඇය එය ඉගෙනගත්තා"
#         },
#         {
#             "incorrect": "අපි  පිටවෙනවා දැන්",
#             "correct": "අපි දැන් පිටවෙනවා"
#         },
#         {
#             "incorrect": "ඔවුහු  කිව්වා බොරු",
#             "correct": "ඔවුහු  බොරු කිව්වා"
#         },
#         {
#             "incorrect": "මට  පුළුවන්  සවන්දෙන්න",
#             "correct": "මට  සවන්දෙන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කරගත්තා අහිමි ",
#             "correct": "ඇය  අහිමි කරගත්තා"
#         },
#         {
#             "incorrect": "අපි  සෑදුවා ඊයේ",
#             "correct": "අපි ඊයේ සෑදුවා"
#         },
#         {
#             "incorrect": "ඔවුන්  හමුවුනා ඔහුව",
#             "correct": "ඔවුන් ඔහුව හමුවුනා"
#         },
#         {
#             "incorrect": "මම  ලියනවා වැරදි",
#             "correct": "මම වැරදි ලියනවා"
#         },
#         {
#             "incorrect": "මම සැමවිටම කරනවා යාච්ඤා ",
#             "correct": "මම සැමවිටම යාච්ඤා කරනවා"
#         },
#         {
#             "incorrect": "ඇය  තෝරාගන්නවා එය",
#             "correct": "ඇය එය තෝරාගන්නවා"
#         },
#         {
#             "incorrect": "අපි  කළා ආරක්ෂා",
#             "correct": "අපි ආරක්ෂා කළා"
#         },
#         {
#             "incorrect": "ඔවුහු  කරාවි දඬුවම්",
#             "correct": "ඔවුහු දඬුවම් කරාවි"
#         },
#         {
#             "incorrect": "මට  පුළුවන් තියන්න",
#             "correct": "මට තියන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කියවනවා එය",
#             "correct": "ඇය එය කියවනවා"
#         },
#         {
#             "incorrect": "අපිට  ලැබුණා එය",
#             "correct": "අපිට එය ලැබුණා"
#         },
#         {
#             "incorrect": "ඔවුන්  කරනවා ප්‍රතික්ෂේප",
#             "correct": "ඔවුන් ප්‍රතික්ෂේප කරනවා"
#         },
#         {
#             "incorrect": "මට  මතකයි එය",
#             "correct": "මට එය මතකයි"
#         },
#         {
#             "incorrect": "නැවත  ඇය කියනවා",
#             "correct": "ඇය නැවත කියනවා"
#         },
#         {
#             "incorrect": "අපිට  පෙනෙනවා එය",
#             "correct": "අපිට එය පෙනෙනවා"
#         },
#         {
#             "incorrect": "එය ඔවුන් විකුණනවා",
#             "correct": "ඔවුන් එය විකුණනවා"
#         },
#         {
#             "incorrect": "මම යැව්වා  ඊයේ",
#             "correct": "මම ඊයේ යැව්වා"
#         },
#         {
#             "incorrect": "රැවුල  ඔහු බෑවා",
#             "correct": "ඔහු රැවුල බෑවා"
#         },
#         {
#             "incorrect": "අපි කළා ගායනා",
#             "correct": "අපි  ගායනා කළා"
#         },
#         {
#             "incorrect": "ඔවුන් ඉඳත්තා එතන ",
#             "correct": "ඔවුන් එතන ඉඳත්තා"
#         },
#         {
#             "incorrect": "මට පුළුවන් කියන්න",
#             "correct": "මට  කියන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කරනවා වියදම්",
#             "correct": "ඇය වියදම් කරනවා"
#         },
#         {
#             "incorrect": "අපි වින්ඳා දුක් ",
#             "correct": "අපි දුක් වින්ඳා"
#         },
#         {
#             "incorrect": "යෝජනා ඔවුන් කරනවා",
#             "correct": "ඔවුන් යෝජනා කරනවා"
#         },
#         {
#             "incorrect": "පුදුම මම කළා",
#             "correct": "මම පුදුම කළා"
#         },
#         {
#             "incorrect": "ඇය ගත්තා එය",
#             "correct": "ඇය එය ගත්තා"
#         },
#         {
#             "incorrect": "එය අපි උගන්වනවා",
#             "correct": "අපි එය උගන්වනවා"
#         },
#         {
#             "incorrect": "ඔවුන් කීව්වා අපට ",
#             "correct": "ඔවුන් අපට කීව්වා"
#         },
#         {
#             "incorrect": "ඇය කළා ස්තූති ",
#             "correct": "ඇය ස්තූති කළා"
#         },
#         {
#             "incorrect": "මට පුළුවන් සිතා බලන්න",
#             "correct": "මට සිතා බලන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා විසි ",
#             "correct": "ඇය විසි කළා"
#         },
#         {
#             "incorrect": "අපි  තේරුම්ගන්නවා එය",
#             "correct": "අපි එය තේරුම්ගන්නවා"
#         },
#         {
#             "incorrect": "එය ඔවුන්ට අවශ්‍යයි",
#             "correct": "ඔවුන්ට එය අවශ්‍යයි"
#         },
#         {
#             "incorrect": "මට පුළුවන් ඇඳපැළඳ ගන්න",
#             "correct": "මට  ඇඳපැළඳ ගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  ලියනවා එය",
#             "correct": "ඇය එය ලියනවා"
#         },
#         {
#             "incorrect": "අපි කරනවා කතා",
#             "correct": "අපි කතා කරනවා"
#         },
#         {
#             "incorrect": "එය ගාව ඔවුන්",
#             "correct": "එය ඔවුන් ගාව"
#         },
#         {
#             "incorrect": "මම නැරඹුවා එය ",
#             "correct": "මම එය නැරඹුවා"
#         },
#         {
#             "incorrect": "කතා මම කරාවි",
#             "correct": "මම කතා කරාවි"
#         },
#         {
#             "incorrect": "ඔහු ගත්තා  මිලට ",
#             "correct": "ඔහු මිලට ගත්තා"
#         },
#         {
#             "incorrect": "අපි කළා නිමා",
#             "correct": "අපි නිමා කළා"
#         },
#         {
#             "incorrect": "මට හැක පිළිගත",
#             "correct": "මට පිළිගත හැක"
#         },
#         {
#             "incorrect": "ඇය කළාය එකතු ",
#             "correct": "ඇය එකතු කළාය"
#         },
#         {
#             "incorrect": "අපි පිළිගනිමු එය ",
#             "correct": "අපි එය පිළිගනිමු"
#         },
#         {
#             "incorrect": "ඔවුහු දුන්නෝය උපදෙස් ",
#             "correct": "ඔවුහු උපදෙස් දුන්නෝය"
#         },
#         {
#             "incorrect": "මට වියහැක එකඟ ",
#             "correct": "මට එකඟ වියහැක"
#         },
#         {
#             "incorrect": "ඇය දෙයි ඉඩ",
#             "correct": "ඇය ඉඩ දෙයි"
#         },
#         {
#             "incorrect": "අපි කරමු නිවේදනය ",
#             "correct": "අපි නිවේදනය කරමු"
#         },
#         {
#             "incorrect": "මට ඉල්ලියහැක  සමාව",
#             "correct": "මට සමාව ඉල්ලියහැක"
#         },
#         {
#             "incorrect": "ඔවුහු  කළෝය පිළියෙළ",
#             "correct": "ඔවුහු පිළියෙළ කළෝය"
#         },
#         {
#             "incorrect": "මට ආහැක හෙට ",
#             "correct": "මට හෙට ආහැක"
#         },
#         {
#             "incorrect": "ඇයට හැක ඇසිය",
#             "correct": "ඇයට ඇසිය හැක"
#         },
#         {
#             "incorrect": "ඇය  අමුණයි එය",
#             "correct": "ඇය එය අමුණයි"
#         },
#         {
#             "incorrect": "අපි පහරදෙමු ඔවුන්ට ",
#             "correct": "අපි ඔවුන්ට පහරදෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු මඟහැරියෝය ඇයව",
#             "correct": "ඔවුහු ඇයව මඟහැරියෝය"
#         },
#         {
#             "incorrect": "පිසිය මට හැක",
#             "correct": "මට පිසිය හැක"
#         },
#         {
#             "incorrect": "ඇය වැනිය ඔහු ",
#             "correct": "ඇය ඔහු වැනිය"
#         },
#         {
#             "incorrect": "අපි  කරමු පරාජය",
#             "correct": "අපි පරාජය කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු පත්විය  සතුටට ",
#             "correct": "ඔවුහු සතුටට පත්විය"
#         },
#         {
#             "incorrect": "මට හැක ඇරඹිය",
#             "correct": "මට ඇරඹිය හැක"
#         },
#         {
#             "incorrect": "ඔවුහු ගනිති හුස්ම ",
#             "correct": "ඔවුහු හුස්ම ගනිති"
#         },
#         {
#             "incorrect": "මට  හැක සෑදිය",
#             "correct": "මට සෑදිය හැක"
#         },
#         {
#             "incorrect": "ආහාර ඇය මිලට ගනියි",
#             "correct": "ඇය ආහාර මිලට ගනියි"
#         },
#         {
#             "incorrect": "ගණනය අපි කරමු",
#             "correct": "අපි ගණනය කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු  යති රැගෙන",
#             "correct": "ඔවුහු රැගෙන යති"
#         },
#         {
#             "incorrect": "ඔවුන්  නොකරයි වංචා",
#             "correct": "ඔවුන් වංචා නොකරයි"
#         },
#         {
#             "incorrect": "ඇය  තෝරයි ඔහුව",
#             "correct": "ඇය ඔහුව තෝරයි"
#         },
#         {
#             "incorrect": "අපි  වසමු එය",
#             "correct": "අපි එය වසමු"
#         },
#         {
#             "incorrect": "ඔහු එයි මෙහි",
#             "correct": "ඔහු මෙහි එයි"
#         },
#         {
#             "incorrect": "මට  හැක සැසඳිය",
#             "correct": "මට සැසඳිය හැක"
#         },
#         {
#             "incorrect": "ඇය කරයි  තරඟ ",
#             "correct": "ඇය තරඟ කරයි"
#         },
#         {
#             "incorrect": "අපි  කරමු පැමිණිලි",
#             "correct": "අපි පැමිණිලි කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු  කළෝය දිගටම",
#             "correct": "ඔවුහු දිගටම කළෝය"
#         },
#         {
#             "incorrect": "දිගටම ඔහු ඇඬුවේය",
#             "correct": "ඔහු දිගටම ඇඬුවේය"
#         },
#         {
#             "incorrect": "ඇය කළාය විස්තර",
#             "correct": "ඇය විස්තර කළාය"
#         },
#         {
#             "incorrect": "අපි නොවීමු එකඟ",
#             "correct": "අපි එකඟ නොවීමු"
#         },
#         {
#             "incorrect": "ඔවුහු විය අතුරුදහන්",
#             "correct": "ඔවුහු අතුරුදහන් විය"
#         },
#         {
#             "incorrect": "එය මම සොයාගත්තෙමි",
#             "correct": "මම එය සොයාගත්තෙමි"
#         },
#         {
#             "incorrect": "ඇය අකැමතියි එයට",
#             "correct": "ඇය එයට අකැමතියි"
#         },
#         {
#             "incorrect": "අපි කරමු එය",
#             "correct": "අපි එය කරමු"
#         },
#         {
#             "incorrect": "ඔවුන් දකිති සිහින",
#             "correct": "ඔවුන් සිහින දකිති"
#         },
#         {
#             "incorrect": "මම උපයමි මුදල්",
#             "correct": "මම මුදල් උපයමි"
#         },
#         {
#             "incorrect": "ඔහු කයි සෑහෙන්න",
#             "correct": "ඔහු සෑහෙන්න කයි"
#         },
#         {
#             "incorrect": "අපි රසවින්ඳෙමු එය",
#             "correct": "අපි එය රසවින්ඳෙමු"
#         },
#         {
#             "incorrect": "ඔවුන් ආවෝය මෙහි ",
#             "correct": "ඔවුන් මෙහි ආවෝය"
#         },
#         {
#             "incorrect": "ඔහු ගියේය පළා",
#             "correct": "ඔහු පළා ගියේය"
#         },
#         {
#             "incorrect": "මට කළහැක පැහැදිලි ",
#             "correct": "මට පැහැදිලි කළහැක"
#         },
#         {
#             "incorrect": "ඇයට හැඟෙයි එය ",
#             "correct": "ඇයට එය හැඟෙයි"
#         },
#         {
#             "incorrect": "අපි ගියෙමු පළා ",
#             "correct": "අපි පළා ගියෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු වන්නෝය ගුවන්ගත ",
#             "correct": "ඔවුහු ගුවන්ගත වන්නෝය"
#         },
#         {
#             "incorrect": "මට කළහැක අනුගමනය ",
#             "correct": "මට අනුගමනය කළහැක"
#         },
#         {
#             "incorrect": "ඇය කළාය අමතක ",
#             "correct": "ඇය අමතක කළාය"
#         },
#         {
#             "incorrect": "අපි දෙමු සමාව ",
#             "correct": "අපි සමාව දෙමු"
#         },
#         {
#             "incorrect": "ඇය යයි එහෙ ",
#             "correct": "ඇය  එහෙ යයි"
#         },
#         {
#             "incorrect": "ආයුබෝවන් අපි කීවෙමු",
#             "correct": "අපි ආයුබෝවන් කීවෙමු"
#         },
#         {
#             "incorrect": "මම කරමි පිළිකුල් ",
#             "correct": "මම පිළිකුල් කරමි"
#         },
#         {
#             "incorrect": "මට ඇසෙයි එය ",
#             "correct": "මට එය ඇසෙයි"
#         },
#         {
#             "incorrect": "ඇය ගනියි  මවා ",
#             "correct": "ඇය මවා ගනියි"
#         },
#         {
#             "incorrect": "අපි කළෙමු ආරාධනා ",
#             "correct": "අපි ආරාධනා කළෙමු"
#         },
#         {
#             "incorrect": "මම දනිමි  ඔහුව ",
#             "correct": "මම ඔහුව දනිමි"
#         },
#         {
#             "incorrect": "ඇය ගත්තාය ඉගෙන ",
#             "correct": "ඇය ඉගෙන ගත්තාය"
#         },
#         {
#             "incorrect": "අපි පිටවෙමු දැන් ",
#             "correct": "අපි දැන් පිටවෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කීවෝය බොරු ",
#             "correct": "ඔවුහු බොරු කීවෝය"
#         },
#         {
#             "incorrect": "මට හැක සවන්දිය ",
#             "correct": "මට සවන්දිය හැක"
#         },
#         {
#             "incorrect": "ඇය කරගත්තාය අහිමි ",
#             "correct": "ඇය අහිමි කරගත්තාය"
#         },
#         {
#             "incorrect": "අපි සෑදුවෙමු එය ",
#             "correct": "අපි එය සෑදුවෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු හමුවූවෝය ඔහුව ",
#             "correct": "ඔවුහු ඔහුව හමුවූවෝය"
#         },
#         {
#             "incorrect": "මම ලෙස ලියමි වැරදි ",
#             "correct": "මම වැරදි ලෙස ලියමි"
#         },
#         {
#             "incorrect": "මම කරමි  යාච්ඤා ",
#             "correct": "මම යාච්ඤා කරමි"
#         },
#         {
#             "incorrect": "ඇය තෝරාගනියි එය ",
#             "correct": "ඇය එය තෝරාගනියි"
#         },
#         {
#             "incorrect": "අපි කළෙමු  ආරක්ෂා ",
#             "correct": "අපි ආරක්ෂා කළෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කරයි දඬුවම්",
#             "correct": "ඔවුහු දඬුවම් කරයි"
#         },
#         {
#             "incorrect": "මට හැක  තැබිය ",
#             "correct": "මට තැබිය හැක"
#         },
#         {
#             "incorrect": "ඇය කියවයි එය ",
#             "correct": "ඇය එය කියවයි"
#         },
#         {
#             "incorrect": "අපිට ලැබුණි එය ",
#             "correct": "අපිට එය ලැබුණි"
#         },
#         {
#             "incorrect": "ඔවුහු කරති  ප්‍රතික්ෂේප ",
#             "correct": "ඔවුහු ප්‍රතික්ෂේප කරති"
#         },
#         {
#             "incorrect": "මට මතකයි එය ",
#             "correct": "මට එය මතකයි"
#         },
#         {
#             "incorrect": "ඇය කියයි නැවත ",
#             "correct": "ඇය නැවත කියයි"
#         },
#         {
#             "incorrect": "අපිට පෙනෙයි එය ",
#             "correct": "අපිට එය පෙනෙයි"
#         },
#         {
#             "incorrect": "ඔවුන් විකුණති  එය ",
#             "correct": "ඔවුන් එය විකුණති"
#         },
#         {
#             "incorrect": "මම යැව්වෙමි ඊයේ ",
#             "correct": "මම ඊයේ යැව්වෙමි"
#         },
#         {
#             "incorrect": "ඔහු බෑවේය රැවුල ",
#             "correct": "ඔහු රැවුල බෑවේය"
#         },
#         {
#             "incorrect": "එය ඇකිළුනේය සැණින් ",
#             "correct": "එය සැණින් ඇකිළුනේය"
#         },
#         {
#             "incorrect": "අපි කරන්නෙමු ගායනා ",
#             "correct": "අපි ගායනා කරන්නෙමු"
#         },
#         {
#             "incorrect": "ඔවුන් ඉඳත්තෝය එතන ",
#             "correct": "ඔවුන් එතන ඉඳත්තෝය"
#         },
#         {
#             "incorrect": "මට හැක කිව ",
#             "correct": "මට කිව හැක"
#         },
#         {
#             "incorrect": "ඇය කරයි වියදම් ",
#             "correct": "ඇය වියදම් කරයි"
#         },
#         {
#             "incorrect": "අපි  වින්ඳෙමු දුක්",
#             "correct": "අපි දුක් වින්ඳෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කරති යෝජනා ",
#             "correct": "ඔවුහු යෝජනා කරති"
#         },
#         {
#             "incorrect": "මම කළෙමි පුදුම ",
#             "correct": "මම පුදුම කළෙමි"
#         },
#         {
#             "incorrect": "ඇය ගත්තාය එය ",
#             "correct": "ඇය එය ගත්තාය"
#         },
#         {
#             "incorrect": "අපි උගන්වමු එය ",
#             "correct": "අපි එය උගන්වමු"
#         },
#         {
#             "incorrect": "අපට ඔවුන් කීවෝය",
#             "correct": "ඔවුන් අපට කීවෝය"
#         },
#         {
#             "incorrect": "ස්තූතියි ඇය කළාය",
#             "correct": "ඇය ස්තූතියි කළාය"
#         },
#         {
#             "incorrect": "සිතා මට බැලියහැක",
#             "correct": "මට සිතා බැලියහැක"
#         },
#         {
#             "incorrect": "විසි  ඇය කළාය",
#             "correct": "ඇය විසි කළාය"
#         },
#         {
#             "incorrect": "එය  අපි තේරුම්ගනිමු",
#             "correct": "අපි එය තේරුම්ගනිමු"
#         },
#         {
#             "incorrect": "ඔවුන්ට අවශ්‍යයි එය ",
#             "correct": "ඔවුන්ට එය අවශ්‍යයි"
#         },
#         {
#             "incorrect": "මට ගතහැක ඇඳපැළඳ ",
#             "correct": "මට ඇඳපැළඳ ගතහැක"
#         },
#         {
#             "incorrect": "එය  ඇය ලියයි",
#             "correct": "ඇය එය ලියයි"
#         },
#         {
#             "incorrect": "අපි කරමු කතා ",
#             "correct": "අපි කතා කරමු"
#         },
#         {
#             "incorrect": "එය සතුයි ඔවුන් ",
#             "correct": "එය ඔවුන් සතුයි"
#         },
#         {
#             "incorrect": "එය  මම නැරඹුවෙමි",
#             "correct": "මම එය නැරඹුවෙමි"
#         },
#         {
#             "incorrect": "කතා  මම කරන්නෙමි",
#             "correct": "මම කතා කරන්නෙමි"
#         },
#         {
#             "incorrect": "ඔහු ගත්තේය මිලට ",
#             "correct": "ඔහු මිලට ගත්තේය"
#         },
#         {
#             "incorrect": "අපි කළෙමු නිමා ",
#             "correct": "අපි නිමා කළෙමු"
#         },
#         {
#             "incorrect": "යන්නෙ ඔහු කොහිද?",
#             "correct": "ඔහු යන්නෙ කොහිද?"
#         },
#         {
#             "incorrect": "දුක්වන්නේ ඔබ ඇයි?",
#             "correct": "ඔබ දුක්වන්නේ ඇයි?"
#         },
#         {
#             "incorrect": "කැමති ඔබ කොහොමද?",
#             "correct": "ඔබ කැමති කොහොමද?"
#         },
#         {
#             "incorrect": "කොතරම් එය විශාලද?",
#             "correct": "එය කොතරම් විශාලද?"
#         },
#         {
#             "incorrect": "ඔහු නොමැත මෙහි ",
#             "correct": "ඔහු මෙහි නොමැත"
#         },
#         {
#             "incorrect": "මෙය නොවෙයි මගේ ",
#             "correct": "මෙය මගේ නොවෙයි"
#         },
#         {
#             "incorrect": "මම නොකරමි කතා ",
#             "correct": "මම කතා නොකරමි"
#         },
#         {
#             "incorrect": "මම නොලියමි පොත ",
#             "correct": "මම පොත නොලියමි"
#         },
#         {
#             "incorrect": "රිය  මම නොපදවමි",
#             "correct": "මම රිය නොපදවමි"
#         },
#         {
#             "incorrect": "ආදරය  මම නොකරමි",
#             "correct": "මම ආදරය නොකරමි"
#         },
#         {
#             "incorrect": "පොත මම නොදෙමි",
#             "correct": "මම පොත නොදෙමි"
#         },
#         {
#             "incorrect": "මම නොවෙමි සිනා ",
#             "correct": "මම සිනා නොවෙමි"
#         },
#         {
#             "incorrect": "මම නොගනිමි පොත ",
#             "correct": "මම පොත නොගනිමි"
#         },
#         {
#             "incorrect": "කතා ඔහු නොකරයි",
#             "correct": "ඔහු කතා නොකරයි"
#         },
#         {
#             "incorrect": "පොත මහු නොලියයි",
#             "correct": "මහු පොත නොලියයි"
#         },
#         {
#             "incorrect": "ඔහු නොපදවයි රිය ",
#             "correct": "ඔහු රිය නොපදවයි"
#         },
#         {
#             "incorrect": "ආදරය ඔහු නොකරයි",
#             "correct": "ඔහු ආදරය නොකරයි"
#         },
#         {
#             "incorrect": "පොත ඔහු නොදෙයි",
#             "correct": "ඔහු පොත නොදෙයි"
#         },
#         {
#             "incorrect": "සිනා ඔහු නොවෙයි",
#             "correct": "ඔහු සිනා නොවෙයි"
#         },
#         {
#             "incorrect": "ඔහු නොගනියි පොත ",
#             "correct": "ඔහු පොත නොගනියි"
#         },
#         {
#             "incorrect": "අපි නොකරමු කතා ",
#             "correct": "අපි කතා නොකරමු"
#         },
#         {
#             "incorrect": "පොත අපි නොලියමු",
#             "correct": "අපි පොත නොලියමු"
#         },
#         {
#             "incorrect": "අපි නොපදවමු රිය ",
#             "correct": "අපි රිය නොපදවමු"
#         },
#         {
#             "incorrect": "ආදරය අපි නොකරමු",
#             "correct": "අපි ආදරය නොකරමු"
#         },
#         {
#             "incorrect": "අපි නොදෙමු පොත ",
#             "correct": "අපි පොත නොදෙමු"
#         },
#         {
#             "incorrect": "සිනා අපි නොවෙමු",
#             "correct": "අපි සිනා නොවෙමු"
#         },
#         {
#             "incorrect": "මම කරමි කතා ",
#             "correct": "මම කතා කරමි"
#         },
#         {
#             "incorrect": "කතා ඔබ කරන්නෙහි",
#             "correct": "ඔබ කතා කරන්නෙහි"
#         },
#         {
#             "incorrect": "ඔහු කරයි කතා ",
#             "correct": "ඔහු කතා කරයි"
#         },
#         {
#             "incorrect": "කතා ඇය කරයි",
#             "correct": "ඇය කතා කරයි"
#         },
#         {
#             "incorrect": "අපි කරමු කතා ",
#             "correct": "අපි කතා කරමු"
#         },
#         {
#             "incorrect": "කතා ඔවුහු කරති",
#             "correct": "ඔවුහු කතා කරති"
#         },
#         {
#             "incorrect": "ගණන් මේක වැඩියි",
#             "correct": "මේක ගණන් වැඩියි"
#         },
#         {
#             "incorrect": "මෙහෙට ඔයා කැමතිද?",
#             "correct": "ඔයා මෙහෙට කැමතිද?"
#         },
#         {
#             "incorrect": "යන්නෙ මම කොහොමද?",
#             "correct": "මම යන්නෙ කොහොමද?"
#         },
#         {
#             "incorrect": "ප්‍රශ්නයක් මට  තියෙනවා ",
#             "correct": "මට ප්‍රශ්නයක් තියෙනවා "
#         },
#         {
#             "incorrect": "කරුණාකර කියන්න මට ",
#             "correct": "කරුණාකර මට කියන්න"
#         },
#         {
#             "incorrect": "මම කථා නැහැ කරන්නේ",
#             "correct": "මම කථා කරන්නේ නැහැ "
#         },
#         {
#             "incorrect": "මම  නැහැ ගන්නේ",
#             "correct": "මම ගන්නේ නැහැ "
#         },
#         {
#             "incorrect": "නැවත ඒක කියන්න ",
#             "correct": "ඒක නැවත කියන්න "
#         },
#         {
#             "incorrect": "මට  අවශ්‍යයි තොරතුරු",
#             "correct": "මට තොරතුරු අවශ්‍යයි "
#         },
#         {
#             "incorrect": "කාමර ඔබට තිබේද? ",
#             "correct": "ඔබට කාමර තිබේද? "
#         },
#         {
#             "incorrect": "කෑම උදෑසන ඇතුළත්ද? ",
#             "correct": "උදෑසන කෑම ඇතුළත්ද? "
#         },
#         {
#             "incorrect": "කාමරයක් මට ඕනේ ",
#             "correct": "මට කාමරයක් ඕනේ "
#         },
#         {
#             "incorrect": "මට ඕනේ කාමරයක් ",
#             "correct": "මට කාමරයක් ඕනේ "
#         },
#         {
#             "incorrect": "යන්ත්‍රය උකස් කොහේද? ",
#             "correct": "උකස් යන්ත්‍රය කොහේද? "
#         },
#         {
#             "incorrect": "කරගන්න කාමරයක් බුක් ඕනේ ",
#             "correct": "කාමරයක් බුක් කරගන්න ඕනේ "
#         },
#         {
#             "incorrect": "ආරක්ෂිතව මම සිටිනවා ",
#             "correct": "මම ආරක්ෂිතව සිටිනවා "
#         },
#         {
#             "incorrect": "උදේ ඇහැරවන්න මාව ",
#             "correct": "උදේ මාව ඇහැරවන්න "
#         },
#         {
#             "incorrect": "බිළිඳුන්ට ඕනේ කූඩයක් ",
#             "correct": "බිළිඳුන්ට කූඩයක් ඕනේ "
#         },
#         {
#             "incorrect": "මිල වට්ටමේ කීයද?",
#             "correct": "වට්ටමේ මිල කීයද?"
#         },
#         {
#             "incorrect": "එය මිලයි වැඩි ",
#             "correct": "එය වැඩි මිලයි"
#         },
#         {
#             "incorrect": "වර්ණයක් මෙයට තිබේද? ",
#             "correct": "මෙයට  වර්ණයක් තිබේද? "
#         },
#         {
#             "incorrect": "මම ඕන දෙන්න  ",
#             "correct": "මම දෙන්න ඕන "
#         },
#         {
#             "incorrect": "ඇලර්ජියක් මට තියෙනවා ",
#             "correct": "මට ඇලර්ජියක් තියෙනවා "
#         },
#         {
#             "incorrect": "මේකට මම කැමතියි ",
#             "correct": "මම මේකට කැමතියි "
#         },
#         {
#             "incorrect": "යන්න මට ඕන",
#             "correct": "මට යන්න ඕන"
#         },
#         {
#             "incorrect": "මගේ  සුදුයි බල්ලා",
#             "correct": "මගේ බල්ලා සුදුයි"
#         },
#         {
#             "incorrect": "කඩේ එයාලා යනවා",
#             "correct": "එයාලා කඩේ යනවා"
#         },
#         {
#             "incorrect": "මේ වහිනවා වෙලාවේ ",
#             "correct": "මේ වෙලාවේ වහිනවා"
#         },
#         {
#             "incorrect": "වැනිලා මම වලට කැමතියි",
#             "correct": "මම වැනිලා වලට කැමතියි"
#         },
#         {
#             "incorrect": "ඉර දිලිසෙනවා එළියෙන් ",
#             "correct": "ඉර එළියෙන් දිලිසෙනවා"
#         },
#         {
#             "incorrect": "අයිස් මම වලට කැමතියි",
#             "correct": "මම අයිස් වලට කැමතියි"
#         },
#         {
#             "incorrect": "මට ඉන්නවා බල්ලෙක්",
#             "correct": "මට බල්ලෙක් ඉන්නවා "
#         },
#         {
#             "incorrect": "අපි නගරයේ නිව්යෝර්ක් ",
#             "correct": "අපි නිව්යෝර්ක් නගරයේ"
#         },
#         {
#             "incorrect": "කලිසමක් ඔහු කළු ඇඳ ගෙන සිටී",
#             "correct": "ඔහු කළු කලිසමක් ඇඳ ගෙන සිටී"
#         },
#         {
#             "incorrect": "උද්යානයට ඔවුන් ගියා",
#             "correct": "ඔවුන් උද්යානයට ගියා"
#         },
#         {
#             "incorrect": "යාළුවෝ එක්ක කරන්න සෙල්ලම්",
#             "correct": "යාළුවෝ එක්ක සෙල්ලම් කරන්න"
#         },
#         {
#             "incorrect": "යහන මත නිදාසිටී බළලා",
#             "correct": "බළලා යහන මත නිදාසිටී"
#         },
#         {
#             "incorrect": "බල්ලා පනිනවා තටාකයට",
#             "correct": "බල්ලා තටාකයට පනිනවා"
#         },
#         {
#             "incorrect": "කැමති මම කෑමකට",
#             "correct": "මම කැමති කෑමකට"
#         },
#         {
#             "incorrect": "අම්මා ආදරෙයි ගොඩක් ",
#             "correct": "අම්මා ගොඩක් ආදරෙයි"
#         },
#         {
#             "incorrect": "මම කරනවා වැඩ ",
#             "correct": "මම වැඩ කරනවා"
#         },
#         {
#             "incorrect": "මම  ගියා කඩේට",
#             "correct": "මම කඩේට ගියා"
#         },
#         {
#             "incorrect": "මගේ නම ස්මිත් ජෝන් ",
#             "correct": "මගේ නම ජෝන් ස්මිත්"
#         },
#         {
#             "incorrect": "අද රස්නෙයි ඉර ",
#             "correct": "අද ඉර රස්නෙයි"
#         },
#         {
#             "incorrect": "ගෙයක් අපිට තියෙනවා",
#             "correct": "අපිට ගෙයක් තියෙනවා"
#         },
#         {
#             "incorrect": "අපි  ඩ්රයිව්කලා රෑම",
#             "correct": "අපි රෑම ඩ්රයිව්කලා"
#         },
#         {
#             "incorrect": "ආයෙත් ඔයා පරක්කුයි",
#             "correct": "ඔයා ආයෙත් පරක්කුයි"
#         },
#         {
#             "incorrect": "බල්ලා විය බුරන්නට ",
#             "correct": "බල්ලා බුරන්නට විය"
#         },
#         {
#             "incorrect": "වටේ බල්ලා දිව්වා",
#             "correct": "බල්ලා වටේ දිව්වා"
#         },
#         {
#             "incorrect": "පූසා  කෑගැහුවා හයියෙන්",
#             "correct": "පූසා හයියෙන් කෑගැහුවා"
#         },
#         {
#             "incorrect": "අයියා ආසයි කන්න සැන්ඩ්විච් ",
#             "correct": "අයියා ආසයි සැන්ඩ්විච් කන්න"
#         },
#         {
#             "incorrect": "මම  යන්න ආසයි සාලෙට",
#             "correct": "මම ආසයි සාලෙට යන්න"
#         },
#         {
#             "incorrect": "හරිම ආසයි ආච්චි කේක් හදන්න ",
#             "correct": "ආච්චි කේක් හදන්න හරිම ආසයි"
#         },
#         {
#             "incorrect": "සීයා නිවස වටා සවි කිරීමට ආසයි  ඇති දේවල්",
#             "correct": "සීයා නිවස වටා ඇති දේවල් සවි කිරීමට ආසයි"
#         },
#         {
#             "incorrect": "එයාලට  සල්ලියක්නෑ කිසිම",
#             "correct": "එයාලට කිසිම සල්ලියක්නෑ"
#         },
#         {
#             "incorrect": "දීප්තිමත්ව හිරු  දිලිසෙනවා",
#             "correct": "හිරු දීප්තිමත්ව දිලිසෙනවා"
#         },
#         {
#             "incorrect": "මම  ආසයි කියවන්න",
#             "correct": "මම කියවන්න ආසයි"
#         },
#         {
#             "incorrect": "පියානෝවාදනයට ඇය  ආසයි",
#             "correct": "ඇය පියානෝවාදනයට ආසයි"
#         },
#         {
#             "incorrect": "ඉන්නේ එයාලා ගෙදරක",
#             "correct": "එයාලා ඉන්නේ ගෙදරක"
#         },
#         {
#             "incorrect": "බළලුන් දිව්වා  වටේ ",
#             "correct": "බළලුන් වටේ දිව්වා"
#         },
#         {
#             "incorrect": "මල් වසන්තයේදීය පිපෙන්නේ ",
#             "correct": "මල් පිපෙන්නේ වසන්තයේදීය"
#         },
#         {
#             "incorrect": "උදේට එයා දුවනවා",
#             "correct": "එයා උදේට දුවනවා"
#         },
#         {
#             "incorrect": "අපි  පීසා කෑවා රෑකෑමට",
#             "correct": "අපි රෑකෑමට පීසා කෑවා"
#         },
#         {
#             "incorrect": "හයියෙන් බල්ලා  බුරනවා",
#             "correct": "බල්ලා හයියෙන් බුරනවා"
#         },
#         {
#             "incorrect": "කුරුල්ලෝ කියනවා සින්දු ",
#             "correct": "කුරුල්ලෝ සින්දු කියනවා"
#         },
#         {
#             "incorrect": "ගලා ගංගාව යයි",
#             "correct": "ගංගාව ගලා යයි"
#         },
#         {
#             "incorrect": "මම තේ  ආසයි බොන්න",
#             "correct": "මම තේ බොන්න ආසයි"
#         },
#         {
#             "incorrect": "ඇය හැටි බලනවා ඉර බහින ",
#             "correct": "ඇය ඉර බහින හැටි බලනවා"
#         },
#         {
#             "incorrect": "ඔවුන් යනවා නිතර ",
#             "correct": "ඔවුන් නිතර යනවා"
#         },
#         {
#             "incorrect": "අද පිරිලා  රෑ හඳ",
#             "correct": "අද රෑ හඳ පිරිලා"
#         },
#         {
#             "incorrect": "සිල්ලරබඩු මට  ගන්න ඕන",
#             "correct": "මට සිල්ලරබඩු ගන්න ඕන"
#         },
#         {
#             "incorrect": "එයා කරන්නෙ වැඩ ",
#             "correct": "එයා වැඩ කරන්නෙ "
#         },
#         {
#             "incorrect": "අපි වැව්වා වත්තක්",
#             "correct": "අපි වත්තක් වැව්වා"
#         },
#         {
#             "incorrect": "කාර් නිල්පාටයි එක ",
#             "correct": "කාර් එක නිල්පාටයි"
#         },
#         {
#             "incorrect": "ඇය බේක්කරයි කුකීස්",
#             "correct": "ඇය කුකීස් බේක්කරයි"
#         },
#         {
#             "incorrect": "කුරුල්ලන් සාදයි කූඩු ",
#             "correct": "කුරුල්ලන් කූඩු සාදයි"
#         },
#         {
#             "incorrect": "ඔහු පුස්තකාලයේ ඉන්නේ ",
#             "correct": "ඔහු ඉන්නේ පුස්තකාලයේ"
#         },
#         {
#             "incorrect": "බබා වෙනවා හිනා ",
#             "correct": "බබා හිනා වෙනවා"
#         },
#         {
#             "incorrect": "ක්රීඩා ඔවුන් කරයි",
#             "correct": "ඔවුන් ක්රීඩා කරයි"
#         },
#         {
#             "incorrect": "කන්ද උසයි හරි ",
#             "correct": "කන්ද හරි උසයි"
#         },
#         {
#             "incorrect": "මට ඇහෙනවා මුහුද ",
#             "correct": "මට මුහුද ඇහෙනවා"
#         },
#         {
#             "incorrect": "ලියුමක් එයා ලිව්වා",
#             "correct": "එයා ලියුමක් ලිව්වා"
#         },
#         {
#             "incorrect": "අපි පැදුවා බයිසිකල් ",
#             "correct": "අපි බයිසිකල් පැදුවා"
#         },
#         {
#             "incorrect": "රත් කෝපි  වෙලා",
#             "correct": "කෝපි රත් වෙලා"
#         },
#         {
#             "incorrect": "ඔහු පිහිනයි  තටාකයේ ",
#             "correct": "ඔහු තටාකයේ පිහිනයි"
#         },
#         {
#             "incorrect": "හිම ශීතඍතුවේ වැටෙනවා",
#             "correct": "ශීතඍතුවේ හිම වැටෙනවා"
#         },
#         {
#             "incorrect": "ඔවුන් ගියා යුරෝපයට ",
#             "correct": "ඔවුන් යුරෝපයට ගියා"
#         },
#         {
#             "incorrect": "මම බැලුවා ෆිල්ම් ",
#             "correct": "මම ෆිල්ම් බැලුවා"
#         },
#         {
#             "incorrect": "ලස්සනට ඇය නටනවා",
#             "correct": "ඇය ලස්සනට නටනවා"
#         },
#         {
#             "incorrect": "දුරකථනය විය නාද ",
#             "correct": "දුරකථනය නාද විය"
#         },
#         {
#             "incorrect": "කඳුකරයේ අපි නැග්ගා",
#             "correct": "අපි කඳුකරයේ නැග්ගා"
#         },
#         {
#             "incorrect": "ගසෙහි ඇත කොළ ",
#             "correct": "ගසෙහි කොළ ඇත"
#         },
#         {
#             "incorrect": "උයන්න එයා ආසයි",
#             "correct": "එයා උයන්න ආසයි"
#         },
#         {
#             "incorrect": "සංක්රමණය කුරුල්ලන්  වේ",
#             "correct": "කුරුල්ලන් සංක්රමණය වේ"
#         },
#         {
#             "incorrect": "මට ඕනේ ජැකට් ",
#             "correct": "මට ජැකට් ඕනේ"
#         },
#         {
#             "incorrect": "ඇය ඇන්දා චිත්‍රරයක් ",
#             "correct": "ඇය චිත්‍රරයක් ඇන්දා "
#         },
#         {
#             "incorrect": "කල් තරඟය දැම්මා.",
#             "correct": "තරඟය කල් දැම්මා."
#         },
#         {
#             "incorrect": "හෙට වහිනවා දවසම ",
#             "correct": "හෙට දවසම වහිනවා"
#         },
#         {
#             "incorrect": "පාපන්දු ජේක් ක්‍රීඩාකළා",
#             "correct": "ජේක් පාපන්දු ක්‍රීඩාකළා"
#         },
#         {
#             "incorrect": "ෆිල්ම් සාරා බැලුවා",
#             "correct": "සාරා ෆිල්ම් බැලුවා"
#         },
#         {
#             "incorrect": "දවසම බළලා නිදාගත්තා",
#             "correct": "බළලා දවසම නිදාගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන් පිරිසිදුකළා  කාමරය ",
#             "correct": "ඔවුන් කාමරය පිරිසිදුකළා"
#         },
#         {
#             "incorrect": "කිචිබිචි කුරුල්ලා  ගාන්නට විය",
#             "correct": "කුරුල්ලා  කිචිබිචි ගාන්නට විය"
#         },
#         {
#             "incorrect": "ඔහු ගියේය බැලීමට ",
#             "correct": "ඔහු බැලීමට ගියේය"
#         },
#         {
#             "incorrect": "අවසන් ටිම් ආහාරය කළේය",
#             "correct": "ටිම් ආහාරය අවසන් කළේය"
#         },
#         {
#             "incorrect": "නතර විය මෝටර්රථය",
#             "correct": "මෝටර්රථය නතර විය"
#         },
#         {
#             "incorrect": "අපි දැක්කා දේදුන්නක්",
#             "correct": "අපි දේදුන්නක් දැක්කා"
#         },
#         {
#             "incorrect": "සාදයේදී නැටුවා සෑම් ",
#             "correct": "සාදයේදී සෑම් නැටුවා"
#         },
#         {
#             "incorrect": "ජැක් කළේය ක්‍රීඩා ",
#             "correct": "ජැක් ක්‍රීඩා කළේය"
#         },
#         {
#             "incorrect": "කුකීස් ලීසා පිළිස්සුවාය",
#             "correct": "ලීසා කුකීස් පිළිස්සුවාය"
#         },
#         {
#             "incorrect": "ටොම් ගියේය ඇවිද ",
#             "correct": "ටොම් ඇවිද ගියේය"
#         },
#         {
#             "incorrect": "නිවාඩුවට සාරා ගියාය",
#             "correct": "සාරා නිවාඩුවට ගියාය"
#         },
#         {
#             "incorrect": "චිත්‍රපටයක් අපි නැරඹුවෙමු",
#             "correct": "අපි චිත්‍රපටයක් නැරඹුවෙමු"
#         },
#         {
#             "incorrect": "ලුහුබැඳ බළලා ගියේය",
#             "correct": "බළලා ලුහුබැඳ ගියේය"
#         },
#         {
#             "incorrect": "පින්තාරු පින්තූරයක්  කළා",
#             "correct": "පින්තූරයක් පින්තාරු කළා"
#         },
#         {
#             "incorrect": "කුස්සිය ඇලෙක්ස්  පිරිසිදු කළේය",
#             "correct": "ඇලෙක්ස් කුස්සිය පිරිසිදු කළේය"
#         },
#         {
#             "incorrect": "බැස හිරු ගියේය",
#             "correct": "හිරු බැස ගියේය"
#         },
#         {
#             "incorrect": "ඉගෙන සිසු ගත්හ",
#             "correct": "සිසු ඉගෙන ගත්හ"
#         },
#         {
#             "incorrect": "ඉස්කෝලේ ජේක් ගියේය",
#             "correct": "ජේක් ඉස්කෝලේ ගියේය"
#         },
#         {
#             "incorrect": "ප්‍රසංගයේදී ලුසී නැටුවාය",
#             "correct": "ලුසී ප්‍රසංගයේදී නැටුවාය"
#         },
#         {
#             "incorrect": "ඔවුන් ඉදිකළහ වැලිමාලිගාවක්",
#             "correct": "ඔවුන් වැලිමාලිගාවක් ඉදිකළහ"
#         },
#         {
#             "incorrect": "අපි  නැරඹුවෙමු චිත්‍රපටයක්",
#             "correct": "අපි චිත්‍රපටයක් නැරඹුවෙමු"
#         },
#         {
#             "incorrect": "චාරිකාවක් අපි යනවා",
#             "correct": "අපි චාරිකාවක් යනවා"
#         },
#         {
#             "incorrect": "වැස්ස විය නතර ",
#             "correct": "වැස්ස නතර විය"
#         },
#         {
#             "incorrect": "මිතුරිය සමන්තා ඇමතුවාය",
#             "correct": "සමන්තා මිතුරිය ඇමතුවාය"
#         },
#         {
#             "incorrect": "මැක්ස්  ගියා ගමනක්",
#             "correct": "මැක්ස් ගමනක් ගියා"
#         },
#         {
#             "incorrect": "එක බයික් හදන්න",
#             "correct": "බයික් එක හදන්න"
#         },
#         {
#             "incorrect": "ටයර්  හදන්න එක",
#             "correct": "ටයර් එක හදන්න"
#         },
#         {
#             "incorrect": "ගුරුවරයා කියෙව්වා කතාවක් ",
#             "correct": "ගුරුවරයා කතාවක් කියෙව්වා"
#         },
#         {
#             "incorrect": "ක්‍රීඩා මයික් කළේය",
#             "correct": "මයික් ක්‍රීඩා කළේය"
#         },
#         {
#             "incorrect": "ඇමී දුටුවේය සතුන්",
#             "correct": "ඇමී සතුන් දුටුවේය"
#         },
#         {
#             "incorrect": "ජේසන් නැග්ගා කන්ද ",
#             "correct": "ජේසන් කන්ද නැග්ගා"
#         },
#         {
#             "incorrect": "කන්ද ජේසන් නැග්ගාද?",
#             "correct": "ජේසන් කන්ද නැග්ගාද?"
#         },
#         {
#             "incorrect": "මම නැග්ගේමි කන්ද ",
#             "correct": "මම කන්ද නැග්ගේමි"
#         },
#         {
#             "incorrect": "එක කාටූන් මොකක්ද?",
#             "correct": "කාටූන් එක මොකක්ද?"
#         },
#         {
#             "incorrect": "අත්පුඩි බබා ගැහුවා",
#             "correct": "බබා අත්පුඩි ගැහුවා"
#         },
#         {
#             "incorrect": "බල්ලා  ගියේය දිව",
#             "correct": "බල්ලා දිව ගියේය"
#         },
#         {
#             "incorrect": "අල්ලා පන්දුව ගත්තද?",
#             "correct": "පන්දුව අල්ලා  ගත්තද?"
#         },
#         {
#             "incorrect": "ලීසා කළාය උදව් ",
#             "correct": "ලීසා උදව් කළාය"
#         },
#         {
#             "incorrect": "මේකට බල්ලා කැමතිද?",
#             "correct": "බල්ලා මේකට කැමතිද?"
#         },
#         {
#             "incorrect": "කතාවට ගුරුවරයා කැමතිද? ",
#             "correct": "ගුරුවරයා කතාවට කැමතිද? "
#         },
#         {
#             "incorrect": "ටිම්ට හැරුනා මග ",
#             "correct": "ටිම්ට මග හැරුනා"
#         },
#         {
#             "incorrect": "මල් ලස්සනට වසන්තයේ පිපෙනවා",
#             "correct": "වසන්තයේ මල් ලස්සනට පිපෙනවා"
#         },
#         {
#             "incorrect": "උපන්දිනය සාරා සැමරුවාය ",
#             "correct": "සාරා උපන්දිනය සැමරුවාය "
#         },
#         {
#             "incorrect": "අපි වෙමු පුදුම ",
#             "correct": "අපි පුදුම වෙමු"
#         },
#         {
#             "incorrect": "ලිපියක් සාරා ලිව්වාය",
#             "correct": "සාරා ලිපියක් ලිව්වාය"
#         },
#         {
#             "incorrect": "පෙට්ටියක් ළමයා සොයා ගත්තේය",
#             "correct": "ළමයා පෙට්ටියක් සොයා ගත්තේය"
#         },
#         {
#             "incorrect": "නිධන් අපි සොයා ගත්තෙමු ",
#             "correct": "අපි නිධන් සොයා ගත්තෙමු "
#         },
#         {
#             "incorrect": "දියඇල්ලක් අපි සොයා ගත්තෙමු",
#             "correct": "අපි දියඇල්ලක් සොයා ගත්තෙමු"
#         },
#         {
#             "incorrect": "පුවරුක්‍රීඩා ඔවුහු කළහ",
#             "correct": "ඔවුහු පුවරුක්‍රීඩා කළහ"
#         }
#     ],
#     "pronoun_ending_match": [
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "ු,"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "නෑ"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ඳා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "අපි",
#             "end": "ඳා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ැත"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "හැ"
#         },
#         {
#             "start": "මම",
#             "end": "හැ"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "ඕන"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "අපි",
#             "end": "යේ"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "යා"
#         },
#         {
#             "start": "අපි",
#             "end": "ලා"
#         },
#         {
#             "start": "මම",
#             "end": "්න"
#         },
#         {
#             "start": "මම",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යේ"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "කා"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         }
#     ],
#     "verb_conjugation": [
#         {
#             "incorrect": "සරුංගලය",
#             "correct": "හැඩයි"
#         },
#         {
#             "incorrect": "නිවේදනය",
#             "correct": "කරයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "මතකයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "අමුණයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "හැඟෙයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "ඇසෙයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "තෝරාගනියි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "කියවයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "මතකයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "පෙනෙයි"
#         },
#         {
#             "incorrect": "ඇය",
#             "correct": "ස්තූතියි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "අවශ්‍යයි"
#         },
#         {
#             "incorrect": "රිය",
#             "correct": "නොපදවයි"
#         }
#     ]
# }
# Accuracy of the rule-based correction system: 80.17%
# Original Sentence: පාසැල් දරුවා  ගියේය
# Corrected Sentence: දරුවා පාසැල් ගියේය

# %%
import re
import difflib

def preprocess_text(text):
    """
    Preprocess the given text by removing unwanted characters and normalizing it.
    This function keeps only Sinhala characters and spaces.
    """
    text = re.sub(r'[^\u0D80-\u0DFF\s]', '', text)
    text = text.strip().lower()
    return text

def tokenize(text):
    """
    Tokenize the text by splitting it into individual words based on spaces.
    """
    return text.split()

def load_data(sentences_path, dictionary_path):
    """
    Load sentences with their labels and the Sinhala dictionary.
    """
    sentences = []
    with open(sentences_path, 'r', encoding='utf-8') as f:
        for line in f:
            label, sentence = line.strip().split(' ', 1)
            sentences.append((int(label), sentence))

    with open(dictionary_path, 'r', encoding='utf-8') as f:
        dictionary = set(f.read().splitlines())

    return sentences, dictionary

def spell_check(sentence, dictionary):
    """
    Identify misspelled words in a sentence.
    """
    words = tokenize(preprocess_text(sentence))
    misspelled = [word for word in words if word not in dictionary]
    return misspelled

def auto_correct(sentence, dictionary):
    """
    Automatically correct misspelled words using the closest match in the dictionary.
    """
    words = tokenize(preprocess_text(sentence))
    corrected_words = []
    for word in words:
        if word in dictionary:
            corrected_words.append(word)
        else:
            closest_matches = difflib.get_close_matches(word, dictionary, n=1)
            corrected_words.append(closest_matches[0] if closest_matches else word)
    return ' '.join(corrected_words)

def basic_grammar_check(sentence):
    """
    Perform a basic grammar check on a sentence.
    - Checks for repeated words.
    - Checks for missing punctuation.
    """
    grammar_issues = []
    words = tokenize(preprocess_text(sentence))

    for i in range(len(words) - 1):
        if words[i] == words[i + 1]:
            grammar_issues.append(f"Repeated word: '{words[i]}'")

    if not re.match(r'.*[.!?]$', sentence.strip()):
        grammar_issues.append("The sentence does not end with proper punctuation (., !, ?).")

    return grammar_issues

def auto_correct_grammar(sentence):
    """
    Automatically correct basic grammar issues:
    - Removes repeated words.
    - Adds missing punctuation at the end.
    """
    words = tokenize(preprocess_text(sentence))
    corrected_words = []

    for i in range(len(words)):
        if i == 0 or words[i] != words[i - 1]:
            corrected_words.append(words[i])

    corrected_text = ' '.join(corrected_words)

    if not re.match(r'.*[.!?]$', corrected_text.strip()):
        corrected_text += '.'

    return corrected_text

def evaluate_input(paragraph, dictionary):
    """
    Evaluate the input paragraph by correcting spelling and grammar in each sentence.
    Returns the corrected paragraph and the accuracy of the corrections.
    """
    sentences = paragraph.split('.')  # Split paragraph into sentences
    corrected_sentences = []
    total_sentences = len(sentences)
    corrected_count = 0  # To track how many sentences were corrected

    for sentence in sentences:
        sentence = sentence.strip()
        if not sentence:
            continue

        # Preprocess the original sentence for comparison later
        original_clean = preprocess_text(sentence)

        # Correct spelling
        corrected_spelling = auto_correct(sentence, dictionary)

        # Correct grammar
        corrected_grammar = auto_correct_grammar(corrected_spelling)

        corrected_clean = preprocess_text(corrected_grammar)

        # Check if any correction was made
        if original_clean != corrected_clean:
            corrected_count += 1

        corrected_sentences.append(corrected_grammar.strip())

    # Combine corrected sentences into a paragraph
    corrected_paragraph = '. '.join(corrected_sentences) + '.'

    # Calculate accuracy: (number of corrected sentences / total sentences) * 100
    accuracy = (corrected_count / total_sentences) * 100 if total_sentences > 0 else 0

    return corrected_paragraph, accuracy

def main():
    # Paths to data files
    dictionary_path = "sinhala_dictionary.txt"  # Dictionary file

    # Load dictionary
    with open(dictionary_path, 'r', encoding='utf-8') as f:
        dictionary = set(f.read().splitlines())

    # Example input for testing
    input_paragraph = input("Enter a paragraph to check spelling and grammar (separate sentences with '.'): ")

    # Evaluate the input paragraph
    corrected_paragraph, accuracy = evaluate_input(input_paragraph, dictionary)

    # Output the results
    print("\nCorrected Paragraph (Spelling & Grammar Fixed):")
    print(corrected_paragraph)
    print(f"\nAccuracy of the spell and grammar checker: {accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Enter a paragraph to check spelling and grammar (separate sentences with '.'): මම දවස්පරා පාඩම කරම. බලලා යහන මත නිදසටී. පූසා හයයෙන් කෑගහවා. ගසෙහි ඇත  කොළ. මම රම පීසා කවා. දප්තිමත්ව හිරු දිලසෙන. අප ආහාර සකසා ගත්තෙය.ඔහු පාසල් යති.. මම ආහාර පිළියෙළ කරමු .ඔහු පාසල් යති. ඔහු පාසල් යයි .
#
# Corrected Paragraph (Spelling & Grammar Fixed):
# මම විස්තර පාඩම කරමු.. බල්ලා යහන මත නිදාසිටී.. පූසා හයියෙන් කෑගැහුවා.. ගසෙහි ඇත කොළ.. මම රෑම පීසා කෑවා.. දීප්තිමත්ව හිරු දිලිසෙනවා.. අප ආහාර සේවකයා ගත්තේය.. ඔහු පාසල් යති.. මම ආහාර පිළියෙළ කරමු.. ඔහු පාසල් යති.. ඔහු පාසල් යයි..
#
# Accuracy of the spell and grammar checker: 53.85%

# %%
import re
import difflib

def preprocess_text(text):
    """
    Preprocess the given text by removing unwanted characters and normalizing it.
    This function keeps only Sinhala characters and spaces.
    """
    text = re.sub(r'[^\u0D80-\u0DFF\s]', '', text)
    text = text.strip().lower()
    return text

def tokenize(text):
    """
    Tokenize the text by splitting it into individual words based on spaces.
    """
    return text.split()

def load_data(sentences_path, dictionary_path):
    """
    Load sentences with their labels and the Sinhala dictionary.
    """
    sentences = []
    with open(sentences_path, 'r', encoding='utf-8') as f:
        for line in f:
            label, sentence = line.strip().split(' ', 1)
            sentences.append((int(label), sentence))

    with open(dictionary_path, 'r', encoding='utf-8') as f:
        dictionary = set(f.read().splitlines())

    return sentences, dictionary

def spell_check(sentence, dictionary):
    """
    Identify misspelled words in a sentence.
    """
    words = tokenize(preprocess_text(sentence))
    misspelled = [word for word in words if word not in dictionary]
    return misspelled

def auto_correct(sentence, dictionary):
    """
    Automatically correct misspelled words using the closest match in the dictionary.
    """
    words = tokenize(preprocess_text(sentence))
    corrected_words = []
    for word in words:
        if word in dictionary:
            corrected_words.append(word)
        else:
            closest_matches = difflib.get_close_matches(word, dictionary, n=1)
            corrected_words.append(closest_matches[0] if closest_matches else word)
    return ' '.join(corrected_words)

def basic_grammar_check(sentence):
    """
    Perform a basic grammar check on a sentence.
    - Checks for repeated words.
    - Checks for missing punctuation.
    """
    grammar_issues = []
    words = tokenize(preprocess_text(sentence))

    for i in range(len(words) - 1):
        if words[i] == words[i + 1]:
            grammar_issues.append(f"Repeated word: '{words[i]}'")

    if not re.match(r'.*[.!?]$', sentence.strip()):
        grammar_issues.append("The sentence does not end with proper punctuation (., !, ?).")

    return grammar_issues

def auto_correct_grammar(sentence):
    """
    Automatically correct basic grammar issues:
    - Removes repeated words.
    - Adds missing punctuation at the end.
    """
    words = tokenize(preprocess_text(sentence))
    corrected_words = []

    for i in range(len(words)):
        if i == 0 or words[i] != words[i - 1]:
            corrected_words.append(words[i])

    corrected_text = ' '.join(corrected_words)

    if not re.match(r'.*[.!?]$', corrected_text.strip()):
        corrected_text += '.'

    return corrected_text

def evaluate(sentences, dictionary):
    """
    Evaluate the spell and grammar checker on the dataset.
    Calculates the accuracy based on correcting incorrect sentences (label = 1).
    """
    correct_count = 0
    total = len(sentences)

    for label, sentence in sentences:
        if label == 0:  # Correct sentence, skip evaluation
            correct_count += 1
            continue

        # Process incorrect sentences
        corrected_spelling = auto_correct(sentence, dictionary)
        corrected_grammar = auto_correct_grammar(corrected_spelling)

        # A simple assumption: Corrected sentence should match expected correct sentences in the dataset
        if corrected_grammar.strip() == preprocess_text(sentence).strip():
            correct_count += 1

    accuracy = (correct_count / total) * 100
    return accuracy

def main():
    # Paths to data files
    sentences_path = "sentences.txt"  # Dataset file
    dictionary_path = "sinhala_dictionary.txt"  # Dictionary file

    # Load data and dictionary
    sentences, dictionary = load_data(sentences_path, dictionary_path)

    # Evaluate the model
    accuracy = evaluate(sentences, dictionary)
    print(f"Accuracy of the spell and grammar checker: {accuracy:.2f}%")

    # Example input for testing
    input_sentence = input("Enter a sentence to check spelling and grammar: ")

    # Check spelling
    misspelled_words = spell_check(input_sentence, dictionary)
    if misspelled_words:
        print("Misspelled words found:", ", ".join(misspelled_words))
    else:
        print("No spelling errors found.")

    # Auto-correct spelling
    corrected_spelling = auto_correct(input_sentence, dictionary)
    print("Corrected Sentence (Spelling Fixed):")
    print(corrected_spelling)

    # Auto-correct grammar
    corrected_grammar = auto_correct_grammar(corrected_spelling)
    print("Corrected Sentence (Grammar Fixed):")
    print(corrected_grammar)

if __name__ == "__main__":
    main()
# Out:
# Accuracy of the spell and grammar checker: 82.73%
# Enter a sentence to check spelling and grammar: දරුවෝ  ගියහ පාසැල්
# No spelling errors found.
# Corrected Sentence (Spelling Fixed):
# දරුවෝ ගියහ පාසැල්
# Corrected Sentence (Grammar Fixed):
# දරුවෝ ගියහ පාසැල්.

# %%
import re
import difflib

def preprocess_text(text):
    """
    Preprocess the given text by removing unwanted characters and normalizing it.
    This function keeps only Sinhala characters and spaces.
    """
    text = re.sub(r'[^\u0D80-\u0DFF\s]', '', text)
    text = text.strip().lower()
    return text

def tokenize(text):
    """
    Tokenize the text by splitting it into individual words based on spaces.
    """
    return text.split()

def load_data(sentences_path, dictionary_path):
    """
    Load sentences with their labels and the Sinhala dictionary.
    """
    sentences = []
    with open(sentences_path, 'r', encoding='utf-8') as f:
        for line in f:
            label, sentence = line.strip().split(' ', 1)
            sentences.append((int(label), sentence))

    with open(dictionary_path, 'r', encoding='utf-8') as f:
        dictionary = set(f.read().splitlines())

    return sentences, dictionary

def spell_check(sentence, dictionary):
    """
    Identify misspelled words in a sentence.
    """
    words = tokenize(preprocess_text(sentence))
    misspelled = [word for word in words if word not in dictionary]
    return misspelled

def auto_correct(sentence, dictionary):
    """
    Automatically correct misspelled words using the closest match in the dictionary.
    """
    words = tokenize(preprocess_text(sentence))
    corrected_words = []
    for word in words:
        if word in dictionary:
            corrected_words.append(word)
        else:
            closest_matches = difflib.get_close_matches(word, dictionary, n=1)
            corrected_words.append(closest_matches[0] if closest_matches else word)
    return ' '.join(corrected_words)

def basic_grammar_check(sentence):
    """
    Perform a basic grammar check on a sentence.
    - Checks for repeated words.
    - Checks for missing punctuation.
    """
    grammar_issues = []
    words = tokenize(preprocess_text(sentence))

    for i in range(len(words) - 1):
        if words[i] == words[i + 1]:
            grammar_issues.append(f"Repeated word: '{words[i]}'")

    if not re.match(r'.*[.!?]$', sentence.strip()):
        grammar_issues.append("The sentence does not end with proper punctuation (., !, ?).")

    return grammar_issues

def auto_correct_grammar(sentence):
    """
    Automatically correct basic grammar issues:
    - Removes repeated words.
    - Adds missing punctuation at the end.
    """
    words = tokenize(preprocess_text(sentence))
    corrected_words = []

    for i in range(len(words)):
        if i == 0 or words[i] != words[i - 1]:
            corrected_words.append(words[i])

    corrected_text = ' '.join(corrected_words)

    if not re.match(r'.*[.!?]$', corrected_text.strip()):
        corrected_text += '.'

    return corrected_text

def process_paragraph(paragraph, dictionary):
    """
    Processes a paragraph by correcting spelling and grammar for each sentence.
    """
    sentences = paragraph.split('.')
    corrected_sentences = []

    for sentence in sentences:
        sentence = sentence.strip()
        if not sentence:
            continue

        # Correct spelling
        corrected_spelling = auto_correct(sentence, dictionary)

        # Correct grammar
        corrected_grammar = auto_correct_grammar(corrected_spelling)

        corrected_sentences.append(corrected_grammar.strip())

    # Combine sentences back into a paragraph
    corrected_paragraph = '. '.join(corrected_sentences) + '.'
    return corrected_paragraph

def evaluate(sentences, dictionary):
    """
    Evaluate the accuracy of the spell and grammar checker.
    """
    correct_count = 0
    total = len(sentences)

    for label, sentence in sentences:
        # Correct the sentence
        corrected_paragraph = process_paragraph(sentence, dictionary)

        # Preprocess for comparison
        corrected_clean = preprocess_text(corrected_paragraph)
        original_clean = preprocess_text(sentence)

        # Check if correction is successful
        if label == 0 and corrected_clean == original_clean:  # Already correct
            correct_count += 1
        elif label == 1 and corrected_clean != original_clean:  # Corrected incorrect sentence
            correct_count += 1

    accuracy = (correct_count / total) * 100
    return accuracy

def main():
    # Paths to data files
    sentences_path = "sentences.txt"  # Labeled dataset file
    dictionary_path = "sinhala_dictionary.txt"  # Dictionary file

    # Load data and dictionary
    sentences, dictionary = load_data(sentences_path, dictionary_path)

    # Evaluate accuracy
    accuracy = evaluate(sentences, dictionary)
    print(f"Accuracy of the spell and grammar checker: {accuracy:.2f}%")

    # Example input for testing
    input_paragraph = input("Enter a paragraph to check spelling and grammar: ")

    # Process paragraph
    corrected_paragraph = process_paragraph(input_paragraph, dictionary)

    print("\nCorrected Paragraph:")
    print(corrected_paragraph)

if __name__ == "__main__":
    main()
# Out:
# Accuracy of the spell and grammar checker: 16.47%
# Enter a paragraph to check spelling and grammar: දරුවෝ පාසැල් ගියෝ. උසිකාව බණ අසත. උපසකයා බණ ඇසුවේය. ගුරුවරයා සිසුන් කැඳවයි. මම අලුයම පිබිදෙය. ගස මල්වලින් පිර තිබේ.
#
# Corrected Paragraph:
# දරුවෝ පාසැල් ගියෝය.. උපාසිකාවෝ බණ අසති.. උපාසකයා බණ ඇසුවේය.. ගුරුවරයා සිසුන් කැඳවයි.. මම අලුයම පිබිදෙයි.. ගස මල්වලින් පිරී තිබේ..

# %%
import re
import difflib
import json


class RuleExtractor:
    def __init__(self, correct_sentences, incorrect_sentences):
        self.correct_sentences = correct_sentences
        self.incorrect_sentences = incorrect_sentences

    def extract_rules(self):
        rules = {
            "subject_verb_order": [],
            "pronoun_ending_match": [],
            "verb_conjugation": []  # New category
        }

        for correct, incorrect in zip(self.correct_sentences, self.incorrect_sentences):
            if correct != incorrect:
                correct_words = correct.split()
                incorrect_words = incorrect.split()

                # Subject-Verb order rule
                if sorted(correct_words) == sorted(incorrect_words):
                    rules["subject_verb_order"].append({
                        "incorrect": incorrect,
                        "correct": correct
                    })

                # Pronoun-ending match rule
                if len(correct_words) > 1 and len(incorrect_words) > 1:
                    pronoun = correct_words[0]
                    correct_ending = correct_words[-1][-2:]
                    incorrect_ending = incorrect_words[-1][-2:]
                    if pronoun in ["මම", "අපි", "ඔහු"] and correct_ending != incorrect_ending:
                        rules["pronoun_ending_match"].append({
                            "start": pronoun,
                            "end": correct_ending
                        })

                # Verb conjugation rule
                if len(correct_words) == len(incorrect_words):
                    for cw, iw in zip(correct_words, incorrect_words):
                        if cw != iw and cw.endswith("යි") and iw.endswith("ය"):
                            rules["verb_conjugation"].append({
                                "incorrect": iw,
                                "correct": cw
                            })

        # Save rules to a JSON file
        with open(".extracted_rules.json", "w", encoding="utf-8") as file:
            json.dump(rules, file, ensure_ascii=False, indent=4)

        return rules


def preprocess_text(text):
    """
    Preprocess the given text by removing unwanted characters and normalizing it.
    """
    text = re.sub(r'[^\u0D80-\u0DFF\s]', '', text)
    text = text.strip().lower()
    return text


def tokenize(text):
    """
    Tokenize the text by splitting it into individual words based on spaces.
    """
    return text.split()


def spell_check(sentence, dictionary):
    """
    Identify misspelled words in a sentence.
    """
    words = tokenize(preprocess_text(sentence))
    misspelled = [word for word in words if word not in dictionary]
    return misspelled


def auto_correct(sentence, dictionary):
    """
    Automatically correct misspelled words using the closest match in the dictionary.
    """
    words = tokenize(preprocess_text(sentence))
    corrected_words = []
    for word in words:
        if word in dictionary:
            corrected_words.append(word)
        else:
            closest_matches = difflib.get_close_matches(word, dictionary, n=1)
            corrected_words.append(closest_matches[0] if closest_matches else word)
    return ' '.join(corrected_words)


def apply_rules(sentence, rules, dictionary):
    """
    Apply spelling corrections first, followed by rule-based grammar corrections.
    """
    # Step 1: Correct spelling
    corrected_sentence = auto_correct(sentence, dictionary)

    # Step 2: Apply subject-verb order rules
    for rule in rules["subject_verb_order"]:
        if corrected_sentence == rule["incorrect"]:
            corrected_sentence = rule["correct"]

    # Step 3: Apply pronoun-ending match rules
    words = corrected_sentence.split()
    if len(words) > 1:
        pronoun = words[0]
        if pronoun in ["මම", "අපි", "ඔහු"]:
            correct_end = next(
                (r["end"] for r in rules["pronoun_ending_match"] if r["start"] == pronoun),
                None
            )
            if correct_end and not words[-1].endswith(correct_end):
                words[-1] = words[-1][:-2] + correct_end
                corrected_sentence = " ".join(words)

    # Step 4: Apply verb conjugation rules
    for rule in rules["verb_conjugation"]:
        if rule["incorrect"] in corrected_sentence:
            corrected_sentence = corrected_sentence.replace(rule["incorrect"], rule["correct"])

    return corrected_sentence


def calculate_accuracy(correct_sentences, incorrect_sentences, rules, dictionary):
    """
    Calculate the accuracy of rule-based correction.
    Compares the corrected sentences to the correct ones.
    """
    total_sentences = len(correct_sentences)
    correct_count = 0

    for correct, incorrect in zip(correct_sentences, incorrect_sentences):
        corrected_sentence = apply_rules(incorrect, rules, dictionary)
        if corrected_sentence == correct:
            correct_count += 1

    accuracy = (correct_count / total_sentences) * 100
    return accuracy


# Load sentences and dictionary from files
with open('incorrectSentences.txt', 'r', encoding='utf-8') as f:
    incorrect_sentences = f.read().splitlines()

with open('correctSentences.txt', 'r', encoding='utf-8') as f:
    correct_sentences = f.read().splitlines()

with open('sinhala_dictionary.txt', 'r', encoding='utf-8') as f:
    dictionary = set(f.read().splitlines())

# Initialize RuleExtractor
extractor = RuleExtractor(correct_sentences, incorrect_sentences)

# Extract rules
rules = extractor.extract_rules()
print("Extracted Rules:")
print(json.dumps(rules, ensure_ascii=False, indent=4))

# Calculate accuracy
accuracy = calculate_accuracy(correct_sentences, incorrect_sentences, rules, dictionary)
print(f"Accuracy of the rule-based correction system: {accuracy:.2f}%")

# Example usage
example_sentence = "  පාසැල දරුව ගියේය"
corrected_sentence = apply_rules(example_sentence, rules, dictionary)
print("Original Sentence:", example_sentence)
print("Corrected Sentence:", corrected_sentence)
# Out:
# Extracted Rules:
# {
#     "subject_verb_order": [
#         {
#             "incorrect": "පාසැල් නුඹ  යන්නෙහි",
#             "correct": "නුඹ පාසැල් යන්නෙහි"
#         },
#         {
#             "incorrect": "ඔබ සැම ගුරුතුමාට  කරන්නෙහු ආචාර",
#             "correct": "ඔබ සැම ගුරුතුමාට ආචාර කරන්නෙහු"
#         },
#         {
#             "incorrect": "ගුරුතුමා  උගන්වයි පාඩම",
#             "correct": "ගුරුතුමා පාඩම උගන්වයි"
#         },
#         {
#             "incorrect": "ගුරුවරු  උගන්වති පාඩම්",
#             "correct": "ගුරුවරු පාඩම් උගන්වති"
#         },
#         {
#             "incorrect": "පාසැල් දරුවා  ගියේය",
#             "correct": "දරුවා පාසැල් ගියේය"
#         },
#         {
#             "incorrect": "දරුවෝ  ගියෝය පාසැල්",
#             "correct": "දරුවෝ පාසැල් ගියෝය"
#         },
#         {
#             "incorrect": "දරුවෝ  ගියහ පාසැල්",
#             "correct": "දරුවෝ පාසැල්  ගියහ"
#         },
#         {
#             "incorrect": "පාසැල් දරුවා  යයි ",
#             "correct": "දරුවා පාසැල් යයි "
#         },
#         {
#             "incorrect": "දරුවෝ  යති පාසැල්  ",
#             "correct": "දරුවෝ පාසැල් යති "
#         },
#         {
#             "incorrect": "ඈ අසයි බණ",
#             "correct": "ඈ බණ අසයි "
#         },
#         {
#             "incorrect": "බණ ඈ අසන්නීය",
#             "correct": "ඈ බණ අසන්නීය"
#         },
#         {
#             "incorrect": "ඈ ඇසුවාය බණ",
#             "correct": "ඈ බණ ඇසුවාය"
#         },
#         {
#             "incorrect": "උපාසිකාවෝ  අසති බණ",
#             "correct": "උපාසිකාවෝ බණ අසති"
#         },
#         {
#             "incorrect": "උපාසිකාවෝ  අසන්නෝය බණ",
#             "correct": "උපාසිකාවෝ බණ අසන්නෝය"
#         },
#         {
#             "incorrect": "බණ උපාසිකාවෝ ඇසූහ ",
#             "correct": "උපාසිකාවෝ බණ ඇසූහ "
#         },
#         {
#             "incorrect": "උපාසිකාවෝ ඇසුවෝය බණ",
#             "correct": "උපාසිකාවෝ බණ ඇසුවෝය"
#         },
#         {
#             "incorrect": "ඔහු අසයි බණ",
#             "correct": "ඔහු බණ අසයි "
#         },
#         {
#             "incorrect": "ඔහු අසන්නේය බණ",
#             "correct": "ඔහු බණ අසන්නේය"
#         },
#         {
#             "incorrect": "බණ උපාසකයා ඇසුවේය",
#             "correct": "උපාසකයා බණ ඇසුවේය"
#         },
#         {
#             "incorrect": "උපාසකයෝ අසති බණ",
#             "correct": "උපාසකයෝ බණ අසති "
#         },
#         {
#             "incorrect": "උපාසකයෝ අසන්නෝය බණ",
#             "correct": "උපාසකයෝ බණ අසන්නෝය"
#         },
#         {
#             "incorrect": "උපාසකයෝ ඇසූහ බණ ",
#             "correct": "උපාසකයෝ බණ ඇසූහ "
#         },
#         {
#             "incorrect": "සෙලවෙයි ගස සුළඟට ",
#             "correct": "ගස සුළඟට සෙලවෙයි"
#         },
#         {
#             "incorrect": "ගස  සෙලැවුණි සුළඟට",
#             "correct": "ගස සුළඟට සෙලැවුණි"
#         },
#         {
#             "incorrect": "සුළඟට ගස සෙලවුණේය",
#             "correct": "ගස සුළඟට සෙලවුණේය"
#         },
#         {
#             "incorrect": "ගස් සෙලවෙයි සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවෙයි "
#         },
#         {
#             "incorrect": "ගස්  සෙලවුණි සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවුණි"
#         },
#         {
#             "incorrect": "ගස් සෙලවුණේය සුළඟට",
#             "correct": "ගස් සුළඟට සෙලවුණේය"
#         },
#         {
#             "incorrect": "අපි  නමදිමු දෙමාපියන්",
#             "correct": "අපි දෙමාපියන් නමදිමු"
#         },
#         {
#             "incorrect": "මා විසින්  කියවේ පොත",
#             "correct": "මා විසින් පොත කියවේ"
#         },
#         {
#             "incorrect": "අප විසින් නැමදෙති දෙමාපියෝ ",
#             "correct": "අප විසින් දෙමාපියෝ නැමදෙති"
#         },
#         {
#             "incorrect": "පුතා  පිබිදෙයි අලුයම",
#             "correct": "පුතා අලුයම පිබිදෙයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින්  සදනු ලබයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු ලබයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින් සදනු සෑදෙයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු සෑදෙයි"
#         },
#         {
#             "incorrect": "තාත්තා සේවකයා ලවා කරවයි වැඩ",
#             "correct": "තාත්තා සේවකයා ලවා වැඩ කරවයි "
#         },
#         {
#             "incorrect": "ලේඛකයෝ  ලියති පොත්",
#             "correct": "ලේඛකයෝ පොත් ලියති"
#         },
#         {
#             "incorrect": "මම කඩමි මලක්",
#             "correct": "මම මලක් කඩමි"
#         },
#         {
#             "incorrect": "වඩුවා විසින්  සදනු ලබයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු ලබයි"
#         },
#         {
#             "incorrect": "වඩුවා විසින් සදනු සෑදෙයි පුටුව",
#             "correct": "වඩුවා විසින් පුටුව සදනු සෑදෙයි"
#         },
#         {
#             "incorrect": "අප විසින්  කඩනු ලැබේ මල්",
#             "correct": "අප විසින් මල් කඩනු ලැබේ "
#         },
#         {
#             "incorrect": "අප විසින්  කඩනු කැඩේ මල්",
#             "correct": "අප විසින් මල් කඩනු කැඩේ"
#         },
#         {
#             "incorrect": "ගුරුවරුන් විසින්  යහ මග යැවේ ශිෂ්‍යයෝ",
#             "correct": "ගුරුවරුන් විසින් ශිෂ්‍යයෝ යහ මග යැවේ"
#         },
#         {
#             "incorrect": "අයියා සෑදූ  හැඩයි සරුංගලය",
#             "correct": "අයියා සෑදූ සරුංගලය හැඩයි"
#         },
#         {
#             "incorrect": "ළමයා මාමා ලවා  කඩවයි අඹ",
#             "correct": "ළමයා මාමා ලවා අඹ කඩවයි"
#         },
#         {
#             "incorrect": "මාමා කෙක්කෙන් කඩයි අඹ",
#             "correct": "මාමා කෙක්කෙන් අඹ කඩයි"
#         },
#         {
#             "incorrect": "ගස්  පිරී තිබේ මල්වලින්",
#             "correct": "ගස් මල්වලින් පිරී තිබේ"
#         },
#         {
#             "incorrect": "විදිලි බුබුළුවලින්  බබලයි තොරණ",
#             "correct": "විදිලි බුබුළුවලින් තොරණ බබලයි "
#         },
#         {
#             "incorrect": "අපි සතුන්ට දක්වමු කරුණාව",
#             "correct": "අපි සතුන්ට කරුණාව දක්වමු"
#         },
#         {
#             "incorrect": "අම්බලම මගීන්ගේ පිණිස නිමවා ඇත පහසුව",
#             "correct": "අම්බලම මගීන්ගේ පහසුව පිණිස නිමවා ඇත"
#         },
#         {
#             "incorrect": "වහලෙන්  බිමට වැටේ වතුර",
#             "correct": "වහලෙන් වතුර බිමට වැටේ"
#         },
#         {
#             "incorrect": "බල්ලා  එලියට ආවේය කුඩුවෙන්",
#             "correct": "බල්ලා කුඩුවෙන් එලියට ආවේය"
#         },
#         {
#             "incorrect": "ඇතාගේ  සුදු පාටය දළ",
#             "correct": "ඇතාගේ දළ සුදු පාටය"
#         },
#         {
#             "incorrect": "ඔහු  පිහිනයි මුහුදේ",
#             "correct": "ඔහු මුහුදේ පිහිනයි"
#         },
#         {
#             "incorrect": "සතුරෝ  ඇද වැටුනෝය රණබිමෙහි",
#             "correct": "සතුරෝ රණබිමෙහි ඇද වැටුනෝය"
#         },
#         {
#             "incorrect": "අඹ  ගෙඩි පිරී ඇත ගස්වල",
#             "correct": "අඹ ගස්වල ගෙඩි පිරී ඇත"
#         },
#         {
#             "incorrect": "මා කියන  අසන්න බස්",
#             "correct": "මා කියන බස් අසන්න"
#         },
#         {
#             "incorrect": "අපට  කියන්න කතාවක්",
#             "correct": "අපට කතාවක් කියන්න"
#         },
#         {
#             "incorrect": "මම  වදිමි අම්මාට",
#             "correct": "මම අම්මාට වදිමි"
#         },
#         {
#             "incorrect": "සිරිපාල  ගියේ ය කඩයට",
#             "correct": "සිරිපාල කඩයට ගියේ ය"
#         },
#         {
#             "incorrect": "ඇත්තු  ඇදී යති පේලියට",
#             "correct": "ඇත්තු පේලියට ඇදී යති"
#         },
#         {
#             "incorrect": "ගස්‌ වැටෙයි සුලඟට",
#             "correct": "ගස්‌ සුලඟට වැටෙයි"
#         },
#         {
#             "incorrect": "ඇය නැළ වූවාය පුතු",
#             "correct": "ඇය පුතු නැළ වූවාය"
#         },
#         {
#             "incorrect": "ඔහු යයි රැකියාවට",
#             "correct": "ඔහු රැකියාවට යයි"
#         },
#         {
#             "incorrect": "ගායකයා ගයයි ගී",
#             "correct": "ගායකයා ගී ගයයි"
#         },
#         {
#             "incorrect": "නිවේදකයා  කරයි නිවේදනය",
#             "correct": "නිවේදකයා නිවේදනය කරයි"
#         },
#         {
#             "incorrect": "පන්ති නායකයා  කියවයි පොත",
#             "correct": "පන්ති නායකයා පොත කියවයි"
#         },
#         {
#             "incorrect": "ළමයා ගසයි බෝලයෙන්‌",
#             "correct": "ළමයා බෝලයෙන්‌ ගසයි"
#         },
#         {
#             "incorrect": "නළු රඟති නිළියෝ",
#             "correct": "නළු නිළියෝ රඟති "
#         },
#         {
#             "incorrect": "සිංහයෝ  නොකති තණ",
#             "correct": "සිංහයෝ තණ නොකති"
#         },
#         {
#             "incorrect": "මම යමි නගරයට",
#             "correct": "මම නගරයට යමි "
#         },
#         {
#             "incorrect": "අපි යමු  නගරයට",
#             "correct": "අපි නගරයට යමු"
#         },
#         {
#             "incorrect": "ඔබ යන්නෙහි  නගරයට",
#             "correct": "ඔබ නගරයට යන්නෙහි "
#         },
#         {
#             "incorrect": "නුබලා යන්නෙහු  නගරයට",
#             "correct": "නුබලා නගරයට යන්නෙහු"
#         },
#         {
#             "incorrect": "නගරයට ඔහු  යයි",
#             "correct": "ඔහු නගරයට යයි"
#         },
#         {
#             "incorrect": "නගරයට අප යති",
#             "correct": "අප නගරයට යති"
#         },
#         {
#             "incorrect": "මම  කළෙමි පාඩමි",
#             "correct": "මම පාඩමි කළෙමි"
#         },
#         {
#             "incorrect": "අපි යන්නේමු පාසල්",
#             "correct": "අපි පාසල් යන්නේමු "
#         },
#         {
#             "incorrect": "කෝවිලට නුඹ යහි ",
#             "correct": "නුඹ කෝවිලට යහි "
#         },
#         {
#             "incorrect": "නුඹ යන්නෙහි කෝවිලට",
#             "correct": "නුඹ කෝවිලට යන්නෙහි"
#         },
#         {
#             "incorrect": "නුඹ ගියෙහි කෝවිලට",
#             "correct": "නුඹ කෝවිලට ගියෙහි"
#         },
#         {
#             "incorrect": "අවදි මම වෙමි",
#             "correct": "මම අවදි වෙමි"
#         },
#         {
#             "incorrect": "මම මඳිමි දත්‌ ",
#             "correct": "මම දත්‌ මඳිමි"
#         },
#         {
#             "incorrect": "මම සෝදමි මුහුණ",
#             "correct": "මම මුහුණ සෝදමි"
#         },
#         {
#             "incorrect": "රට රණවිරුවෝ  රකිති",
#             "correct": "රණවිරුවෝ රට රකිති"
#         },
#         {
#             "incorrect": "කොටියා විසින්‌  මැරෙයි මුව ",
#             "correct": "කොටියා විසින්‌ මුව මැරෙයි"
#         },
#         {
#             "incorrect": "කම්කරුවා විසින්‌  ගොඩ නැගේ මාර්ග",
#             "correct": "කම්කරුවා විසින්‌ මාර්ග ගොඩ නැගේ"
#         },
#         {
#             "incorrect": "මට පුළුවන් පිළිගන්න",
#             "correct": "මට පිළිගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා එකතු",
#             "correct": "ඇය එකතු කළා"
#         },
#         {
#             "incorrect": "අපි  පිළිගත්තා එය",
#             "correct": "අපි එය පිළිගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන්  දුන්නා උපදෙස්",
#             "correct": "ඔවුන් උපදෙස් දුන්නා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් පිළිගන්න",
#             "correct": "මට පිළිගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  දෙනවා ඉඩ",
#             "correct": "ඇය ඉඩ දෙනවා"
#         },
#         {
#             "incorrect": "අපි  කරනවා නිවේදනය",
#             "correct": "අපි නිවේදනය කරනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් ගන්න",
#             "correct": "මට ගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  ඉන්නවා අද",
#             "correct": "ඇය අද ඉන්නවා"
#         },
#         {
#             "incorrect": "ඔවුන්  කළා පිළිවෙළ",
#             "correct": "ඔවුන් පිළිවෙළ කළා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් එන්න",
#             "correct": "මට එන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇයට  පුළුවන් අහන්න",
#             "correct": "ඇයට අහන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය අමුණනවා  එය ",
#             "correct": "ඇය එය අමුණනවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට දෙනවා  පහර",
#             "correct": "අපි ඔවුන්ට පහර දෙනවා"
#         },
#         {
#             "incorrect": "ඔවුන්  මඟහරිනවා ඇයව",
#             "correct": "ඔවුන් ඇයව මඟහරිනවා"
#         },
#         {
#             "incorrect": "මට පුළුවන් පිසින්න",
#             "correct": "මට පිසින්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  වගෙයි ඔහු",
#             "correct": "ඇය ඔහු වගෙයි"
#         },
#         {
#             "incorrect": "අපි   කරනවා පරාජය",
#             "correct": "අපි  පරාජය කරනවා"
#         },
#         {
#             "incorrect": "සතුටට ඔවුන්  පත්වුනා",
#             "correct": "ඔවුන් සතුටට පත්වුනා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් අරඹන්න ",
#             "correct": "මට  අරඹන්න පුළුවන්"
#         },
#         {
#             "incorrect": "අපි  ණයට ගත්තා මුදල්",
#             "correct": "අපි මුදල් ණයට ගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන්  ගන්නවා හුස්ම",
#             "correct": "ඔවුන් හුස්ම ගන්නවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් එන්න",
#             "correct": "මට එන්න පුළුවන්"
#         },
#         {
#             "incorrect": "මට  පුළුවන් සාදන්න",
#             "correct": "මට සාදන්න පුළුවන්"
#         },
#         {
#             "incorrect": "අපි කරනවා  ගණනය ",
#             "correct": "අපි  ගණනය කරනවා"
#         },
#         {
#             "incorrect": "ඇය  තෝරනවා ඔහුව",
#             "correct": "ඇය ඔහුව තෝරනවා"
#         },
#         {
#             "incorrect": "අපි  වහනවා එය",
#             "correct": "අපි එය වහනවා"
#         },
#         {
#             "incorrect": "මෙහෙ ඔහු  එනවා",
#             "correct": "ඔහු මෙහෙ එනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් සසඳන්න ",
#             "correct": "මට  සසඳන්න පුළුවන්"
#         },
#         {
#             "incorrect": "තරඟ ඇය  කරනවා",
#             "correct": "ඇය තරඟ කරනවා"
#         },
#         {
#             "incorrect": "පැමිණිලි අපි  කරනවා",
#             "correct": "අපි පැමිණිලි කරනවා"
#         },
#         {
#             "incorrect": "ඔවුන් දිගටම කළා කියවීම ",
#             "correct": "ඔවුන් කියවීම දිගටම කළා"
#         },
#         {
#             "incorrect": "ඔහු  ඇඬුවා ගැන",
#             "correct": "ඔහු ගැන ඇඬුවා"
#         },
#         {
#             "incorrect": "තීරණය මට  කරන්න පුළුවන්",
#             "correct": "මට තීරණය කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා විස්තර ",
#             "correct": "ඇය විස්තර කළා"
#         },
#         {
#             "incorrect": "අතුරුදහන් ඔවුන්  වුනා",
#             "correct": "ඔවුන් අතුරුදහන් වුනා"
#         },
#         {
#             "incorrect": "එය මම සොයාගත්තා",
#             "correct": "මම එය සොයාගත්තා"
#         },
#         {
#             "incorrect": "එයට  ඇය කැමතිනෑ",
#             "correct": "ඇය එයට කැමතිනෑ"
#         },
#         {
#             "incorrect": "අපි කරනවා  එය ",
#             "correct": "අපි එය කරනවා"
#         },
#         {
#             "incorrect": "ඔවුන් දකිනවා සිහින ",
#             "correct": "ඔවුන් සිහින දකිනවා"
#         },
#         {
#             "incorrect": "මම උපයනවා මුදල්",
#             "correct": "මම මුදල් උපයනවා"
#         },
#         {
#             "incorrect": "ඔහු  කනවා සෑහෙන්න",
#             "correct": "ඔහු සෑහෙන්න කනවා"
#         },
#         {
#             "incorrect": "අපි රසවින්ඳා එය ",
#             "correct": "අපි එය රසවින්ඳා"
#         },
#         {
#             "incorrect": "මෙහෙ ඔවුන් ආවා",
#             "correct": "ඔවුන් මෙහෙ ආවා"
#         },
#         {
#             "incorrect": "පළා ඔහු  ගියා",
#             "correct": "ඔහු පළා ගියා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් කරන්න",
#             "correct": "මට කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇයටත්  හැඟෙනවා එය",
#             "correct": "ඇයටත් එය හැඟෙනවා"
#         },
#         {
#             "incorrect": "එහෙන් අපි  පළාගියා",
#             "correct": "අපි එහෙන් පළාගියා"
#         },
#         {
#             "incorrect": "ඔවුන්  වෙනවා ගුවන්ගත",
#             "correct": "ඔවුන් ගුවන්ගත වෙනවා"
#         },
#         {
#             "incorrect": "මට  පුළුවන් අනුගමනය කරන්න",
#             "correct": "මට අනුගමනය කරන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කළා අමතක",
#             "correct": "ඇය අමතක කළා"
#         },
#         {
#             "incorrect": "අපි  දෙනවා සමාව",
#             "correct": "අපි සමාව දෙනවා"
#         },
#         {
#             "incorrect": "මට  ඇයට පුළුවන් දෙන්න ",
#             "correct": "මට ඇයට දෙන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය යනවා එහෙ ",
#             "correct": "ඇය එහෙ යනවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට  කිව්වා ආයුබෝවන්",
#             "correct": "අපි ඔවුන්ට ආයුබෝවන් කිව්වා"
#         },
#         {
#             "incorrect": "මම   කරනවා පිළිකුල්",
#             "correct": "මම  පිළිකුල් කරනවා"
#         },
#         {
#             "incorrect": "එය මට  ඇහෙනවා",
#             "correct": "මට එය ඇහෙනවා"
#         },
#         {
#             "incorrect": "ඇය  මවාගන්නවා සිතෙහි",
#             "correct": "ඇය සිතෙහි මවාගන්නවා"
#         },
#         {
#             "incorrect": "අපි ඔවුන්ට කළා ආරාධනා ",
#             "correct": "අපි ඔවුන්ට ආරාධනා කළා"
#         },
#         {
#             "incorrect": "මම  දන්නවා ඔහුව",
#             "correct": "මම ඔහුව දන්නවා"
#         },
#         {
#             "incorrect": "ඇය  ඉගෙනගත්තා එය",
#             "correct": "ඇය එය ඉගෙනගත්තා"
#         },
#         {
#             "incorrect": "අපි  පිටවෙනවා දැන්",
#             "correct": "අපි දැන් පිටවෙනවා"
#         },
#         {
#             "incorrect": "ඔවුහු  කිව්වා බොරු",
#             "correct": "ඔවුහු  බොරු කිව්වා"
#         },
#         {
#             "incorrect": "මට  පුළුවන්  සවන්දෙන්න",
#             "correct": "මට  සවන්දෙන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කරගත්තා අහිමි ",
#             "correct": "ඇය  අහිමි කරගත්තා"
#         },
#         {
#             "incorrect": "අපි  සෑදුවා ඊයේ",
#             "correct": "අපි ඊයේ සෑදුවා"
#         },
#         {
#             "incorrect": "ඔවුන්  හමුවුනා ඔහුව",
#             "correct": "ඔවුන් ඔහුව හමුවුනා"
#         },
#         {
#             "incorrect": "මම  ලියනවා වැරදි",
#             "correct": "මම වැරදි ලියනවා"
#         },
#         {
#             "incorrect": "මම සැමවිටම කරනවා යාච්ඤා ",
#             "correct": "මම සැමවිටම යාච්ඤා කරනවා"
#         },
#         {
#             "incorrect": "ඇය  තෝරාගන්නවා එය",
#             "correct": "ඇය එය තෝරාගන්නවා"
#         },
#         {
#             "incorrect": "අපි  කළා ආරක්ෂා",
#             "correct": "අපි ආරක්ෂා කළා"
#         },
#         {
#             "incorrect": "ඔවුහු  කරාවි දඬුවම්",
#             "correct": "ඔවුහු දඬුවම් කරාවි"
#         },
#         {
#             "incorrect": "මට  පුළුවන් තියන්න",
#             "correct": "මට තියන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කියවනවා එය",
#             "correct": "ඇය එය කියවනවා"
#         },
#         {
#             "incorrect": "අපිට  ලැබුණා එය",
#             "correct": "අපිට එය ලැබුණා"
#         },
#         {
#             "incorrect": "ඔවුන්  කරනවා ප්‍රතික්ෂේප",
#             "correct": "ඔවුන් ප්‍රතික්ෂේප කරනවා"
#         },
#         {
#             "incorrect": "මට  මතකයි එය",
#             "correct": "මට එය මතකයි"
#         },
#         {
#             "incorrect": "නැවත  ඇය කියනවා",
#             "correct": "ඇය නැවත කියනවා"
#         },
#         {
#             "incorrect": "අපිට  පෙනෙනවා එය",
#             "correct": "අපිට එය පෙනෙනවා"
#         },
#         {
#             "incorrect": "එය ඔවුන් විකුණනවා",
#             "correct": "ඔවුන් එය විකුණනවා"
#         },
#         {
#             "incorrect": "මම යැව්වා  ඊයේ",
#             "correct": "මම ඊයේ යැව්වා"
#         },
#         {
#             "incorrect": "රැවුල  ඔහු බෑවා",
#             "correct": "ඔහු රැවුල බෑවා"
#         },
#         {
#             "incorrect": "අපි කළා ගායනා",
#             "correct": "අපි  ගායනා කළා"
#         },
#         {
#             "incorrect": "ඔවුන් ඉඳත්තා එතන ",
#             "correct": "ඔවුන් එතන ඉඳත්තා"
#         },
#         {
#             "incorrect": "මට පුළුවන් කියන්න",
#             "correct": "මට  කියන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  කරනවා වියදම්",
#             "correct": "ඇය වියදම් කරනවා"
#         },
#         {
#             "incorrect": "අපි වින්ඳා දුක් ",
#             "correct": "අපි දුක් වින්ඳා"
#         },
#         {
#             "incorrect": "යෝජනා ඔවුන් කරනවා",
#             "correct": "ඔවුන් යෝජනා කරනවා"
#         },
#         {
#             "incorrect": "පුදුම මම කළා",
#             "correct": "මම පුදුම කළා"
#         },
#         {
#             "incorrect": "ඇය ගත්තා එය",
#             "correct": "ඇය එය ගත්තා"
#         },
#         {
#             "incorrect": "එය අපි උගන්වනවා",
#             "correct": "අපි එය උගන්වනවා"
#         },
#         {
#             "incorrect": "ඔවුන් කීව්වා අපට ",
#             "correct": "ඔවුන් අපට කීව්වා"
#         },
#         {
#             "incorrect": "ඇය කළා ස්තූති ",
#             "correct": "ඇය ස්තූති කළා"
#         },
#         {
#             "incorrect": "මට පුළුවන් සිතා බලන්න",
#             "correct": "මට සිතා බලන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය කළා විසි ",
#             "correct": "ඇය විසි කළා"
#         },
#         {
#             "incorrect": "අපි  තේරුම්ගන්නවා එය",
#             "correct": "අපි එය තේරුම්ගන්නවා"
#         },
#         {
#             "incorrect": "එය ඔවුන්ට අවශ්‍යයි",
#             "correct": "ඔවුන්ට එය අවශ්‍යයි"
#         },
#         {
#             "incorrect": "මට පුළුවන් ඇඳපැළඳ ගන්න",
#             "correct": "මට  ඇඳපැළඳ ගන්න පුළුවන්"
#         },
#         {
#             "incorrect": "ඇය  ලියනවා එය",
#             "correct": "ඇය එය ලියනවා"
#         },
#         {
#             "incorrect": "අපි කරනවා කතා",
#             "correct": "අපි කතා කරනවා"
#         },
#         {
#             "incorrect": "එය ගාව ඔවුන්",
#             "correct": "එය ඔවුන් ගාව"
#         },
#         {
#             "incorrect": "මම නැරඹුවා එය ",
#             "correct": "මම එය නැරඹුවා"
#         },
#         {
#             "incorrect": "කතා මම කරාවි",
#             "correct": "මම කතා කරාවි"
#         },
#         {
#             "incorrect": "ඔහු ගත්තා  මිලට ",
#             "correct": "ඔහු මිලට ගත්තා"
#         },
#         {
#             "incorrect": "අපි කළා නිමා",
#             "correct": "අපි නිමා කළා"
#         },
#         {
#             "incorrect": "මට හැක පිළිගත",
#             "correct": "මට පිළිගත හැක"
#         },
#         {
#             "incorrect": "ඇය කළාය එකතු ",
#             "correct": "ඇය එකතු කළාය"
#         },
#         {
#             "incorrect": "අපි පිළිගනිමු එය ",
#             "correct": "අපි එය පිළිගනිමු"
#         },
#         {
#             "incorrect": "ඔවුහු දුන්නෝය උපදෙස් ",
#             "correct": "ඔවුහු උපදෙස් දුන්නෝය"
#         },
#         {
#             "incorrect": "මට වියහැක එකඟ ",
#             "correct": "මට එකඟ වියහැක"
#         },
#         {
#             "incorrect": "ඇය දෙයි ඉඩ",
#             "correct": "ඇය ඉඩ දෙයි"
#         },
#         {
#             "incorrect": "අපි කරමු නිවේදනය ",
#             "correct": "අපි නිවේදනය කරමු"
#         },
#         {
#             "incorrect": "මට ඉල්ලියහැක  සමාව",
#             "correct": "මට සමාව ඉල්ලියහැක"
#         },
#         {
#             "incorrect": "ඔවුහු  කළෝය පිළියෙළ",
#             "correct": "ඔවුහු පිළියෙළ කළෝය"
#         },
#         {
#             "incorrect": "මට ආහැක හෙට ",
#             "correct": "මට හෙට ආහැක"
#         },
#         {
#             "incorrect": "ඇයට හැක ඇසිය",
#             "correct": "ඇයට ඇසිය හැක"
#         },
#         {
#             "incorrect": "ඇය  අමුණයි එය",
#             "correct": "ඇය එය අමුණයි"
#         },
#         {
#             "incorrect": "අපි පහරදෙමු ඔවුන්ට ",
#             "correct": "අපි ඔවුන්ට පහරදෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු මඟහැරියෝය ඇයව",
#             "correct": "ඔවුහු ඇයව මඟහැරියෝය"
#         },
#         {
#             "incorrect": "පිසිය මට හැක",
#             "correct": "මට පිසිය හැක"
#         },
#         {
#             "incorrect": "ඇය වැනිය ඔහු ",
#             "correct": "ඇය ඔහු වැනිය"
#         },
#         {
#             "incorrect": "අපි  කරමු පරාජය",
#             "correct": "අපි පරාජය කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු පත්විය  සතුටට ",
#             "correct": "ඔවුහු සතුටට පත්විය"
#         },
#         {
#             "incorrect": "මට හැක ඇරඹිය",
#             "correct": "මට ඇරඹිය හැක"
#         },
#         {
#             "incorrect": "ඔවුහු ගනිති හුස්ම ",
#             "correct": "ඔවුහු හුස්ම ගනිති"
#         },
#         {
#             "incorrect": "මට  හැක සෑදිය",
#             "correct": "මට සෑදිය හැක"
#         },
#         {
#             "incorrect": "ආහාර ඇය මිලට ගනියි",
#             "correct": "ඇය ආහාර මිලට ගනියි"
#         },
#         {
#             "incorrect": "ගණනය අපි කරමු",
#             "correct": "අපි ගණනය කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු  යති රැගෙන",
#             "correct": "ඔවුහු රැගෙන යති"
#         },
#         {
#             "incorrect": "ඔවුන්  නොකරයි වංචා",
#             "correct": "ඔවුන් වංචා නොකරයි"
#         },
#         {
#             "incorrect": "ඇය  තෝරයි ඔහුව",
#             "correct": "ඇය ඔහුව තෝරයි"
#         },
#         {
#             "incorrect": "අපි  වසමු එය",
#             "correct": "අපි එය වසමු"
#         },
#         {
#             "incorrect": "ඔහු එයි මෙහි",
#             "correct": "ඔහු මෙහි එයි"
#         },
#         {
#             "incorrect": "මට  හැක සැසඳිය",
#             "correct": "මට සැසඳිය හැක"
#         },
#         {
#             "incorrect": "ඇය කරයි  තරඟ ",
#             "correct": "ඇය තරඟ කරයි"
#         },
#         {
#             "incorrect": "අපි  කරමු පැමිණිලි",
#             "correct": "අපි පැමිණිලි කරමු"
#         },
#         {
#             "incorrect": "ඔවුහු  කළෝය දිගටම",
#             "correct": "ඔවුහු දිගටම කළෝය"
#         },
#         {
#             "incorrect": "දිගටම ඔහු ඇඬුවේය",
#             "correct": "ඔහු දිගටම ඇඬුවේය"
#         },
#         {
#             "incorrect": "ඇය කළාය විස්තර",
#             "correct": "ඇය විස්තර කළාය"
#         },
#         {
#             "incorrect": "අපි නොවීමු එකඟ",
#             "correct": "අපි එකඟ නොවීමු"
#         },
#         {
#             "incorrect": "ඔවුහු විය අතුරුදහන්",
#             "correct": "ඔවුහු අතුරුදහන් විය"
#         },
#         {
#             "incorrect": "එය මම සොයාගත්තෙමි",
#             "correct": "මම එය සොයාගත්තෙමි"
#         },
#         {
#             "incorrect": "ඇය අකැමතියි එයට",
#             "correct": "ඇය එයට අකැමතියි"
#         },
#         {
#             "incorrect": "අපි කරමු එය",
#             "correct": "අපි එය කරමු"
#         },
#         {
#             "incorrect": "ඔවුන් දකිති සිහින",
#             "correct": "ඔවුන් සිහින දකිති"
#         },
#         {
#             "incorrect": "මම උපයමි මුදල්",
#             "correct": "මම මුදල් උපයමි"
#         },
#         {
#             "incorrect": "ඔහු කයි සෑහෙන්න",
#             "correct": "ඔහු සෑහෙන්න කයි"
#         },
#         {
#             "incorrect": "අපි රසවින්ඳෙමු එය",
#             "correct": "අපි එය රසවින්ඳෙමු"
#         },
#         {
#             "incorrect": "ඔවුන් ආවෝය මෙහි ",
#             "correct": "ඔවුන් මෙහි ආවෝය"
#         },
#         {
#             "incorrect": "ඔහු ගියේය පළා",
#             "correct": "ඔහු පළා ගියේය"
#         },
#         {
#             "incorrect": "මට කළහැක පැහැදිලි ",
#             "correct": "මට පැහැදිලි කළහැක"
#         },
#         {
#             "incorrect": "ඇයට හැඟෙයි එය ",
#             "correct": "ඇයට එය හැඟෙයි"
#         },
#         {
#             "incorrect": "අපි ගියෙමු පළා ",
#             "correct": "අපි පළා ගියෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු වන්නෝය ගුවන්ගත ",
#             "correct": "ඔවුහු ගුවන්ගත වන්නෝය"
#         },
#         {
#             "incorrect": "මට කළහැක අනුගමනය ",
#             "correct": "මට අනුගමනය කළහැක"
#         },
#         {
#             "incorrect": "ඇය කළාය අමතක ",
#             "correct": "ඇය අමතක කළාය"
#         },
#         {
#             "incorrect": "අපි දෙමු සමාව ",
#             "correct": "අපි සමාව දෙමු"
#         },
#         {
#             "incorrect": "ඇය යයි එහෙ ",
#             "correct": "ඇය  එහෙ යයි"
#         },
#         {
#             "incorrect": "ආයුබෝවන් අපි කීවෙමු",
#             "correct": "අපි ආයුබෝවන් කීවෙමු"
#         },
#         {
#             "incorrect": "මම කරමි පිළිකුල් ",
#             "correct": "මම පිළිකුල් කරමි"
#         },
#         {
#             "incorrect": "මට ඇසෙයි එය ",
#             "correct": "මට එය ඇසෙයි"
#         },
#         {
#             "incorrect": "ඇය ගනියි  මවා ",
#             "correct": "ඇය මවා ගනියි"
#         },
#         {
#             "incorrect": "අපි කළෙමු ආරාධනා ",
#             "correct": "අපි ආරාධනා කළෙමු"
#         },
#         {
#             "incorrect": "මම දනිමි  ඔහුව ",
#             "correct": "මම ඔහුව දනිමි"
#         },
#         {
#             "incorrect": "ඇය ගත්තාය ඉගෙන ",
#             "correct": "ඇය ඉගෙන ගත්තාය"
#         },
#         {
#             "incorrect": "අපි පිටවෙමු දැන් ",
#             "correct": "අපි දැන් පිටවෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කීවෝය බොරු ",
#             "correct": "ඔවුහු බොරු කීවෝය"
#         },
#         {
#             "incorrect": "මට හැක සවන්දිය ",
#             "correct": "මට සවන්දිය හැක"
#         },
#         {
#             "incorrect": "ඇය කරගත්තාය අහිමි ",
#             "correct": "ඇය අහිමි කරගත්තාය"
#         },
#         {
#             "incorrect": "අපි සෑදුවෙමු එය ",
#             "correct": "අපි එය සෑදුවෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු හමුවූවෝය ඔහුව ",
#             "correct": "ඔවුහු ඔහුව හමුවූවෝය"
#         },
#         {
#             "incorrect": "මම ලෙස ලියමි වැරදි ",
#             "correct": "මම වැරදි ලෙස ලියමි"
#         },
#         {
#             "incorrect": "මම කරමි  යාච්ඤා ",
#             "correct": "මම යාච්ඤා කරමි"
#         },
#         {
#             "incorrect": "ඇය තෝරාගනියි එය ",
#             "correct": "ඇය එය තෝරාගනියි"
#         },
#         {
#             "incorrect": "අපි කළෙමු  ආරක්ෂා ",
#             "correct": "අපි ආරක්ෂා කළෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කරයි දඬුවම්",
#             "correct": "ඔවුහු දඬුවම් කරයි"
#         },
#         {
#             "incorrect": "මට හැක  තැබිය ",
#             "correct": "මට තැබිය හැක"
#         },
#         {
#             "incorrect": "ඇය කියවයි එය ",
#             "correct": "ඇය එය කියවයි"
#         },
#         {
#             "incorrect": "අපිට ලැබුණි එය ",
#             "correct": "අපිට එය ලැබුණි"
#         },
#         {
#             "incorrect": "ඔවුහු කරති  ප්‍රතික්ෂේප ",
#             "correct": "ඔවුහු ප්‍රතික්ෂේප කරති"
#         },
#         {
#             "incorrect": "මට මතකයි එය ",
#             "correct": "මට එය මතකයි"
#         },
#         {
#             "incorrect": "ඇය කියයි නැවත ",
#             "correct": "ඇය නැවත කියයි"
#         },
#         {
#             "incorrect": "අපිට පෙනෙයි එය ",
#             "correct": "අපිට එය පෙනෙයි"
#         },
#         {
#             "incorrect": "ඔවුන් විකුණති  එය ",
#             "correct": "ඔවුන් එය විකුණති"
#         },
#         {
#             "incorrect": "මම යැව්වෙමි ඊයේ ",
#             "correct": "මම ඊයේ යැව්වෙමි"
#         },
#         {
#             "incorrect": "ඔහු බෑවේය රැවුල ",
#             "correct": "ඔහු රැවුල බෑවේය"
#         },
#         {
#             "incorrect": "එය ඇකිළුනේය සැණින් ",
#             "correct": "එය සැණින් ඇකිළුනේය"
#         },
#         {
#             "incorrect": "අපි කරන්නෙමු ගායනා ",
#             "correct": "අපි ගායනා කරන්නෙමු"
#         },
#         {
#             "incorrect": "ඔවුන් ඉඳත්තෝය එතන ",
#             "correct": "ඔවුන් එතන ඉඳත්තෝය"
#         },
#         {
#             "incorrect": "මට හැක කිව ",
#             "correct": "මට කිව හැක"
#         },
#         {
#             "incorrect": "ඇය කරයි වියදම් ",
#             "correct": "ඇය වියදම් කරයි"
#         },
#         {
#             "incorrect": "අපි  වින්ඳෙමු දුක්",
#             "correct": "අපි දුක් වින්ඳෙමු"
#         },
#         {
#             "incorrect": "ඔවුහු කරති යෝජනා ",
#             "correct": "ඔවුහු යෝජනා කරති"
#         },
#         {
#             "incorrect": "මම කළෙමි පුදුම ",
#             "correct": "මම පුදුම කළෙමි"
#         },
#         {
#             "incorrect": "ඇය ගත්තාය එය ",
#             "correct": "ඇය එය ගත්තාය"
#         },
#         {
#             "incorrect": "අපි උගන්වමු එය ",
#             "correct": "අපි එය උගන්වමු"
#         },
#         {
#             "incorrect": "අපට ඔවුන් කීවෝය",
#             "correct": "ඔවුන් අපට කීවෝය"
#         },
#         {
#             "incorrect": "ස්තූතියි ඇය කළාය",
#             "correct": "ඇය ස්තූතියි කළාය"
#         },
#         {
#             "incorrect": "සිතා මට බැලියහැක",
#             "correct": "මට සිතා බැලියහැක"
#         },
#         {
#             "incorrect": "විසි  ඇය කළාය",
#             "correct": "ඇය විසි කළාය"
#         },
#         {
#             "incorrect": "එය  අපි තේරුම්ගනිමු",
#             "correct": "අපි එය තේරුම්ගනිමු"
#         },
#         {
#             "incorrect": "ඔවුන්ට අවශ්‍යයි එය ",
#             "correct": "ඔවුන්ට එය අවශ්‍යයි"
#         },
#         {
#             "incorrect": "මට ගතහැක ඇඳපැළඳ ",
#             "correct": "මට ඇඳපැළඳ ගතහැක"
#         },
#         {
#             "incorrect": "එය  ඇය ලියයි",
#             "correct": "ඇය එය ලියයි"
#         },
#         {
#             "incorrect": "අපි කරමු කතා ",
#             "correct": "අපි කතා කරමු"
#         },
#         {
#             "incorrect": "එය සතුයි ඔවුන් ",
#             "correct": "එය ඔවුන් සතුයි"
#         },
#         {
#             "incorrect": "එය  මම නැරඹුවෙමි",
#             "correct": "මම එය නැරඹුවෙමි"
#         },
#         {
#             "incorrect": "කතා  මම කරන්නෙමි",
#             "correct": "මම කතා කරන්නෙමි"
#         },
#         {
#             "incorrect": "ඔහු ගත්තේය මිලට ",
#             "correct": "ඔහු මිලට ගත්තේය"
#         },
#         {
#             "incorrect": "අපි කළෙමු නිමා ",
#             "correct": "අපි නිමා කළෙමු"
#         },
#         {
#             "incorrect": "යන්නෙ ඔහු කොහිද?",
#             "correct": "ඔහු යන්නෙ කොහිද?"
#         },
#         {
#             "incorrect": "දුක්වන්නේ ඔබ ඇයි?",
#             "correct": "ඔබ දුක්වන්නේ ඇයි?"
#         },
#         {
#             "incorrect": "කැමති ඔබ කොහොමද?",
#             "correct": "ඔබ කැමති කොහොමද?"
#         },
#         {
#             "incorrect": "කොතරම් එය විශාලද?",
#             "correct": "එය කොතරම් විශාලද?"
#         },
#         {
#             "incorrect": "ඔහු නොමැත මෙහි ",
#             "correct": "ඔහු මෙහි නොමැත"
#         },
#         {
#             "incorrect": "මෙය නොවෙයි මගේ ",
#             "correct": "මෙය මගේ නොවෙයි"
#         },
#         {
#             "incorrect": "මම නොකරමි කතා ",
#             "correct": "මම කතා නොකරමි"
#         },
#         {
#             "incorrect": "මම නොලියමි පොත ",
#             "correct": "මම පොත නොලියමි"
#         },
#         {
#             "incorrect": "රිය  මම නොපදවමි",
#             "correct": "මම රිය නොපදවමි"
#         },
#         {
#             "incorrect": "ආදරය  මම නොකරමි",
#             "correct": "මම ආදරය නොකරමි"
#         },
#         {
#             "incorrect": "පොත මම නොදෙමි",
#             "correct": "මම පොත නොදෙමි"
#         },
#         {
#             "incorrect": "මම නොවෙමි සිනා ",
#             "correct": "මම සිනා නොවෙමි"
#         },
#         {
#             "incorrect": "මම නොගනිමි පොත ",
#             "correct": "මම පොත නොගනිමි"
#         },
#         {
#             "incorrect": "කතා ඔහු නොකරයි",
#             "correct": "ඔහු කතා නොකරයි"
#         },
#         {
#             "incorrect": "පොත මහු නොලියයි",
#             "correct": "මහු පොත නොලියයි"
#         },
#         {
#             "incorrect": "ඔහු නොපදවයි රිය ",
#             "correct": "ඔහු රිය නොපදවයි"
#         },
#         {
#             "incorrect": "ආදරය ඔහු නොකරයි",
#             "correct": "ඔහු ආදරය නොකරයි"
#         },
#         {
#             "incorrect": "පොත ඔහු නොදෙයි",
#             "correct": "ඔහු පොත නොදෙයි"
#         },
#         {
#             "incorrect": "සිනා ඔහු නොවෙයි",
#             "correct": "ඔහු සිනා නොවෙයි"
#         },
#         {
#             "incorrect": "ඔහු නොගනියි පොත ",
#             "correct": "ඔහු පොත නොගනියි"
#         },
#         {
#             "incorrect": "අපි නොකරමු කතා ",
#             "correct": "අපි කතා නොකරමු"
#         },
#         {
#             "incorrect": "පොත අපි නොලියමු",
#             "correct": "අපි පොත නොලියමු"
#         },
#         {
#             "incorrect": "අපි නොපදවමු රිය ",
#             "correct": "අපි රිය නොපදවමු"
#         },
#         {
#             "incorrect": "ආදරය අපි නොකරමු",
#             "correct": "අපි ආදරය නොකරමු"
#         },
#         {
#             "incorrect": "අපි නොදෙමු පොත ",
#             "correct": "අපි පොත නොදෙමු"
#         },
#         {
#             "incorrect": "සිනා අපි නොවෙමු",
#             "correct": "අපි සිනා නොවෙමු"
#         },
#         {
#             "incorrect": "මම කරමි කතා ",
#             "correct": "මම කතා කරමි"
#         },
#         {
#             "incorrect": "කතා ඔබ කරන්නෙහි",
#             "correct": "ඔබ කතා කරන්නෙහි"
#         },
#         {
#             "incorrect": "ඔහු කරයි කතා ",
#             "correct": "ඔහු කතා කරයි"
#         },
#         {
#             "incorrect": "කතා ඇය කරයි",
#             "correct": "ඇය කතා කරයි"
#         },
#         {
#             "incorrect": "අපි කරමු කතා ",
#             "correct": "අපි කතා කරමු"
#         },
#         {
#             "incorrect": "කතා ඔවුහු කරති",
#             "correct": "ඔවුහු කතා කරති"
#         },
#         {
#             "incorrect": "ගණන් මේක වැඩියි",
#             "correct": "මේක ගණන් වැඩියි"
#         },
#         {
#             "incorrect": "මෙහෙට ඔයා කැමතිද?",
#             "correct": "ඔයා මෙහෙට කැමතිද?"
#         },
#         {
#             "incorrect": "යන්නෙ මම කොහොමද?",
#             "correct": "මම යන්නෙ කොහොමද?"
#         },
#         {
#             "incorrect": "ප්‍රශ්නයක් මට  තියෙනවා ",
#             "correct": "මට ප්‍රශ්නයක් තියෙනවා "
#         },
#         {
#             "incorrect": "කරුණාකර කියන්න මට ",
#             "correct": "කරුණාකර මට කියන්න"
#         },
#         {
#             "incorrect": "මම කථා නැහැ කරන්නේ",
#             "correct": "මම කථා කරන්නේ නැහැ "
#         },
#         {
#             "incorrect": "මම  නැහැ ගන්නේ",
#             "correct": "මම ගන්නේ නැහැ "
#         },
#         {
#             "incorrect": "නැවත ඒක කියන්න ",
#             "correct": "ඒක නැවත කියන්න "
#         },
#         {
#             "incorrect": "මට  අවශ්‍යයි තොරතුරු",
#             "correct": "මට තොරතුරු අවශ්‍යයි "
#         },
#         {
#             "incorrect": "කාමර ඔබට තිබේද? ",
#             "correct": "ඔබට කාමර තිබේද? "
#         },
#         {
#             "incorrect": "කෑම උදෑසන ඇතුළත්ද? ",
#             "correct": "උදෑසන කෑම ඇතුළත්ද? "
#         },
#         {
#             "incorrect": "කාමරයක් මට ඕනේ ",
#             "correct": "මට කාමරයක් ඕනේ "
#         },
#         {
#             "incorrect": "මට ඕනේ කාමරයක් ",
#             "correct": "මට කාමරයක් ඕනේ "
#         },
#         {
#             "incorrect": "යන්ත්‍රය උකස් කොහේද? ",
#             "correct": "උකස් යන්ත්‍රය කොහේද? "
#         },
#         {
#             "incorrect": "කරගන්න කාමරයක් බුක් ඕනේ ",
#             "correct": "කාමරයක් බුක් කරගන්න ඕනේ "
#         },
#         {
#             "incorrect": "ආරක්ෂිතව මම සිටිනවා ",
#             "correct": "මම ආරක්ෂිතව සිටිනවා "
#         },
#         {
#             "incorrect": "උදේ ඇහැරවන්න මාව ",
#             "correct": "උදේ මාව ඇහැරවන්න "
#         },
#         {
#             "incorrect": "බිළිඳුන්ට ඕනේ කූඩයක් ",
#             "correct": "බිළිඳුන්ට කූඩයක් ඕනේ "
#         },
#         {
#             "incorrect": "මිල වට්ටමේ කීයද?",
#             "correct": "වට්ටමේ මිල කීයද?"
#         },
#         {
#             "incorrect": "එය මිලයි වැඩි ",
#             "correct": "එය වැඩි මිලයි"
#         },
#         {
#             "incorrect": "වර්ණයක් මෙයට තිබේද? ",
#             "correct": "මෙයට  වර්ණයක් තිබේද? "
#         },
#         {
#             "incorrect": "මම ඕන දෙන්න  ",
#             "correct": "මම දෙන්න ඕන "
#         },
#         {
#             "incorrect": "ඇලර්ජියක් මට තියෙනවා ",
#             "correct": "මට ඇලර්ජියක් තියෙනවා "
#         },
#         {
#             "incorrect": "මේකට මම කැමතියි ",
#             "correct": "මම මේකට කැමතියි "
#         },
#         {
#             "incorrect": "යන්න මට ඕන",
#             "correct": "මට යන්න ඕන"
#         },
#         {
#             "incorrect": "මගේ  සුදුයි බල්ලා",
#             "correct": "මගේ බල්ලා සුදුයි"
#         },
#         {
#             "incorrect": "කඩේ එයාලා යනවා",
#             "correct": "එයාලා කඩේ යනවා"
#         },
#         {
#             "incorrect": "මේ වහිනවා වෙලාවේ ",
#             "correct": "මේ වෙලාවේ වහිනවා"
#         },
#         {
#             "incorrect": "වැනිලා මම වලට කැමතියි",
#             "correct": "මම වැනිලා වලට කැමතියි"
#         },
#         {
#             "incorrect": "ඉර දිලිසෙනවා එළියෙන් ",
#             "correct": "ඉර එළියෙන් දිලිසෙනවා"
#         },
#         {
#             "incorrect": "අයිස් මම වලට කැමතියි",
#             "correct": "මම අයිස් වලට කැමතියි"
#         },
#         {
#             "incorrect": "මට ඉන්නවා බල්ලෙක්",
#             "correct": "මට බල්ලෙක් ඉන්නවා "
#         },
#         {
#             "incorrect": "අපි නගරයේ නිව්යෝර්ක් ",
#             "correct": "අපි නිව්යෝර්ක් නගරයේ"
#         },
#         {
#             "incorrect": "කලිසමක් ඔහු කළු ඇඳ ගෙන සිටී",
#             "correct": "ඔහු කළු කලිසමක් ඇඳ ගෙන සිටී"
#         },
#         {
#             "incorrect": "උද්යානයට ඔවුන් ගියා",
#             "correct": "ඔවුන් උද්යානයට ගියා"
#         },
#         {
#             "incorrect": "යාළුවෝ එක්ක කරන්න සෙල්ලම්",
#             "correct": "යාළුවෝ එක්ක සෙල්ලම් කරන්න"
#         },
#         {
#             "incorrect": "යහන මත නිදාසිටී බළලා",
#             "correct": "බළලා යහන මත නිදාසිටී"
#         },
#         {
#             "incorrect": "බල්ලා පනිනවා තටාකයට",
#             "correct": "බල්ලා තටාකයට පනිනවා"
#         },
#         {
#             "incorrect": "කැමති මම කෑමකට",
#             "correct": "මම කැමති කෑමකට"
#         },
#         {
#             "incorrect": "අම්මා ආදරෙයි ගොඩක් ",
#             "correct": "අම්මා ගොඩක් ආදරෙයි"
#         },
#         {
#             "incorrect": "මම කරනවා වැඩ ",
#             "correct": "මම වැඩ කරනවා"
#         },
#         {
#             "incorrect": "මම  ගියා කඩේට",
#             "correct": "මම කඩේට ගියා"
#         },
#         {
#             "incorrect": "මගේ නම ස්මිත් ජෝන් ",
#             "correct": "මගේ නම ජෝන් ස්මිත්"
#         },
#         {
#             "incorrect": "අද රස්නෙයි ඉර ",
#             "correct": "අද ඉර රස්නෙයි"
#         },
#         {
#             "incorrect": "ගෙයක් අපිට තියෙනවා",
#             "correct": "අපිට ගෙයක් තියෙනවා"
#         },
#         {
#             "incorrect": "අපි  ඩ්රයිව්කලා රෑම",
#             "correct": "අපි රෑම ඩ්රයිව්කලා"
#         },
#         {
#             "incorrect": "ආයෙත් ඔයා පරක්කුයි",
#             "correct": "ඔයා ආයෙත් පරක්කුයි"
#         },
#         {
#             "incorrect": "බල්ලා විය බුරන්නට ",
#             "correct": "බල්ලා බුරන්නට විය"
#         },
#         {
#             "incorrect": "වටේ බල්ලා දිව්වා",
#             "correct": "බල්ලා වටේ දිව්වා"
#         },
#         {
#             "incorrect": "පූසා  කෑගැහුවා හයියෙන්",
#             "correct": "පූසා හයියෙන් කෑගැහුවා"
#         },
#         {
#             "incorrect": "අයියා ආසයි කන්න සැන්ඩ්විච් ",
#             "correct": "අයියා ආසයි සැන්ඩ්විච් කන්න"
#         },
#         {
#             "incorrect": "මම  යන්න ආසයි සාලෙට",
#             "correct": "මම ආසයි සාලෙට යන්න"
#         },
#         {
#             "incorrect": "හරිම ආසයි ආච්චි කේක් හදන්න ",
#             "correct": "ආච්චි කේක් හදන්න හරිම ආසයි"
#         },
#         {
#             "incorrect": "සීයා නිවස වටා සවි කිරීමට ආසයි  ඇති දේවල්",
#             "correct": "සීයා නිවස වටා ඇති දේවල් සවි කිරීමට ආසයි"
#         },
#         {
#             "incorrect": "එයාලට  සල්ලියක්නෑ කිසිම",
#             "correct": "එයාලට කිසිම සල්ලියක්නෑ"
#         },
#         {
#             "incorrect": "දීප්තිමත්ව හිරු  දිලිසෙනවා",
#             "correct": "හිරු දීප්තිමත්ව දිලිසෙනවා"
#         },
#         {
#             "incorrect": "මම  ආසයි කියවන්න",
#             "correct": "මම කියවන්න ආසයි"
#         },
#         {
#             "incorrect": "පියානෝවාදනයට ඇය  ආසයි",
#             "correct": "ඇය පියානෝවාදනයට ආසයි"
#         },
#         {
#             "incorrect": "ඉන්නේ එයාලා ගෙදරක",
#             "correct": "එයාලා ඉන්නේ ගෙදරක"
#         },
#         {
#             "incorrect": "බළලුන් දිව්වා  වටේ ",
#             "correct": "බළලුන් වටේ දිව්වා"
#         },
#         {
#             "incorrect": "මල් වසන්තයේදීය පිපෙන්නේ ",
#             "correct": "මල් පිපෙන්නේ වසන්තයේදීය"
#         },
#         {
#             "incorrect": "උදේට එයා දුවනවා",
#             "correct": "එයා උදේට දුවනවා"
#         },
#         {
#             "incorrect": "අපි  පීසා කෑවා රෑකෑමට",
#             "correct": "අපි රෑකෑමට පීසා කෑවා"
#         },
#         {
#             "incorrect": "හයියෙන් බල්ලා  බුරනවා",
#             "correct": "බල්ලා හයියෙන් බුරනවා"
#         },
#         {
#             "incorrect": "කුරුල්ලෝ කියනවා සින්දු ",
#             "correct": "කුරුල්ලෝ සින්දු කියනවා"
#         },
#         {
#             "incorrect": "ගලා ගංගාව යයි",
#             "correct": "ගංගාව ගලා යයි"
#         },
#         {
#             "incorrect": "මම තේ  ආසයි බොන්න",
#             "correct": "මම තේ බොන්න ආසයි"
#         },
#         {
#             "incorrect": "ඇය හැටි බලනවා ඉර බහින ",
#             "correct": "ඇය ඉර බහින හැටි බලනවා"
#         },
#         {
#             "incorrect": "ඔවුන් යනවා නිතර ",
#             "correct": "ඔවුන් නිතර යනවා"
#         },
#         {
#             "incorrect": "අද පිරිලා  රෑ හඳ",
#             "correct": "අද රෑ හඳ පිරිලා"
#         },
#         {
#             "incorrect": "සිල්ලරබඩු මට  ගන්න ඕන",
#             "correct": "මට සිල්ලරබඩු ගන්න ඕන"
#         },
#         {
#             "incorrect": "එයා කරන්නෙ වැඩ ",
#             "correct": "එයා වැඩ කරන්නෙ "
#         },
#         {
#             "incorrect": "අපි වැව්වා වත්තක්",
#             "correct": "අපි වත්තක් වැව්වා"
#         },
#         {
#             "incorrect": "කාර් නිල්පාටයි එක ",
#             "correct": "කාර් එක නිල්පාටයි"
#         },
#         {
#             "incorrect": "ඇය බේක්කරයි කුකීස්",
#             "correct": "ඇය කුකීස් බේක්කරයි"
#         },
#         {
#             "incorrect": "කුරුල්ලන් සාදයි කූඩු ",
#             "correct": "කුරුල්ලන් කූඩු සාදයි"
#         },
#         {
#             "incorrect": "ඔහු පුස්තකාලයේ ඉන්නේ ",
#             "correct": "ඔහු ඉන්නේ පුස්තකාලයේ"
#         },
#         {
#             "incorrect": "බබා වෙනවා හිනා ",
#             "correct": "බබා හිනා වෙනවා"
#         },
#         {
#             "incorrect": "ක්රීඩා ඔවුන් කරයි",
#             "correct": "ඔවුන් ක්රීඩා කරයි"
#         },
#         {
#             "incorrect": "කන්ද උසයි හරි ",
#             "correct": "කන්ද හරි උසයි"
#         },
#         {
#             "incorrect": "මට ඇහෙනවා මුහුද ",
#             "correct": "මට මුහුද ඇහෙනවා"
#         },
#         {
#             "incorrect": "ලියුමක් එයා ලිව්වා",
#             "correct": "එයා ලියුමක් ලිව්වා"
#         },
#         {
#             "incorrect": "අපි පැදුවා බයිසිකල් ",
#             "correct": "අපි බයිසිකල් පැදුවා"
#         },
#         {
#             "incorrect": "රත් කෝපි  වෙලා",
#             "correct": "කෝපි රත් වෙලා"
#         },
#         {
#             "incorrect": "ඔහු පිහිනයි  තටාකයේ ",
#             "correct": "ඔහු තටාකයේ පිහිනයි"
#         },
#         {
#             "incorrect": "හිම ශීතඍතුවේ වැටෙනවා",
#             "correct": "ශීතඍතුවේ හිම වැටෙනවා"
#         },
#         {
#             "incorrect": "ඔවුන් ගියා යුරෝපයට ",
#             "correct": "ඔවුන් යුරෝපයට ගියා"
#         },
#         {
#             "incorrect": "මම බැලුවා ෆිල්ම් ",
#             "correct": "මම ෆිල්ම් බැලුවා"
#         },
#         {
#             "incorrect": "ලස්සනට ඇය නටනවා",
#             "correct": "ඇය ලස්සනට නටනවා"
#         },
#         {
#             "incorrect": "දුරකථනය විය නාද ",
#             "correct": "දුරකථනය නාද විය"
#         },
#         {
#             "incorrect": "කඳුකරයේ අපි නැග්ගා",
#             "correct": "අපි කඳුකරයේ නැග්ගා"
#         },
#         {
#             "incorrect": "ගසෙහි ඇත කොළ ",
#             "correct": "ගසෙහි කොළ ඇත"
#         },
#         {
#             "incorrect": "උයන්න එයා ආසයි",
#             "correct": "එයා උයන්න ආසයි"
#         },
#         {
#             "incorrect": "සංක්රමණය කුරුල්ලන්  වේ",
#             "correct": "කුරුල්ලන් සංක්රමණය වේ"
#         },
#         {
#             "incorrect": "මට ඕනේ ජැකට් ",
#             "correct": "මට ජැකට් ඕනේ"
#         },
#         {
#             "incorrect": "ඇය ඇන්දා චිත්‍රරයක් ",
#             "correct": "ඇය චිත්‍රරයක් ඇන්දා "
#         },
#         {
#             "incorrect": "කල් තරඟය දැම්මා.",
#             "correct": "තරඟය කල් දැම්මා."
#         },
#         {
#             "incorrect": "හෙට වහිනවා දවසම ",
#             "correct": "හෙට දවසම වහිනවා"
#         },
#         {
#             "incorrect": "පාපන්දු ජේක් ක්‍රීඩාකළා",
#             "correct": "ජේක් පාපන්දු ක්‍රීඩාකළා"
#         },
#         {
#             "incorrect": "ෆිල්ම් සාරා බැලුවා",
#             "correct": "සාරා ෆිල්ම් බැලුවා"
#         },
#         {
#             "incorrect": "දවසම බළලා නිදාගත්තා",
#             "correct": "බළලා දවසම නිදාගත්තා"
#         },
#         {
#             "incorrect": "ඔවුන් පිරිසිදුකළා  කාමරය ",
#             "correct": "ඔවුන් කාමරය පිරිසිදුකළා"
#         },
#         {
#             "incorrect": "කිචිබිචි කුරුල්ලා  ගාන්නට විය",
#             "correct": "කුරුල්ලා  කිචිබිචි ගාන්නට විය"
#         },
#         {
#             "incorrect": "ඔහු ගියේය බැලීමට ",
#             "correct": "ඔහු බැලීමට ගියේය"
#         },
#         {
#             "incorrect": "අවසන් ටිම් ආහාරය කළේය",
#             "correct": "ටිම් ආහාරය අවසන් කළේය"
#         },
#         {
#             "incorrect": "නතර විය මෝටර්රථය",
#             "correct": "මෝටර්රථය නතර විය"
#         },
#         {
#             "incorrect": "අපි දැක්කා දේදුන්නක්",
#             "correct": "අපි දේදුන්නක් දැක්කා"
#         },
#         {
#             "incorrect": "සාදයේදී නැටුවා සෑම් ",
#             "correct": "සාදයේදී සෑම් නැටුවා"
#         },
#         {
#             "incorrect": "ජැක් කළේය ක්‍රීඩා ",
#             "correct": "ජැක් ක්‍රීඩා කළේය"
#         },
#         {
#             "incorrect": "කුකීස් ලීසා පිළිස්සුවාය",
#             "correct": "ලීසා කුකීස් පිළිස්සුවාය"
#         },
#         {
#             "incorrect": "ටොම් ගියේය ඇවිද ",
#             "correct": "ටොම් ඇවිද ගියේය"
#         },
#         {
#             "incorrect": "නිවාඩුවට සාරා ගියාය",
#             "correct": "සාරා නිවාඩුවට ගියාය"
#         },
#         {
#             "incorrect": "චිත්‍රපටයක් අපි නැරඹුවෙමු",
#             "correct": "අපි චිත්‍රපටයක් නැරඹුවෙමු"
#         },
#         {
#             "incorrect": "ලුහුබැඳ බළලා ගියේය",
#             "correct": "බළලා ලුහුබැඳ ගියේය"
#         },
#         {
#             "incorrect": "පින්තාරු පින්තූරයක්  කළා",
#             "correct": "පින්තූරයක් පින්තාරු කළා"
#         },
#         {
#             "incorrect": "කුස්සිය ඇලෙක්ස්  පිරිසිදු කළේය",
#             "correct": "ඇලෙක්ස් කුස්සිය පිරිසිදු කළේය"
#         },
#         {
#             "incorrect": "බැස හිරු ගියේය",
#             "correct": "හිරු බැස ගියේය"
#         },
#         {
#             "incorrect": "ඉගෙන සිසු ගත්හ",
#             "correct": "සිසු ඉගෙන ගත්හ"
#         },
#         {
#             "incorrect": "ඉස්කෝලේ ජේක් ගියේය",
#             "correct": "ජේක් ඉස්කෝලේ ගියේය"
#         },
#         {
#             "incorrect": "ප්‍රසංගයේදී ලුසී නැටුවාය",
#             "correct": "ලුසී ප්‍රසංගයේදී නැටුවාය"
#         },
#         {
#             "incorrect": "ඔවුන් ඉදිකළහ වැලිමාලිගාවක්",
#             "correct": "ඔවුන් වැලිමාලිගාවක් ඉදිකළහ"
#         },
#         {
#             "incorrect": "අපි  නැරඹුවෙමු චිත්‍රපටයක්",
#             "correct": "අපි චිත්‍රපටයක් නැරඹුවෙමු"
#         },
#         {
#             "incorrect": "චාරිකාවක් අපි යනවා",
#             "correct": "අපි චාරිකාවක් යනවා"
#         },
#         {
#             "incorrect": "වැස්ස විය නතර ",
#             "correct": "වැස්ස නතර විය"
#         },
#         {
#             "incorrect": "මිතුරිය සමන්තා ඇමතුවාය",
#             "correct": "සමන්තා මිතුරිය ඇමතුවාය"
#         },
#         {
#             "incorrect": "මැක්ස්  ගියා ගමනක්",
#             "correct": "මැක්ස් ගමනක් ගියා"
#         },
#         {
#             "incorrect": "එක බයික් හදන්න",
#             "correct": "බයික් එක හදන්න"
#         },
#         {
#             "incorrect": "ටයර්  හදන්න එක",
#             "correct": "ටයර් එක හදන්න"
#         },
#         {
#             "incorrect": "ගුරුවරයා කියෙව්වා කතාවක් ",
#             "correct": "ගුරුවරයා කතාවක් කියෙව්වා"
#         },
#         {
#             "incorrect": "ක්‍රීඩා මයික් කළේය",
#             "correct": "මයික් ක්‍රීඩා කළේය"
#         },
#         {
#             "incorrect": "ඇමී දුටුවේය සතුන්",
#             "correct": "ඇමී සතුන් දුටුවේය"
#         },
#         {
#             "incorrect": "ජේසන් නැග්ගා කන්ද ",
#             "correct": "ජේසන් කන්ද නැග්ගා"
#         },
#         {
#             "incorrect": "කන්ද ජේසන් නැග්ගාද?",
#             "correct": "ජේසන් කන්ද නැග්ගාද?"
#         },
#         {
#             "incorrect": "මම නැග්ගේමි කන්ද ",
#             "correct": "මම කන්ද නැග්ගේමි"
#         },
#         {
#             "incorrect": "එක කාටූන් මොකක්ද?",
#             "correct": "කාටූන් එක මොකක්ද?"
#         },
#         {
#             "incorrect": "අත්පුඩි බබා ගැහුවා",
#             "correct": "බබා අත්පුඩි ගැහුවා"
#         },
#         {
#             "incorrect": "බල්ලා  ගියේය දිව",
#             "correct": "බල්ලා දිව ගියේය"
#         },
#         {
#             "incorrect": "අල්ලා පන්දුව ගත්තද?",
#             "correct": "පන්දුව අල්ලා  ගත්තද?"
#         },
#         {
#             "incorrect": "ලීසා කළාය උදව් ",
#             "correct": "ලීසා උදව් කළාය"
#         },
#         {
#             "incorrect": "මේකට බල්ලා කැමතිද?",
#             "correct": "බල්ලා මේකට කැමතිද?"
#         },
#         {
#             "incorrect": "කතාවට ගුරුවරයා කැමතිද? ",
#             "correct": "ගුරුවරයා කතාවට කැමතිද? "
#         },
#         {
#             "incorrect": "ටිම්ට හැරුනා මග ",
#             "correct": "ටිම්ට මග හැරුනා"
#         },
#         {
#             "incorrect": "මල් ලස්සනට වසන්තයේ පිපෙනවා",
#             "correct": "වසන්තයේ මල් ලස්සනට පිපෙනවා"
#         },
#         {
#             "incorrect": "උපන්දිනය සාරා සැමරුවාය ",
#             "correct": "සාරා උපන්දිනය සැමරුවාය "
#         },
#         {
#             "incorrect": "අපි වෙමු පුදුම ",
#             "correct": "අපි පුදුම වෙමු"
#         },
#         {
#             "incorrect": "ලිපියක් සාරා ලිව්වාය",
#             "correct": "සාරා ලිපියක් ලිව්වාය"
#         },
#         {
#             "incorrect": "පෙට්ටියක් ළමයා සොයා ගත්තේය",
#             "correct": "ළමයා පෙට්ටියක් සොයා ගත්තේය"
#         },
#         {
#             "incorrect": "නිධන් අපි සොයා ගත්තෙමු ",
#             "correct": "අපි නිධන් සොයා ගත්තෙමු "
#         },
#         {
#             "incorrect": "දියඇල්ලක් අපි සොයා ගත්තෙමු",
#             "correct": "අපි දියඇල්ලක් සොයා ගත්තෙමු"
#         },
#         {
#             "incorrect": "පුවරුක්‍රීඩා ඔවුහු කළහ",
#             "correct": "ඔවුහු පුවරුක්‍රීඩා කළහ"
#         }
#     ],
#     "pronoun_ending_match": [
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "ු,"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "නෑ"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ඳා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "අපි",
#             "end": "ඳා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "තා"
#         },
#         {
#             "start": "අපි",
#             "end": "ළා"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ැත"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "හැ"
#         },
#         {
#             "start": "මම",
#             "end": "හැ"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "මම",
#             "end": "ඕන"
#         },
#         {
#             "start": "මම",
#             "end": "ද?"
#         },
#         {
#             "start": "අපි",
#             "end": "යේ"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "යා"
#         },
#         {
#             "start": "අපි",
#             "end": "ලා"
#         },
#         {
#             "start": "මම",
#             "end": "්න"
#         },
#         {
#             "start": "මම",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "මම",
#             "end": "යි"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යේ"
#         },
#         {
#             "start": "අපි",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "යි"
#         },
#         {
#             "start": "මම",
#             "end": "වා"
#         },
#         {
#             "start": "ඔහු",
#             "end": "ේය"
#         },
#         {
#             "start": "අපි",
#             "end": "කා"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         },
#         {
#             "start": "මම",
#             "end": "මි"
#         },
#         {
#             "start": "අපි",
#             "end": "මු"
#         }
#     ],
#     "verb_conjugation": [
#         {
#             "incorrect": "සරුංගලය",
#             "correct": "හැඩයි"
#         },
#         {
#             "incorrect": "නිවේදනය",
#             "correct": "කරයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "මතකයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "අමුණයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "හැඟෙයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "ඇසෙයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "තෝරාගනියි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "කියවයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "මතකයි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "පෙනෙයි"
#         },
#         {
#             "incorrect": "ඇය",
#             "correct": "ස්තූතියි"
#         },
#         {
#             "incorrect": "එය",
#             "correct": "අවශ්‍යයි"
#         },
#         {
#             "incorrect": "රිය",
#             "correct": "නොපදවයි"
#         }
#     ]
# }
# Accuracy of the rule-based correction system: 16.50%
# Original Sentence:   පාසැල දරුව ගියේය
# Corrected Sentence: පාසැල් දරුවෝ ගියේය
